# %% [markdown]
# # **Data Preprocessing**

# %%
# Importing the drive module from google.colab library
from google.colab import drive

# Mounting the Google Drive to the Colab environment
drive.mount('/content/drive')

project_path = '/content/drive/My Drive/GitHub/MarineMammalSoundClassification/'
# %cd /content/drive/My Drive/GitHub/MarineMammalSoundClassification/
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1oJSL58N419Ve8pd0wCvgXEy52hLM2tJN/MarineMammalSoundClassification

# %%
import os
import shutil
import json
from utils.utilities import ensure_dir, get_wav_duration

# %% [markdown]
# ## **Data Cleaning**
#
# During the initial preprocessing, folders containing fewer than 20 instances were deleted. We then attempted to use the pyAudioAnalysis library to split the data into training, validation, and test sets. However, some files in the remaining folders produced errors, including an entire class (Fin_FinbackWhale). Consequently, during a second round of preprocessing, this class folder and the problematic files within other folders were also deleted.
#
# Overall, the following folders of classes and specific files from the remaining classes have been removed from our data:
#
# Directories:
#
# *   **data/LeopardSeal** (10 instances)
# *   **data/MinkeWhale** (17 instances)
# *   **data/WeddellSeal** (2 instances)
# *   **data/Fin_FinbackWhale** (IndexError: index 15 is out of bounds for axis 0 with size 15)
#
# Files:
#
# *   **data/PantropicalSpottedDolphin/84021003.wav** (WAV header is invalid: nAvgBytesPerSec must equal product of nSamplesPerSec and nBlockAlign, but file has nSamplesPerSec = 40960, nBlockAlign = 2, and nAvgBytesPerSec = 61440)
# *   **data/Short_Finned(Pacific)PilotWhale/57021003.wav** (WAV header is invalid: nAvgBytesPerSec must equal product of nSamplesPerSec and nBlockAlign, but file has nSamplesPerSec = 30000, nBlockAlign = 2, and nAvgBytesPerSec = 45000)
# *   **data/SpermWhale/84021003.wav** (WAV header is invalid: nAvgBytesPerSec must equal product of nSamplesPerSec and nBlockAlign, but file has nSamplesPerSec = 40960, nBlockAlign = 2, and nAvgBytesPerSec = 61440)

# %%
directory_paths = ['data/LeopardSeal', 'data/MinkeWhale', 'data/WeddellSeal', 'data/Fin_FinbackWhale']

for dpath in directory_paths:
  if os.path.exists(dpath):
      shutil.rmtree(dpath)
      print(f"The directory {dpath} has been deleted.")
  else:
      print(f"The directory {dpath} does not exist.")

file_paths = ['data/PantropicalSpottedDolphin/84021003.wav', 'data/Short_Finned(Pacific)PilotWhale/57021003.wav', 'data/SpermWhale/84021003.wav']

for fpath in file_paths:
  if os.path.exists(fpath):
      os.remove(fpath)
      print(f"The file {fpath} has been deleted.")
  else:
      print(f"The file {fpath} does not exist.")
# Out:
# The directory data/LeopardSeal has been deleted.
# The directory data/MinkeWhale has been deleted.
# The directory data/WeddellSeal has been deleted.
# The directory data/Fin_FinbackWhale has been deleted.
# The file data/PantropicalSpottedDolphin/84021003.wav has been deleted.
# The file data/Short_Finned(Pacific)PilotWhale/57021003.wav has been deleted.
# The file data/SpermWhale/84021003.wav has been deleted.

# %% [markdown]
# We also delete any files that, according to their metadata, appear to contain <u>more than one mammal sounds</u>.

# %%
# Load metadata from JSON files
with open('metadata/wav_metadata.json', 'r') as f:
    wav_metadata = json.load(f)

with open('metadata/species.json', 'r') as f:
    species = json.load(f)

for m in wav_metadata:
    na = wav_metadata[m]['NA:'].replace("  ", " ")
    num_of_animals = na.split('|')

    if len(num_of_animals) > 1:
        print(m+'.wav')
        print(na)

        animal_1_code = num_of_animals[0].split(" ")[-2]
        animal_2_code = num_of_animals[1].split(" ")[-1]

        animal_1_name = next((s for s in species if species[s]['code'] == animal_1_code), None)
        animal_2_name = next((s for s in species if species[s]['code'] == animal_2_code), None)

        if animal_1_name and animal_2_name:
            print(animal_1_name, animal_2_name)

            filepath_1 = os.path.join('data', animal_1_name, m + '.wav')
            filepath_2 = os.path.join('data', animal_2_name, m + '.wav')

            if os.path.exists(filepath_1):
                os.remove(filepath_1)

            if os.path.exists(filepath_2):
                os.remove(filepath_2)
# Out:
# 72021005.wav
# 1, possibly 2+ AA1A | 1+ CC2A
# BowheadWhale BeardedSeal
# 7202100T.wav
# 1+ AA1A | 1+ CC2A
# BowheadWhale BeardedSeal
# 7202100V.wav
# 1+ AA1A | 1+ CC2A
# BowheadWhale BeardedSeal
# 7202100Z.wav
# 1+ AA1A | 1+ CC2A
# BowheadWhale BeardedSeal
# 78018002.wav
# 3+ CC2A | 1+ AA1A
# BeardedSeal BowheadWhale
# 78018003.wav
# 3+ CC2A | 1+ AA1A
# BeardedSeal BowheadWhale
# 7801800B.wav
# 1+ AA1A | 3+ CC2A
# BowheadWhale BeardedSeal
# 7801800D.wav
# 1+ AA1A | 3+ CC2A
# BowheadWhale BeardedSeal
# 7801800H.wav
# 1+ AA1A | 3+ CC2A
# BowheadWhale BeardedSeal
# 7801800J.wav
# 1+ AA1A | 3+ CC2A
# BowheadWhale BeardedSeal
# 91012009.wav
# 2+ BD10A | 1+ BA2A
# MelonHeadedWhale SpermWhale
# 9101200B.wav
# 2 BD10A | 1+ BA2A
# MelonHeadedWhale SpermWhale
# 9101200K.wav
# 2+ BD10A | 1+ BA2A
# MelonHeadedWhale SpermWhale
# 9101201E.wav
# 1 BD10A | 1 BA2A
# MelonHeadedWhale SpermWhale
# 84021003.wav
# 1 BA2A | 3 BD15A
# SpermWhale PantropicalSpottedDolphin
# 90058068.wav
# 3 BA2A | 100-150 BD15A
# SpermWhale PantropicalSpottedDolphin
# 9005807N.wav
# 3 BA2A | 100-150 BD15A
# SpermWhale PantropicalSpottedDolphin
# 9005807O.wav
# 3 BA2A | 100-150 BD15A
# SpermWhale PantropicalSpottedDolphin
# 9005807P.wav
# 3 BA2A | 100-150 BD15A
# SpermWhale PantropicalSpottedDolphin

# %% [markdown]
# ## **Convert Sample Rate**
#
# Our EDA revealed that the .wav files have varying sample rates across different species. Therefore, before creating spectrograms and testing the models, <u>we standardize all .wav files to a sample rate of 22050</u>, using the [ffmpeg-python](https://github.com/kkroening/ffmpeg-python) library.

# %%
# !pip install ffmpeg-python
# Out:
# Collecting ffmpeg-python
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from ffmpeg-python) (0.18.3)
# Installing collected packages: ffmpeg-python
# Successfully installed ffmpeg-python-0.2.0

# %%
import ffmpeg

def convert_sample_rate(input_file, output_file, new_sample_rate):
    """
    Convert the sample rate of an audio file to a new specified rate.

    Parameters:
    input_file (str): The path to the input audio file.
    output_file (str): The path where the output audio file will be saved.
    new_sample_rate (int): The new sample rate to set for the audio file.

    Returns:
    None
    """
    (
        ffmpeg
        .input(input_file)
        .output(output_file, ar=new_sample_rate)
        .overwrite_output()
        .run()
    )

# %%
# Define the input (source) and output(destination) directories
## Source and destination directories
source_dir = 'data'
destination_dir = 'data_22050'

# Ensure the destination directory exists
ensure_dir(destination_dir)

## Walk through all files in the source directory
for root, dirs, files in os.walk(source_dir):
    for file in files:
        if file.lower().endswith('.wav'):
            input_file = os.path.join(root, file)
            print('Convert: '+input_file)
            relative_path = os.path.relpath(input_file, source_dir)
            output_file = os.path.join(destination_dir, relative_path)
            ensure_dir(os.path.dirname(output_file))
            convert_sample_rate(input_file, output_file, 22050)
# Out:
# Convert: data/AtlanticSpottedDolphin/61025001.wav
# Convert: data/AtlanticSpottedDolphin/61025002.wav
# Convert: data/AtlanticSpottedDolphin/61025003.wav
# Convert: data/AtlanticSpottedDolphin/61025004.wav
# Convert: data/AtlanticSpottedDolphin/61025006.wav
# Convert: data/AtlanticSpottedDolphin/61025007.wav
# Convert: data/AtlanticSpottedDolphin/61025008.wav
# Convert: data/AtlanticSpottedDolphin/61025009.wav
# Convert: data/AtlanticSpottedDolphin/6102500A.wav
# Convert: data/AtlanticSpottedDolphin/6102500B.wav
# Convert: data/AtlanticSpottedDolphin/6102500C.wav
# Convert: data/AtlanticSpottedDolphin/6102500D.wav
# Convert: data/AtlanticSpottedDolphin/6102500E.wav
# Convert: data/AtlanticSpottedDolphin/6102500F.wav
# Convert: data/AtlanticSpottedDolphin/6102500G.wav
# Convert: data/AtlanticSpottedDolphin/6102500H.wav
# Convert: data/AtlanticSpottedDolphin/6102500I.wav
# Convert: data/AtlanticSpottedDolphin/6102500J.wav
# Convert: data/AtlanticSpottedDolphin/6102500K.wav
# Convert: data/AtlanticSpottedDolphin/6102500M.wav
# Convert: data/AtlanticSpottedDolphin/6102500N.wav
# Convert: data/AtlanticSpottedDolphin/6102500O.wav
# Convert: data/AtlanticSpottedDolphin/6102500P.wav
# Convert: data/AtlanticSpottedDolphin/6102500Q.wav
# Convert: data/AtlanticSpottedDolphin/6102500R.wav
# Convert: data/AtlanticSpottedDolphin/61026001.wav
# Convert: data/AtlanticSpottedDolphin/61026002.wav
# Convert: data/AtlanticSpottedDolphin/61026004.wav
# Convert: data/AtlanticSpottedDolphin/6102600F.wav
# Convert: data/AtlanticSpottedDolphin/6102600G.wav
# Convert: data/AtlanticSpottedDolphin/6102601Y.wav
# Convert: data/AtlanticSpottedDolphin/6102601Z.wav
# Convert: data/AtlanticSpottedDolphin/61026020.wav
# Convert: data/AtlanticSpottedDolphin/61026021.wav
# Convert: data/AtlanticSpottedDolphin/6102602I.wav
# Convert: data/AtlanticSpottedDolphin/6102602J.wav
# Convert: data/AtlanticSpottedDolphin/6102602K.wav
# Convert: data/AtlanticSpottedDolphin/6102602T.wav
# Convert: data/AtlanticSpottedDolphin/6102602U.wav
# Convert: data/AtlanticSpottedDolphin/6102602V.wav
# Convert: data/AtlanticSpottedDolphin/6102602W.wav
# Convert: data/AtlanticSpottedDolphin/61026031.wav
# Convert: data/AtlanticSpottedDolphin/61026036.wav
# Convert: data/AtlanticSpottedDolphin/6102603A.wav
# Convert: data/AtlanticSpottedDolphin/6102603C.wav
# Convert: data/AtlanticSpottedDolphin/6102603E.wav
# Convert: data/AtlanticSpottedDolphin/6102603F.wav
# Convert: data/AtlanticSpottedDolphin/6102603I.wav
# Convert: data/AtlanticSpottedDolphin/6102603L.wav
# Convert: data/AtlanticSpottedDolphin/6102603O.wav
# Convert: data/AtlanticSpottedDolphin/6102603S.wav
# Convert: data/AtlanticSpottedDolphin/6102603V.wav
# Convert: data/AtlanticSpottedDolphin/6102603W.wav
# Convert: data/AtlanticSpottedDolphin/6102603X.wav
# Convert: data/AtlanticSpottedDolphin/6102603Z.wav
# Convert: data/AtlanticSpottedDolphin/6102604J.wav
# Convert: data/AtlanticSpottedDolphin/6102604K.wav
# Convert: data/AtlanticSpottedDolphin/6102604L.wav
# Convert: data/BeardedSeal/66038001.wav
# Convert: data/BeardedSeal/66038002.wav
# Convert: data/BeardedSeal/66038003.wav
# Convert: data/BeardedSeal/66038004.wav
# Convert: data/BeardedSeal/66038005.wav
# Convert: data/BeardedSeal/66038007.wav
# Convert: data/BeardedSeal/70025001.wav
# Convert: data/BeardedSeal/70025002.wav
# Convert: data/BeardedSeal/70025003.wav
# Convert: data/BeardedSeal/70025004.wav
# Convert: data/BeardedSeal/70025005.wav
# Convert: data/BeardedSeal/70025006.wav
# Convert: data/BeardedSeal/70025007.wav
# Convert: data/BeardedSeal/70025008.wav
# Convert: data/BeardedSeal/70025009.wav
# Convert: data/BeardedSeal/71012001.wav
# Convert: data/BeardedSeal/71012002.wav
# Convert: data/BeardedSeal/71012003.wav
# Convert: data/BeardedSeal/71012004.wav
# Convert: data/BeardedSeal/71012005.wav
# Convert: data/BeardedSeal/71012006.wav
# Convert: data/BeardedSeal/71012007.wav
# Convert: data/BeardedSeal/71012008.wav
# Convert: data/BeardedSeal/71012009.wav
# Convert: data/BeardedSeal/78018001.wav
# Convert: data/BeardedSeal/78018005.wav
# Convert: data/BeardedSeal/7801800M.wav
# Convert: data/Beluga_WhiteWhale/62018001.wav
# Convert: data/Beluga_WhiteWhale/62018002.wav
# Convert: data/Beluga_WhiteWhale/62019001.wav
# Convert: data/Beluga_WhiteWhale/62019007.wav
# Convert: data/Beluga_WhiteWhale/6202200E.wav
# Convert: data/Beluga_WhiteWhale/6202200F.wav
# Convert: data/Beluga_WhiteWhale/6202200G.wav
# Convert: data/Beluga_WhiteWhale/6202200P.wav
# Convert: data/Beluga_WhiteWhale/6202200Q.wav
# Convert: data/Beluga_WhiteWhale/6202200T.wav
# Convert: data/Beluga_WhiteWhale/6202200W.wav
# Convert: data/Beluga_WhiteWhale/6202200Z.wav
# Convert: data/Beluga_WhiteWhale/62022012.wav
# Convert: data/BottlenoseDolphin/89514014.wav
# Convert: data/BottlenoseDolphin/89514015.wav
# Convert: data/BottlenoseDolphin/89514017.wav
# Convert: data/BottlenoseDolphin/89514018.wav
# Convert: data/BowheadWhale/7202100Q.wav
# Convert: data/BowheadWhale/88006001.wav
# Convert: data/BowheadWhale/88006003.wav
# Convert: data/BowheadWhale/88006005.wav
# Convert: data/BowheadWhale/88006006.wav
# Convert: data/BowheadWhale/88006007.wav
# Convert: data/BowheadWhale/88006008.wav
# Convert: data/BowheadWhale/8800600A.wav
# Convert: data/BowheadWhale/8800600C.wav
# Convert: data/BowheadWhale/8800600D.wav
# Convert: data/BowheadWhale/8800600E.wav
# Convert: data/BowheadWhale/8800600F.wav
# Convert: data/BowheadWhale/8800600G.wav
# Convert: data/BowheadWhale/8800600H.wav
# Convert: data/BowheadWhale/8800600I.wav
# Convert: data/BowheadWhale/8800600J.wav
# Convert: data/BowheadWhale/8800600K.wav
# Convert: data/BowheadWhale/8800600L.wav
# Convert: data/BowheadWhale/8800600N.wav
# Convert: data/BowheadWhale/8800600O.wav
# Convert: data/BowheadWhale/8800600P.wav
# Convert: data/BowheadWhale/8800600Q.wav
# Convert: data/BowheadWhale/8800600R.wav
# Convert: data/BowheadWhale/8800600S.wav
# Convert: data/BowheadWhale/8800600T.wav
# Convert: data/BowheadWhale/8800600U.wav
# Convert: data/BowheadWhale/8800600W.wav
# Convert: data/BowheadWhale/8800600Y.wav
# Convert: data/BowheadWhale/8800600Z.wav
# Convert: data/BowheadWhale/88006013.wav
# Convert: data/BowheadWhale/88006016.wav
# Convert: data/BowheadWhale/88006017.wav
# Convert: data/BowheadWhale/8800601B.wav
# Convert: data/BowheadWhale/8800601C.wav
# Convert: data/BowheadWhale/8800601L.wav
# Convert: data/BowheadWhale/8800601U.wav
# Convert: data/BowheadWhale/8800601Y.wav
# Convert: data/BowheadWhale/8800602Q.wav
# Convert: data/BowheadWhale/8800602S.wav
# Convert: data/BowheadWhale/8800602T.wav
# Convert: data/BowheadWhale/8800602U.wav
# Convert: data/BowheadWhale/8800602Z.wav
# Convert: data/BowheadWhale/88006030.wav
# Convert: data/BowheadWhale/88006031.wav
# Convert: data/BowheadWhale/88006032.wav
# Convert: data/BowheadWhale/88006033.wav
# Convert: data/BowheadWhale/88006034.wav
# Convert: data/BowheadWhale/88006036.wav
# Convert: data/BowheadWhale/88006037.wav
# Convert: data/BowheadWhale/88006038.wav
# Convert: data/ClymeneDolphin/83006001.wav
# Convert: data/ClymeneDolphin/83006002.wav
# Convert: data/ClymeneDolphin/83006003.wav
# Convert: data/ClymeneDolphin/83006008.wav
# Convert: data/ClymeneDolphin/83006009.wav
# Convert: data/ClymeneDolphin/8300600A.wav
# Convert: data/ClymeneDolphin/8300600B.wav
# Convert: data/ClymeneDolphin/8300600C.wav
# Convert: data/ClymeneDolphin/8300600D.wav
# Convert: data/ClymeneDolphin/8300600E.wav
# Convert: data/ClymeneDolphin/8300600F.wav
# Convert: data/ClymeneDolphin/8300600N.wav
# Convert: data/Grampus_Risso'sDolphin/85009007.wav
# Convert: data/Grampus_Risso'sDolphin/85009008.wav
# Convert: data/Grampus_Risso'sDolphin/85009009.wav
# Convert: data/Grampus_Risso'sDolphin/8500900A.wav
# Convert: data/Grampus_Risso'sDolphin/8500900I.wav
# Convert: data/Grampus_Risso'sDolphin/8500900J.wav
# Convert: data/Grampus_Risso'sDolphin/8500900L.wav
# Convert: data/Grampus_Risso'sDolphin/8500900M.wav
# Convert: data/Grampus_Risso'sDolphin/8500900N.wav
# Convert: data/Grampus_Risso'sDolphin/8500900O.wav
# Convert: data/Grampus_Risso'sDolphin/8500900P.wav
# Convert: data/Grampus_Risso'sDolphin/8500900Q.wav
# Convert: data/Grampus_Risso'sDolphin/8500900R.wav
# Convert: data/Grampus_Risso'sDolphin/8500900S.wav
# Convert: data/Grampus_Risso'sDolphin/8500900T.wav
# Convert: data/Grampus_Risso'sDolphin/8500900U.wav
# Convert: data/Grampus_Risso'sDolphin/8700400E.wav
# Convert: data/HarpSeal/67008008.wav
# Convert: data/HarpSeal/67009001.wav
# Convert: data/HarpSeal/67009002.wav
# Convert: data/HarpSeal/67009003.wav
# Convert: data/HarpSeal/67009004.wav
# Convert: data/HarpSeal/67009005.wav
# Convert: data/HarpSeal/67009006.wav
# Convert: data/HarpSeal/67009007.wav
# Convert: data/HarpSeal/67009008.wav
# Convert: data/HarpSeal/67009009.wav
# Convert: data/HarpSeal/6700900A.wav
# Convert: data/HarpSeal/6700900B.wav
# Convert: data/HarpSeal/6700900D.wav
# Convert: data/HarpSeal/6700900E.wav
# Convert: data/HarpSeal/6700900F.wav
# Convert: data/HarpSeal/6700900G.wav
# Convert: data/HarpSeal/6700900H.wav
# Convert: data/HarpSeal/6700900I.wav
# Convert: data/HarpSeal/6700900J.wav
# Convert: data/HarpSeal/6700900K.wav
# Convert: data/HarpSeal/6700900L.wav
# Convert: data/HarpSeal/6700900M.wav
# Convert: data/HarpSeal/6700900N.wav
# Convert: data/HarpSeal/6700900P.wav
# Convert: data/HarpSeal/6700900Q.wav
# Convert: data/HarpSeal/6700900R.wav
# Convert: data/HarpSeal/6700900S.wav
# Convert: data/HarpSeal/6700900T.wav
# Convert: data/HarpSeal/6700900U.wav
# Convert: data/HarpSeal/6700900W.wav
# Convert: data/HarpSeal/67010001.wav
# Convert: data/HarpSeal/67010002.wav
# Convert: data/HarpSeal/67010003.wav
# Convert: data/HarpSeal/67010004.wav
# Convert: data/HarpSeal/67010005.wav
# Convert: data/HarpSeal/67010006.wav
# Convert: data/HarpSeal/67010007.wav
# Convert: data/HarpSeal/67010008.wav
# Convert: data/HarpSeal/67010009.wav
# Convert: data/HarpSeal/6701000A.wav
# Convert: data/HarpSeal/6701000B.wav
# Convert: data/HarpSeal/6701000C.wav
# Convert: data/HarpSeal/6701000D.wav
# Convert: data/HarpSeal/6701000E.wav
# Convert: data/HarpSeal/6701000F.wav
# Convert: data/HarpSeal/6701000G.wav
# Convert: data/HarpSeal/6701000H.wav
# Convert: data/HumpbackWhale/55113001.wav
# Convert: data/HumpbackWhale/55113002.wav
# Convert: data/HumpbackWhale/55113003.wav
# Convert: data/HumpbackWhale/55113004.wav
# Convert: data/HumpbackWhale/55113007.wav
# Convert: data/HumpbackWhale/5511300F.wav
# Convert: data/HumpbackWhale/63019001.wav
# Convert: data/HumpbackWhale/63019002.wav
# Convert: data/HumpbackWhale/63019003.wav
# Convert: data/HumpbackWhale/63019004.wav
# Convert: data/HumpbackWhale/63019005.wav
# Convert: data/HumpbackWhale/63019007.wav
# Convert: data/HumpbackWhale/6301900B.wav
# Convert: data/HumpbackWhale/6301900C.wav
# Convert: data/HumpbackWhale/6301900D.wav
# Convert: data/HumpbackWhale/6301900T.wav
# Convert: data/HumpbackWhale/6301900V.wav
# Convert: data/HumpbackWhale/6301900W.wav
# Convert: data/HumpbackWhale/6301900Y.wav
# Convert: data/HumpbackWhale/6301900Z.wav
# Convert: data/HumpbackWhale/63019010.wav
# Convert: data/HumpbackWhale/63019011.wav
# Convert: data/HumpbackWhale/63019012.wav
# Convert: data/HumpbackWhale/63019014.wav
# Convert: data/HumpbackWhale/63019016.wav
# Convert: data/HumpbackWhale/63019017.wav
# Convert: data/HumpbackWhale/63019018.wav
# Convert: data/HumpbackWhale/63019019.wav
# Convert: data/HumpbackWhale/6301901A.wav
# Convert: data/HumpbackWhale/6301901B.wav
# Convert: data/HumpbackWhale/6301901C.wav
# Convert: data/HumpbackWhale/6301901D.wav
# Convert: data/HumpbackWhale/6301901E.wav
# Convert: data/HumpbackWhale/6301901H.wav
# Convert: data/HumpbackWhale/6301901L.wav
# Convert: data/HumpbackWhale/6301901M.wav
# Convert: data/HumpbackWhale/6301901N.wav
# Convert: data/HumpbackWhale/6301901T.wav
# Convert: data/HumpbackWhale/6301901U.wav
# Convert: data/HumpbackWhale/6301901V.wav
# Convert: data/HumpbackWhale/6304300E.wav
# Convert: data/HumpbackWhale/6304300F.wav
# Convert: data/HumpbackWhale/6304300K.wav
# Convert: data/HumpbackWhale/6304300M.wav
# Convert: data/HumpbackWhale/6304300N.wav
# Convert: data/HumpbackWhale/6304300O.wav
# Convert: data/HumpbackWhale/8002001M.wav
# Convert: data/HumpbackWhale/92201001.wav
# Convert: data/HumpbackWhale/92201002.wav
# Convert: data/HumpbackWhale/92201003.wav
# Convert: data/HumpbackWhale/92201005.wav
# Convert: data/HumpbackWhale/92201007.wav
# Convert: data/HumpbackWhale/9220100B.wav
# Convert: data/HumpbackWhale/9220100D.wav
# Convert: data/HumpbackWhale/9220100E.wav
# Convert: data/HumpbackWhale/9220100F.wav
# Convert: data/HumpbackWhale/9220100G.wav
# Convert: data/HumpbackWhale/9220100Q.wav
# Convert: data/HumpbackWhale/9220100S.wav
# Convert: data/HumpbackWhale/9220100T.wav
# Convert: data/HumpbackWhale/9220100V.wav
# Convert: data/HumpbackWhale/9220100W.wav
# Convert: data/HumpbackWhale/9220100X.wav
# Convert: data/HumpbackWhale/9220100Z.wav
# Convert: data/KillerWhale/60026001.wav
# Convert: data/KillerWhale/60026002.wav
# Convert: data/KillerWhale/60026003.wav
# Convert: data/KillerWhale/60026004.wav
# Convert: data/KillerWhale/60026005.wav
# Convert: data/KillerWhale/60026006.wav
# Convert: data/KillerWhale/6002600A.wav
# Convert: data/KillerWhale/6002600B.wav
# Convert: data/KillerWhale/64020001.wav
# Convert: data/KillerWhale/64020003.wav
# Convert: data/KillerWhale/89405023.wav
# Convert: data/KillerWhale/9230000L.wav
# Convert: data/KillerWhale/92300013.wav
# Convert: data/KillerWhale/92301007.wav
# Convert: data/KillerWhale/92304008.wav
# Convert: data/KillerWhale/9230400D.wav
# Convert: data/KillerWhale/9750000S.wav
# Convert: data/KillerWhale/97501009.wav
# Convert: data/KillerWhale/97503007.wav
# Convert: data/KillerWhale/9750300I.wav
# Convert: data/KillerWhale/9750300N.wav
# Convert: data/KillerWhale/9750300Q.wav
# Convert: data/KillerWhale/9750300V.wav
# Convert: data/KillerWhale/9750300Z.wav
# Convert: data/KillerWhale/97503018.wav
# Convert: data/KillerWhale/9750301L.wav
# Convert: data/KillerWhale/9750301M.wav
# Convert: data/KillerWhale/9750301O.wav
# Convert: data/KillerWhale/9750301Q.wav
# Convert: data/KillerWhale/9750400C.wav
# Convert: data/KillerWhale/9750400J.wav
# Convert: data/KillerWhale/9750400V.wav
# Convert: data/KillerWhale/9761900T.wav
# Convert: data/KillerWhale/97619015.wav
# Convert: data/KillerWhale/9769201Q.wav
# Convert: data/Long_FinnedPilotWhale/54024001.wav
# Convert: data/Long_FinnedPilotWhale/54024002.wav
# Convert: data/Long_FinnedPilotWhale/54024003.wav
# Convert: data/Long_FinnedPilotWhale/54024004.wav
# Convert: data/Long_FinnedPilotWhale/54024005.wav
# Convert: data/Long_FinnedPilotWhale/54024006.wav
# Convert: data/Long_FinnedPilotWhale/54024007.wav
# Convert: data/Long_FinnedPilotWhale/54024008.wav
# Convert: data/Long_FinnedPilotWhale/54024009.wav
# Convert: data/Long_FinnedPilotWhale/5402400A.wav
# Convert: data/Long_FinnedPilotWhale/5402400B.wav
# Convert: data/Long_FinnedPilotWhale/5402400C.wav
# Convert: data/Long_FinnedPilotWhale/7500400U.wav
# Convert: data/Long_FinnedPilotWhale/7500401F.wav
# Convert: data/Long_FinnedPilotWhale/75004025.wav
# Convert: data/Long_FinnedPilotWhale/7500402E.wav
# Convert: data/Long_FinnedPilotWhale/7500402F.wav
# Convert: data/Long_FinnedPilotWhale/7500402I.wav
# Convert: data/Long_FinnedPilotWhale/7500402O.wav
# Convert: data/Long_FinnedPilotWhale/75004033.wav
# Convert: data/Long_FinnedPilotWhale/7500403A.wav
# Convert: data/Long_FinnedPilotWhale/7500403J.wav
# Convert: data/Long_FinnedPilotWhale/7500403N.wav
# Convert: data/Long_FinnedPilotWhale/7500502J.wav
# Convert: data/Long_FinnedPilotWhale/7500502Q.wav
# Convert: data/Long_FinnedPilotWhale/7500502R.wav
# Convert: data/Long_FinnedPilotWhale/7500502S.wav
# Convert: data/Long_FinnedPilotWhale/7500502T.wav
# Convert: data/Long_FinnedPilotWhale/7500502U.wav
# Convert: data/Long_FinnedPilotWhale/7500502V.wav
# Convert: data/Long_FinnedPilotWhale/7500502W.wav
# Convert: data/Long_FinnedPilotWhale/7500502X.wav
# Convert: data/Long_FinnedPilotWhale/7500502Z.wav
# Convert: data/Long_FinnedPilotWhale/75005031.wav
# Convert: data/Long_FinnedPilotWhale/75005032.wav
# Convert: data/Long_FinnedPilotWhale/75005039.wav
# Convert: data/Long_FinnedPilotWhale/7500503L.wav
# Convert: data/Long_FinnedPilotWhale/77028008.wav
# Convert: data/Long_FinnedPilotWhale/77028009.wav
# Convert: data/Long_FinnedPilotWhale/7702800U.wav
# Convert: data/Long_FinnedPilotWhale/7702800V.wav
# Convert: data/Long_FinnedPilotWhale/7702800X.wav
# Convert: data/Long_FinnedPilotWhale/77028010.wav
# Convert: data/Long_FinnedPilotWhale/77028015.wav
# Convert: data/Long_FinnedPilotWhale/77028017.wav
# Convert: data/Long_FinnedPilotWhale/77028018.wav
# Convert: data/Long_FinnedPilotWhale/7702801D.wav
# Convert: data/Long_FinnedPilotWhale/7702801F.wav
# Convert: data/Long_FinnedPilotWhale/7702801K.wav
# Convert: data/Long_FinnedPilotWhale/7702801L.wav
# Convert: data/Long_FinnedPilotWhale/7702801M.wav
# Convert: data/Long_FinnedPilotWhale/77034002.wav
# Convert: data/Long_FinnedPilotWhale/77034006.wav
# Convert: data/Long_FinnedPilotWhale/77034008.wav
# Convert: data/Long_FinnedPilotWhale/77034009.wav
# Convert: data/Long_FinnedPilotWhale/7703400A.wav
# Convert: data/Long_FinnedPilotWhale/7703400B.wav
# Convert: data/Long_FinnedPilotWhale/7703400D.wav
# Convert: data/Long_FinnedPilotWhale/7703400H.wav
# Convert: data/Long_FinnedPilotWhale/7703400J.wav
# Convert: data/Long_FinnedPilotWhale/7703400K.wav
# Convert: data/Long_FinnedPilotWhale/7703400L.wav
# Convert: data/Long_FinnedPilotWhale/7703400M.wav
# Convert: data/Long_FinnedPilotWhale/7703400O.wav
# Convert: data/Long_FinnedPilotWhale/7703400P.wav
# Convert: data/Long_FinnedPilotWhale/7703400Q.wav
# Convert: data/Long_FinnedPilotWhale/7703400R.wav
# Convert: data/Long_FinnedPilotWhale/7703400S.wav
# Convert: data/Long_FinnedPilotWhale/7703400U.wav
# Convert: data/Long_FinnedPilotWhale/7703400V.wav
# Convert: data/MelonHeadedWhale/91012003.wav
# Convert: data/MelonHeadedWhale/91012006.wav
# Convert: data/MelonHeadedWhale/91012007.wav
# Convert: data/MelonHeadedWhale/9101200C.wav
# Convert: data/MelonHeadedWhale/9101200I.wav
# Convert: data/MelonHeadedWhale/9101200U.wav
# Convert: data/MelonHeadedWhale/91012016.wav
# Convert: data/MelonHeadedWhale/91012018.wav
# Convert: data/MelonHeadedWhale/9101201C.wav
# Convert: data/MelonHeadedWhale/9101201F.wav
# Convert: data/MelonHeadedWhale/9101201I.wav
# Convert: data/MelonHeadedWhale/9101201L.wav
# Convert: data/NorthernRightWhale/59005004.wav
# Convert: data/NorthernRightWhale/70014002.wav
# Convert: data/NorthernRightWhale/7001800B.wav
# Convert: data/NorthernRightWhale/7001800H.wav
# Convert: data/NorthernRightWhale/7001800T.wav
# Convert: data/NorthernRightWhale/7001800U.wav
# Convert: data/NorthernRightWhale/74003001.wav
# Convert: data/NorthernRightWhale/74003002.wav
# Convert: data/NorthernRightWhale/74003004.wav
# Convert: data/NorthernRightWhale/81013007.wav
# Convert: data/NorthernRightWhale/81014029.wav
# Convert: data/NorthernRightWhale/8101402F.wav
# Convert: data/NorthernRightWhale/8101402I.wav
# Convert: data/NorthernRightWhale/81014033.wav
# Convert: data/NorthernRightWhale/81014034.wav
# Convert: data/NorthernRightWhale/81014036.wav
# Convert: data/NorthernRightWhale/8101403B.wav
# Convert: data/NorthernRightWhale/8101403Z.wav
# Convert: data/NorthernRightWhale/81014040.wav
# Convert: data/NorthernRightWhale/81015002.wav
# Convert: data/NorthernRightWhale/81015005.wav
# Convert: data/PantropicalSpottedDolphin/64005009.wav
# Convert: data/PantropicalSpottedDolphin/6400500D.wav
# Convert: data/PantropicalSpottedDolphin/64005015.wav
# Convert: data/PantropicalSpottedDolphin/64005016.wav
# Convert: data/PantropicalSpottedDolphin/64005017.wav
# Convert: data/PantropicalSpottedDolphin/64005018.wav
# Convert: data/PantropicalSpottedDolphin/64005019.wav
# Convert: data/PantropicalSpottedDolphin/6400501A.wav
# Convert: data/PantropicalSpottedDolphin/6400501B.wav
# Convert: data/PantropicalSpottedDolphin/6400501C.wav
# Convert: data/PantropicalSpottedDolphin/6400501D.wav
# Convert: data/PantropicalSpottedDolphin/90028007.wav
# Convert: data/PantropicalSpottedDolphin/90028008.wav
# Convert: data/PantropicalSpottedDolphin/90028009.wav
# Convert: data/PantropicalSpottedDolphin/9002800A.wav
# Convert: data/PantropicalSpottedDolphin/9002800F.wav
# Convert: data/PantropicalSpottedDolphin/9004400O.wav
# Convert: data/PantropicalSpottedDolphin/9004400Y.wav
# Convert: data/PantropicalSpottedDolphin/9004401S.wav
# Convert: data/PantropicalSpottedDolphin/9004401T.wav
# Convert: data/PantropicalSpottedDolphin/9004401U.wav
# Convert: data/PantropicalSpottedDolphin/9004401V.wav
# Convert: data/PantropicalSpottedDolphin/9004401W.wav
# Convert: data/PantropicalSpottedDolphin/9004401X.wav
# Convert: data/PantropicalSpottedDolphin/9004401Y.wav
# Convert: data/PantropicalSpottedDolphin/9004401Z.wav
# Convert: data/PantropicalSpottedDolphin/90044021.wav
# Convert: data/PantropicalSpottedDolphin/93001008.wav
# Convert: data/PantropicalSpottedDolphin/9300100D.wav
# Convert: data/PantropicalSpottedDolphin/9300100H.wav
# Convert: data/PantropicalSpottedDolphin/94006003.wav
# Convert: data/PantropicalSpottedDolphin/94006004.wav
# Convert: data/PantropicalSpottedDolphin/94006005.wav
# Convert: data/PantropicalSpottedDolphin/94008006.wav
# Convert: data/PantropicalSpottedDolphin/94008008.wav
# Convert: data/PantropicalSpottedDolphin/9400800U.wav
# Convert: data/RossSeal/6608500Q.wav
# Convert: data/RossSeal/6608500R.wav
# Convert: data/RossSeal/6608500S.wav
# Convert: data/RossSeal/6608900A.wav
# Convert: data/RossSeal/6608900B.wav
# Convert: data/RossSeal/6608900C.wav
# Convert: data/RossSeal/6608900D.wav
# Convert: data/RossSeal/6608900E.wav
# Convert: data/RossSeal/6608900F.wav
# Convert: data/RossSeal/6608900G.wav
# Convert: data/RossSeal/6608900H.wav
# Convert: data/Rough_ToothedDolphin/85013002.wav
# Convert: data/Rough_ToothedDolphin/85013007.wav
# Convert: data/Rough_ToothedDolphin/85013009.wav
# Convert: data/Rough_ToothedDolphin/8501300A.wav
# Convert: data/Rough_ToothedDolphin/8501300D.wav
# Convert: data/Rough_ToothedDolphin/8501300E.wav
# Convert: data/Rough_ToothedDolphin/8501300H.wav
# Convert: data/Rough_ToothedDolphin/8501300I.wav
# Convert: data/Rough_ToothedDolphin/8501300J.wav
# Convert: data/Rough_ToothedDolphin/8501300K.wav
# Convert: data/Rough_ToothedDolphin/8501300L.wav
# Convert: data/Rough_ToothedDolphin/8501300M.wav
# Convert: data/Rough_ToothedDolphin/8501300N.wav
# Convert: data/Rough_ToothedDolphin/8501300P.wav
# Convert: data/Rough_ToothedDolphin/8501300R.wav
# Convert: data/Rough_ToothedDolphin/8501300S.wav
# Convert: data/Rough_ToothedDolphin/8501300T.wav
# Convert: data/Rough_ToothedDolphin/8501300X.wav
# Convert: data/Rough_ToothedDolphin/8501300Y.wav
# Convert: data/Rough_ToothedDolphin/85013010.wav
# Convert: data/Rough_ToothedDolphin/85013011.wav
# Convert: data/Rough_ToothedDolphin/85013014.wav
# Convert: data/Rough_ToothedDolphin/85013015.wav
# Convert: data/Rough_ToothedDolphin/85013019.wav
# Convert: data/Rough_ToothedDolphin/8501301A.wav
# Convert: data/Rough_ToothedDolphin/8501301C.wav
# Convert: data/Rough_ToothedDolphin/8501301D.wav
# Convert: data/Rough_ToothedDolphin/8501301F.wav
# Convert: data/Rough_ToothedDolphin/8501301H.wav
# Convert: data/Rough_ToothedDolphin/8501301J.wav
# Convert: data/Rough_ToothedDolphin/85014001.wav
# Convert: data/Rough_ToothedDolphin/85014003.wav
# Convert: data/Rough_ToothedDolphin/85014005.wav
# Convert: data/Rough_ToothedDolphin/85014006.wav
# Convert: data/Rough_ToothedDolphin/85014007.wav
# Convert: data/Rough_ToothedDolphin/8501400B.wav
# Convert: data/Rough_ToothedDolphin/8501400F.wav
# Convert: data/Rough_ToothedDolphin/8501400G.wav
# Convert: data/Rough_ToothedDolphin/8501400H.wav
# Convert: data/Rough_ToothedDolphin/8501400L.wav
# Convert: data/Rough_ToothedDolphin/8501400M.wav
# Convert: data/Rough_ToothedDolphin/8501400N.wav
# Convert: data/Rough_ToothedDolphin/8501400P.wav
# Convert: data/Rough_ToothedDolphin/8501400Q.wav
# Convert: data/Rough_ToothedDolphin/8501400R.wav
# Convert: data/Rough_ToothedDolphin/8501400S.wav
# Convert: data/Rough_ToothedDolphin/8501400T.wav
# Convert: data/Rough_ToothedDolphin/8501400U.wav
# Convert: data/Rough_ToothedDolphin/8501400V.wav
# Convert: data/Rough_ToothedDolphin/8501400Y.wav
# Convert: data/Short_Finned(Pacific)PilotWhale/57021001.wav
# Convert: data/Short_Finned(Pacific)PilotWhale/57021002.wav
# Convert: data/Short_Finned(Pacific)PilotWhale/57021004.wav
# Convert: data/Short_Finned(Pacific)PilotWhale/57021005.wav
# Convert: data/Short_Finned(Pacific)PilotWhale/57021007.wav
# Convert: data/Short_Finned(Pacific)PilotWhale/57021008.wav
# Convert: data/Short_Finned(Pacific)PilotWhale/57021009.wav
# Convert: data/Short_Finned(Pacific)PilotWhale/5702100A.wav
# Convert: data/Short_Finned(Pacific)PilotWhale/5702100B.wav
# Convert: data/Short_Finned(Pacific)PilotWhale/5702100C.wav
# Convert: data/Short_Finned(Pacific)PilotWhale/5702100D.wav
# Convert: data/Short_Finned(Pacific)PilotWhale/5702100E.wav
# Convert: data/Short_Finned(Pacific)PilotWhale/5702100F.wav
# Convert: data/Short_Finned(Pacific)PilotWhale/5702100G.wav
# ...
# Convert: data/SpermWhale/85005004.wav
# Convert: data/SpermWhale/85005005.wav
# Convert: data/SpermWhale/85005006.wav
# Convert: data/SpermWhale/87017001.wav
# Convert: data/SpermWhale/87017002.wav
# Convert: data/SpermWhale/87017003.wav
# Convert: data/SpermWhale/87017004.wav
# Convert: data/SpermWhale/8800201M.wav
# Convert: data/SpermWhale/8800201N.wav
# Convert: data/SpermWhale/90039006.wav
# Convert: data/SpermWhale/91003001.wav
# Convert: data/SpermWhale/91003002.wav
# Convert: data/SpermWhale/91003003.wav
# Convert: data/SpermWhale/91003005.wav
# Convert: data/SpermWhale/91012022.wav
# Convert: data/SpermWhale/91012048.wav
# Convert: data/SpermWhale/91012049.wav
# Convert: data/SpermWhale/93570006.wav
# Convert: data/SpermWhale/93570007.wav
# Convert: data/SpermWhale/93570008.wav
# Convert: data/SpermWhale/9357000A.wav
# Convert: data/SpermWhale/9357000B.wav
# Convert: data/SpermWhale/9357000C.wav
# Convert: data/SpermWhale/9357000E.wav
# Convert: data/SpermWhale/9357000J.wav
# Convert: data/SpermWhale/9357000P.wav
# Convert: data/SpermWhale/9357000R.wav
# Convert: data/SpermWhale/93570017.wav
# Convert: data/SpermWhale/9357001A.wav
# Convert: data/SpermWhale/94004004.wav
# Convert: data/SpermWhale/94004005.wav
# Convert: data/SpermWhale/9400400C.wav
# Convert: data/SpermWhale/9400500C.wav
# Convert: data/SpermWhale/9500100Q.wav
# Convert: data/SpinnerDolphin/7100100C.wav
# Convert: data/SpinnerDolphin/7100100N.wav
# Convert: data/SpinnerDolphin/7100100X.wav
# Convert: data/SpinnerDolphin/7100100Z.wav
# Convert: data/SpinnerDolphin/71001010.wav
# Convert: data/SpinnerDolphin/71001014.wav
# Convert: data/SpinnerDolphin/7100101A.wav
# Convert: data/SpinnerDolphin/7100101B.wav
# Convert: data/SpinnerDolphin/7100101I.wav
# Convert: data/StripedDolphin/5801100V.wav
# Convert: data/StripedDolphin/5801100W.wav
# Convert: data/StripedDolphin/5801100X.wav
# Convert: data/StripedDolphin/5801100Y.wav
# Convert: data/StripedDolphin/5801100Z.wav
# Convert: data/StripedDolphin/58011011.wav
# Convert: data/StripedDolphin/58011012.wav
# Convert: data/StripedDolphin/5801101I.wav
# Convert: data/StripedDolphin/5801101J.wav
# Convert: data/StripedDolphin/5801101K.wav
# Convert: data/StripedDolphin/5801101L.wav
# Convert: data/StripedDolphin/5801101M.wav
# Convert: data/StripedDolphin/5801101N.wav
# Convert: data/StripedDolphin/5801101O.wav
# Convert: data/StripedDolphin/72007035.wav
# Convert: data/StripedDolphin/72007036.wav
# Convert: data/StripedDolphin/72007037.wav
# Convert: data/StripedDolphin/72007038.wav
# Convert: data/StripedDolphin/72007039.wav
# Convert: data/StripedDolphin/7200703A.wav
# Convert: data/StripedDolphin/7200703B.wav
# Convert: data/StripedDolphin/7200703C.wav
# Convert: data/StripedDolphin/75003002.wav
# Convert: data/StripedDolphin/75003005.wav
# Convert: data/StripedDolphin/75003009.wav
# Convert: data/StripedDolphin/7500300H.wav
# Convert: data/StripedDolphin/7500300M.wav
# Convert: data/StripedDolphin/7500300P.wav
# Convert: data/StripedDolphin/7500300Q.wav
# Convert: data/StripedDolphin/7500300T.wav
# Convert: data/StripedDolphin/7500300V.wav
# Convert: data/StripedDolphin/7500300Z.wav
# Convert: data/StripedDolphin/75003010.wav
# Convert: data/StripedDolphin/75003011.wav
# Convert: data/StripedDolphin/75003014.wav
# Convert: data/StripedDolphin/75003015.wav
# Convert: data/StripedDolphin/75003016.wav
# Convert: data/StripedDolphin/75003019.wav
# Convert: data/StripedDolphin/7500301H.wav
# Convert: data/StripedDolphin/7500301N.wav
# Convert: data/StripedDolphin/7500301O.wav
# Convert: data/StripedDolphin/7500301P.wav
# Convert: data/StripedDolphin/7500301W.wav
# Convert: data/StripedDolphin/75003022.wav
# Convert: data/StripedDolphin/75003024.wav
# Convert: data/StripedDolphin/7500305Y.wav
# Convert: data/StripedDolphin/7500305Z.wav
# Convert: data/StripedDolphin/75003060.wav
# Convert: data/StripedDolphin/75003061.wav
# Convert: data/StripedDolphin/8500701A.wav
# Convert: data/StripedDolphin/8500701B.wav
# Convert: data/StripedDolphin/8500701C.wav
# Convert: data/StripedDolphin/8500701E.wav
# Convert: data/StripedDolphin/8500701F.wav
# Convert: data/StripedDolphin/8500701G.wav
# Convert: data/StripedDolphin/8500701H.wav
# Convert: data/StripedDolphin/8500701I.wav
# Convert: data/StripedDolphin/8500701J.wav
# Convert: data/StripedDolphin/8500701K.wav
# Convert: data/StripedDolphin/8500701L.wav
# Convert: data/StripedDolphin/85009011.wav
# Convert: data/Walrus/66006005.wav
# Convert: data/Walrus/72002001.wav
# Convert: data/Walrus/72002002.wav
# Convert: data/Walrus/72002003.wav
# Convert: data/Walrus/72002004.wav
# Convert: data/Walrus/72002008.wav
# Convert: data/Walrus/72002009.wav
# Convert: data/Walrus/7200200A.wav
# Convert: data/Walrus/7200200B.wav
# Convert: data/Walrus/7200200C.wav
# Convert: data/Walrus/7200200D.wav
# Convert: data/Walrus/7200200E.wav
# Convert: data/Walrus/7200200F.wav
# Convert: data/Walrus/7200200G.wav
# Convert: data/Walrus/7200200K.wav
# Convert: data/Walrus/7200200L.wav
# Convert: data/Walrus/7200200M.wav
# Convert: data/Walrus/72014001.wav
# Convert: data/Walrus/72014002.wav
# Convert: data/Walrus/72014003.wav
# Convert: data/Walrus/72014004.wav
# Convert: data/Walrus/72014005.wav
# Convert: data/Walrus/72014006.wav
# Convert: data/Walrus/72014007.wav
# Convert: data/Walrus/72014008.wav
# Convert: data/Walrus/72014009.wav
# Convert: data/Walrus/72019001.wav
# Convert: data/Walrus/72019002.wav
# Convert: data/Walrus/72019003.wav
# Convert: data/Walrus/72019004.wav
# Convert: data/Walrus/72019005.wav
# Convert: data/Walrus/72019007.wav
# Convert: data/Walrus/72019008.wav
# Convert: data/Walrus/72019009.wav
# Convert: data/Walrus/72020006.wav
# Convert: data/Walrus/72020008.wav
# Convert: data/Walrus/7202000A.wav
# Convert: data/Walrus/7202000B.wav
# Convert: data/White_beakedDolphin/59037001.wav
# Convert: data/White_beakedDolphin/59037005.wav
# Convert: data/White_beakedDolphin/59037006.wav
# Convert: data/White_beakedDolphin/59037007.wav
# Convert: data/White_beakedDolphin/59037008.wav
# Convert: data/White_beakedDolphin/5903700B.wav
# Convert: data/White_beakedDolphin/5903700F.wav
# Convert: data/White_beakedDolphin/5903700G.wav
# Convert: data/White_beakedDolphin/5903700J.wav
# Convert: data/White_beakedDolphin/5903700K.wav
# Convert: data/White_beakedDolphin/5903700L.wav
# Convert: data/White_beakedDolphin/5903700M.wav
# Convert: data/White_beakedDolphin/5903700N.wav
# Convert: data/White_beakedDolphin/5903700Q.wav
# Convert: data/White_beakedDolphin/5903700S.wav
# Convert: data/White_beakedDolphin/5903700Y.wav
# Convert: data/White_beakedDolphin/59037012.wav
# Convert: data/White_beakedDolphin/59037013.wav
# Convert: data/White_beakedDolphin/59037014.wav
# Convert: data/White_beakedDolphin/59037016.wav
# Convert: data/White_beakedDolphin/70005002.wav
# Convert: data/White_beakedDolphin/70006003.wav
# Convert: data/White_beakedDolphin/70006004.wav
# Convert: data/White_beakedDolphin/7001300B.wav
# Convert: data/White_beakedDolphin/7001300E.wav
# Convert: data/White_beakedDolphin/7001300G.wav
# Convert: data/White_beakedDolphin/7001400Q.wav
# Convert: data/White_beakedDolphin/7001400T.wav
# Convert: data/White_beakedDolphin/7001400V.wav
# Convert: data/White_beakedDolphin/7001400X.wav
# Convert: data/White_beakedDolphin/7001400Y.wav
# Convert: data/White_beakedDolphin/7001400Z.wav
# Convert: data/White_beakedDolphin/70014010.wav
# Convert: data/White_beakedDolphin/70014011.wav
# Convert: data/White_beakedDolphin/70014014.wav
# Convert: data/White_beakedDolphin/72005001.wav
# Convert: data/White_beakedDolphin/72005003.wav
# Convert: data/White_beakedDolphin/72005004.wav
# Convert: data/White_sidedDolphin/78007015.wav
# Convert: data/White_sidedDolphin/7800701J.wav
# Convert: data/White_sidedDolphin/78007038.wav
# Convert: data/White_sidedDolphin/7800703Q.wav
# Convert: data/White_sidedDolphin/79004007.wav
# Convert: data/White_sidedDolphin/79004016.wav
# Convert: data/White_sidedDolphin/79006014.wav
# Convert: data/White_sidedDolphin/79006015.wav
# Convert: data/White_sidedDolphin/79006016.wav
# Convert: data/White_sidedDolphin/79006017.wav
# Convert: data/White_sidedDolphin/79006018.wav
# Convert: data/White_sidedDolphin/79006019.wav

# %% [markdown]
# ## **Data Splitting**
#
# Next, the [split-folders](https://pypi.org/project/split-folders/) library was used to split folders with .wav files into train, validation and test (dataset) folders. The ratio we chose was 80% train, 10% validation, and 10% test because the dataset has a fairly small number of instances per class and many classes. We wanted to ensure that there would be a sufficient amount of data for training the model.

# %%
# !pip install split-folders
# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %% [markdown]
# Before splitting the files into train, validation, and test sets, we ensure that <u>all the long files (>30secs) are included in the train set</u> to prevent them from affecting the majority voting in the test set.

# %%
ensure_dir('data_split/train')

# %%
source_dir = 'data_22050'
destination_dir = 'data_split/train'

## Walk through all files in the source directory
for root, dirs, files in os.walk(source_dir):
    for file in files:
        if file.lower().endswith('.wav'):
            input_file = os.path.join(root, file)
            duration = get_wav_duration(input_file)
            relative_path = os.path.relpath(input_file, source_dir)
            output_file = os.path.join(destination_dir, relative_path)
            ensure_dir(os.path.dirname(output_file))
            if duration > 30:
                shutil.move(input_file, output_file)

# %%
import splitfolders

# Split the dataset into train, validation, and test sets
# Parameters:
# - "data": The path to the original dataset directory
# - output="data_split": The path where the split data will be saved
# - seed=1337: Seed for random number generator to ensure reproducibility
# - ratio=(.8, .1, .1): The split ratio for train, validation, and test sets
# - group_prefix=None: Option to keep files with the same prefix together, set to None as it's not needed here
# - move=True: Move files instead of coping them
splitfolders.ratio("data_22050", output="data_split", seed=1337, ratio=(.8, .1, .1), group_prefix=None, move=True)
# Out:
# Copying files: 1527 files [00:09, 159.73 files/s]

# %%
# Delete the empty folder data_22050
shutil.rmtree('data_22050')

# %% [markdown]
# ## **Extract Handcrafted Features**
#
# We used the pyAudioAnalysis library, specifically the `MidTermFeatures.directory_feature_extraction` function, to calculate the handcrafted features for all directories in each set: train, validation, and test. The results were saved in separate CSV files for each set in the `handcrafted_features` directory to make it easier to retrieve them later.

# %%
# !pip install eyed3
# !pip install pydub
# !pip install pyAudioAnalysis
# Out:
# Collecting eyed3
#   Downloading eyed3-0.9.7-py3-none-any.whl (246 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.1/246.1 kB 3.7 MB/s eta 0:00:00
# Collecting coverage[toml]<6.0.0,>=5.3.1 (from eyed3)
#   Downloading coverage-5.5-cp310-cp310-manylinux1_x86_64.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.0/239.0 kB 6.5 MB/s eta 0:00:00
# Collecting deprecation<3.0.0,>=2.1.0 (from eyed3)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting filetype<2.0.0,>=1.0.7 (from eyed3)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from coverage[toml]<6.0.0,>=5.3.1->eyed3) (0.10.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from deprecation<3.0.0,>=2.1.0->eyed3) (24.1)
# Installing collected packages: filetype, deprecation, coverage, eyed3
# Successfully installed coverage-5.5 deprecation-2.1.0 eyed3-0.9.7 filetype-1.2.0
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1
# Collecting pyAudioAnalysis
#   Downloading pyAudioAnalysis-0.3.14.tar.gz (41.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 MB 26.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pyAudioAnalysis
#   Building wheel for pyAudioAnalysis (setup.py) ... done
#   Created wheel for pyAudioAnalysis: filename=pyAudioAnalysis-0.3.14-py3-none-any.whl size=41264373 sha256=1b8f190fc0664724cddf16effb13c97b2112751b7edf6caacb761859f1a3fc40
#   Stored in directory: /root/.cache/pip/wheels/a7/54/73/fa830689c2440d2c81ff175c60e374930ad1607a8881e0f43f
# Successfully built pyAudioAnalysis
# Installing collected packages: pyAudioAnalysis
# Successfully installed pyAudioAnalysis-0.3.14

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
from pyAudioAnalysis import MidTermFeatures as aF

# %%
def create_csv_with_features(set_name):
    """
    Extracts audio features from directories of audio files and saves them to a CSV file.

    Args:
    set_name (str): The name of the dataset (subdirectory in 'data_split') to process.

    This function assumes the following directory structure:
    - data_split/
        - set_name/
            - class1/
            - class2/
            - ...

    For each class directory, the function extracts audio features using
    the directory_feature_extraction function and saves the results in a CSV file
    located in the 'handcrafted_features' directory.
    """

    set_dir = os.path.join("data_split", set_name)
    set_classes = os.listdir(set_dir)
    dirs = [os.path.join(set_dir, c) for c in set_classes]

    # Define parameters for feature extraction
    m_win, m_step, s_win, s_step = 1, 1, 0.1, 0.05

    features = []

    for d in dirs:
        # Extract feature matrix, file names, and feature names for the directory
        f, files, fn = aF.directory_feature_extraction(d, m_win, m_step, s_win, s_step)

        # Get the class name from the directory path
        class_name = os.path.basename(d)

        # Remove the directory path from file names
        files = [f.replace(d + '/', '') for f in files]

        # Extend feature list with class name and file name
        extended_f = [[class_name, b] + a.tolist() for a, b in zip(f, files)]
        features.extend(extended_f)

    col_names = ['class', 'file'] + fn
    features_df = pd.DataFrame(features, columns=col_names)

    # Save the DataFrame to a CSV file in the 'handcrafted_features' directory
    features_df.to_csv(os.path.join('handcrafted_features', f'{set_name}_features.csv'), sep='\t', header=True)

# %%
ensure_dir('handcrafted_features')

for set_name in ['train', 'val', 'test']:
  create_csv_with_features(set_name)
# Out:
# Analyzing file 1 of 46: data_split/train/AtlanticSpottedDolphin/61025001.wav
# Analyzing file 2 of 46: data_split/train/AtlanticSpottedDolphin/61025002.wav
# Analyzing file 3 of 46: data_split/train/AtlanticSpottedDolphin/61025003.wav
# Analyzing file 4 of 46: data_split/train/AtlanticSpottedDolphin/61025004.wav
# Analyzing file 5 of 46: data_split/train/AtlanticSpottedDolphin/61025006.wav
# Analyzing file 6 of 46: data_split/train/AtlanticSpottedDolphin/61025007.wav
# Analyzing file 7 of 46: data_split/train/AtlanticSpottedDolphin/61025008.wav
# Analyzing file 8 of 46: data_split/train/AtlanticSpottedDolphin/61025009.wav
# Analyzing file 9 of 46: data_split/train/AtlanticSpottedDolphin/6102500A.wav
# Analyzing file 10 of 46: data_split/train/AtlanticSpottedDolphin/6102500B.wav
# Analyzing file 11 of 46: data_split/train/AtlanticSpottedDolphin/6102500D.wav
# Analyzing file 12 of 46: data_split/train/AtlanticSpottedDolphin/6102500E.wav
# Analyzing file 13 of 46: data_split/train/AtlanticSpottedDolphin/6102500F.wav
# Analyzing file 14 of 46: data_split/train/AtlanticSpottedDolphin/6102500G.wav
# Analyzing file 15 of 46: data_split/train/AtlanticSpottedDolphin/6102500H.wav
# Analyzing file 16 of 46: data_split/train/AtlanticSpottedDolphin/6102500I.wav
# Analyzing file 17 of 46: data_split/train/AtlanticSpottedDolphin/6102500J.wav
# Analyzing file 18 of 46: data_split/train/AtlanticSpottedDolphin/6102500K.wav
# Analyzing file 19 of 46: data_split/train/AtlanticSpottedDolphin/6102500M.wav
# Analyzing file 20 of 46: data_split/train/AtlanticSpottedDolphin/6102500N.wav
# Analyzing file 21 of 46: data_split/train/AtlanticSpottedDolphin/6102500P.wav
# Analyzing file 22 of 46: data_split/train/AtlanticSpottedDolphin/6102500R.wav
# Analyzing file 23 of 46: data_split/train/AtlanticSpottedDolphin/61026002.wav
# Analyzing file 24 of 46: data_split/train/AtlanticSpottedDolphin/61026004.wav
# Analyzing file 25 of 46: data_split/train/AtlanticSpottedDolphin/6102600F.wav
# Analyzing file 26 of 46: data_split/train/AtlanticSpottedDolphin/6102600G.wav
# Analyzing file 27 of 46: data_split/train/AtlanticSpottedDolphin/6102601Y.wav
# Analyzing file 28 of 46: data_split/train/AtlanticSpottedDolphin/6102601Z.wav
# Analyzing file 29 of 46: data_split/train/AtlanticSpottedDolphin/61026020.wav
# Analyzing file 30 of 46: data_split/train/AtlanticSpottedDolphin/61026021.wav
# Analyzing file 31 of 46: data_split/train/AtlanticSpottedDolphin/6102602I.wav
# Analyzing file 32 of 46: data_split/train/AtlanticSpottedDolphin/6102602K.wav
# Analyzing file 33 of 46: data_split/train/AtlanticSpottedDolphin/6102602V.wav
# Analyzing file 34 of 46: data_split/train/AtlanticSpottedDolphin/61026036.wav
# Analyzing file 35 of 46: data_split/train/AtlanticSpottedDolphin/6102603A.wav
# Analyzing file 36 of 46: data_split/train/AtlanticSpottedDolphin/6102603C.wav
# Analyzing file 37 of 46: data_split/train/AtlanticSpottedDolphin/6102603E.wav
# Analyzing file 38 of 46: data_split/train/AtlanticSpottedDolphin/6102603L.wav
# Analyzing file 39 of 46: data_split/train/AtlanticSpottedDolphin/6102603O.wav
# Analyzing file 40 of 46: data_split/train/AtlanticSpottedDolphin/6102603S.wav
# Analyzing file 41 of 46: data_split/train/AtlanticSpottedDolphin/6102603V.wav
# Analyzing file 42 of 46: data_split/train/AtlanticSpottedDolphin/6102603W.wav
# Analyzing file 43 of 46: data_split/train/AtlanticSpottedDolphin/6102603X.wav
# Analyzing file 44 of 46: data_split/train/AtlanticSpottedDolphin/6102604J.wav
# Analyzing file 45 of 46: data_split/train/AtlanticSpottedDolphin/6102604K.wav
# Analyzing file 46 of 46: data_split/train/AtlanticSpottedDolphin/6102604L.wav
# Feature extraction complexity ratio: 15.2 x realtime
# Analyzing file 1 of 21: data_split/train/BeardedSeal/66038001.wav
# Analyzing file 2 of 21: data_split/train/BeardedSeal/66038002.wav
# Analyzing file 3 of 21: data_split/train/BeardedSeal/66038003.wav
# Analyzing file 4 of 21: data_split/train/BeardedSeal/66038004.wav
# Analyzing file 5 of 21: data_split/train/BeardedSeal/66038005.wav
# Analyzing file 6 of 21: data_split/train/BeardedSeal/66038007.wav
# Analyzing file 7 of 21: data_split/train/BeardedSeal/70025001.wav
# Analyzing file 8 of 21: data_split/train/BeardedSeal/70025002.wav
# Analyzing file 9 of 21: data_split/train/BeardedSeal/70025003.wav
# Analyzing file 10 of 21: data_split/train/BeardedSeal/70025004.wav
# Analyzing file 11 of 21: data_split/train/BeardedSeal/70025005.wav
# Analyzing file 12 of 21: data_split/train/BeardedSeal/70025007.wav
# Analyzing file 13 of 21: data_split/train/BeardedSeal/70025008.wav
# Analyzing file 14 of 21: data_split/train/BeardedSeal/70025009.wav
# Analyzing file 15 of 21: data_split/train/BeardedSeal/71012001.wav
# Analyzing file 16 of 21: data_split/train/BeardedSeal/71012002.wav
# Analyzing file 17 of 21: data_split/train/BeardedSeal/71012006.wav
# Analyzing file 18 of 21: data_split/train/BeardedSeal/71012009.wav
# Analyzing file 19 of 21: data_split/train/BeardedSeal/78018001.wav
# Analyzing file 20 of 21: data_split/train/BeardedSeal/78018005.wav
# Analyzing file 21 of 21: data_split/train/BeardedSeal/7801800M.wav
# Feature extraction complexity ratio: 15.3 x realtime
# Analyzing file 1 of 40: data_split/train/Beluga_WhiteWhale/62018001.wav
# Analyzing file 2 of 40: data_split/train/Beluga_WhiteWhale/62018002.wav
# Analyzing file 3 of 40: data_split/train/Beluga_WhiteWhale/62019001.wav
# Analyzing file 4 of 40: data_split/train/Beluga_WhiteWhale/62019007.wav
# Analyzing file 5 of 40: data_split/train/Beluga_WhiteWhale/6202200E.wav
# Analyzing file 6 of 40: data_split/train/Beluga_WhiteWhale/6202200F.wav
# Analyzing file 7 of 40: data_split/train/Beluga_WhiteWhale/6202200G.wav
# Analyzing file 8 of 40: data_split/train/Beluga_WhiteWhale/6202200P.wav
# Analyzing file 9 of 40: data_split/train/Beluga_WhiteWhale/6202200Q.wav
# Analyzing file 10 of 40: data_split/train/Beluga_WhiteWhale/6202200T.wav
# Analyzing file 11 of 40: data_split/train/Beluga_WhiteWhale/6202200Z.wav
# Analyzing file 12 of 40: data_split/train/Beluga_WhiteWhale/62022012.wav
# Analyzing file 13 of 40: data_split/train/Beluga_WhiteWhale/62022013.wav
# Analyzing file 14 of 40: data_split/train/Beluga_WhiteWhale/62022014.wav
# Analyzing file 15 of 40: data_split/train/Beluga_WhiteWhale/62022016.wav
# Analyzing file 16 of 40: data_split/train/Beluga_WhiteWhale/62022017.wav
# Analyzing file 17 of 40: data_split/train/Beluga_WhiteWhale/62022018.wav
# Analyzing file 18 of 40: data_split/train/Beluga_WhiteWhale/62026001.wav
# Analyzing file 19 of 40: data_split/train/Beluga_WhiteWhale/62026002.wav
# Analyzing file 20 of 40: data_split/train/Beluga_WhiteWhale/62026003.wav
# Analyzing file 21 of 40: data_split/train/Beluga_WhiteWhale/62026007.wav
# Analyzing file 22 of 40: data_split/train/Beluga_WhiteWhale/6202600B.wav
# Analyzing file 23 of 40: data_split/train/Beluga_WhiteWhale/6202600C.wav
# Analyzing file 24 of 40: data_split/train/Beluga_WhiteWhale/6202600D.wav
# Analyzing file 25 of 40: data_split/train/Beluga_WhiteWhale/63015001.wav
# Analyzing file 26 of 40: data_split/train/Beluga_WhiteWhale/63015002.wav
# Analyzing file 27 of 40: data_split/train/Beluga_WhiteWhale/63015003.wav
# Analyzing file 28 of 40: data_split/train/Beluga_WhiteWhale/63015004.wav
# Analyzing file 29 of 40: data_split/train/Beluga_WhiteWhale/63015005.wav
# Analyzing file 30 of 40: data_split/train/Beluga_WhiteWhale/63015006.wav
# Analyzing file 31 of 40: data_split/train/Beluga_WhiteWhale/65030009.wav
# Analyzing file 32 of 40: data_split/train/Beluga_WhiteWhale/6503000H.wav
# Analyzing file 33 of 40: data_split/train/Beluga_WhiteWhale/65033003.wav
# Analyzing file 34 of 40: data_split/train/Beluga_WhiteWhale/65033004.wav
# Analyzing file 35 of 40: data_split/train/Beluga_WhiteWhale/65033007.wav
# Analyzing file 36 of 40: data_split/train/Beluga_WhiteWhale/6503300C.wav
# Analyzing file 37 of 40: data_split/train/Beluga_WhiteWhale/6503300E.wav
# Analyzing file 38 of 40: data_split/train/Beluga_WhiteWhale/6503300H.wav
# Analyzing file 39 of 40: data_split/train/Beluga_WhiteWhale/6503300J.wav
# Analyzing file 40 of 40: data_split/train/Beluga_WhiteWhale/6503300K.wav
# Feature extraction complexity ratio: 15.4 x realtime
# Analyzing file 1 of 19: data_split/train/BottlenoseDolphin/51041C01.wav
# Analyzing file 2 of 19: data_split/train/BottlenoseDolphin/56006001.wav
# Analyzing file 3 of 19: data_split/train/BottlenoseDolphin/56006002.wav
# Analyzing file 4 of 19: data_split/train/BottlenoseDolphin/56006003.wav
# Analyzing file 5 of 19: data_split/train/BottlenoseDolphin/56006004.wav
# Analyzing file 6 of 19: data_split/train/BottlenoseDolphin/56006005.wav
# Analyzing file 7 of 19: data_split/train/BottlenoseDolphin/56006006.wav
# Analyzing file 8 of 19: data_split/train/BottlenoseDolphin/5600600A.wav
# Analyzing file 9 of 19: data_split/train/BottlenoseDolphin/5600600B.wav
# Analyzing file 10 of 19: data_split/train/BottlenoseDolphin/5600600D.wav
# Analyzing file 11 of 19: data_split/train/BottlenoseDolphin/5600600E.wav
# Analyzing file 12 of 19: data_split/train/BottlenoseDolphin/89514002.wav
# Analyzing file 13 of 19: data_split/train/BottlenoseDolphin/89514003.wav
# Analyzing file 14 of 19: data_split/train/BottlenoseDolphin/89514004.wav
# Analyzing file 15 of 19: data_split/train/BottlenoseDolphin/89514005.wav
# Analyzing file 16 of 19: data_split/train/BottlenoseDolphin/89514010.wav
# Analyzing file 17 of 19: data_split/train/BottlenoseDolphin/89514015.wav
# Analyzing file 18 of 19: data_split/train/BottlenoseDolphin/89514017.wav
# Analyzing file 19 of 19: data_split/train/BottlenoseDolphin/89514018.wav
# Feature extraction complexity ratio: 19.2 x realtime
# Analyzing file 1 of 40: data_split/train/BowheadWhale/7202100Q.wav
# Analyzing file 2 of 40: data_split/train/BowheadWhale/88006001.wav
# Analyzing file 3 of 40: data_split/train/BowheadWhale/88006003.wav
# Analyzing file 4 of 40: data_split/train/BowheadWhale/88006005.wav
# Analyzing file 5 of 40: data_split/train/BowheadWhale/88006006.wav
# Analyzing file 6 of 40: data_split/train/BowheadWhale/88006007.wav
# Analyzing file 7 of 40: data_split/train/BowheadWhale/88006008.wav
# Analyzing file 8 of 40: data_split/train/BowheadWhale/8800600A.wav
# Analyzing file 9 of 40: data_split/train/BowheadWhale/8800600C.wav
# Analyzing file 10 of 40: data_split/train/BowheadWhale/8800600D.wav
# Analyzing file 11 of 40: data_split/train/BowheadWhale/8800600F.wav
# Analyzing file 12 of 40: data_split/train/BowheadWhale/8800600G.wav
# Analyzing file 13 of 40: data_split/train/BowheadWhale/8800600H.wav
# Analyzing file 14 of 40: data_split/train/BowheadWhale/8800600I.wav
# Analyzing file 15 of 40: data_split/train/BowheadWhale/8800600J.wav
# Analyzing file 16 of 40: data_split/train/BowheadWhale/8800600K.wav
# Analyzing file 17 of 40: data_split/train/BowheadWhale/8800600L.wav
# Analyzing file 18 of 40: data_split/train/BowheadWhale/8800600N.wav
# Analyzing file 19 of 40: data_split/train/BowheadWhale/8800600O.wav
# Analyzing file 20 of 40: data_split/train/BowheadWhale/8800600P.wav
# Analyzing file 21 of 40: data_split/train/BowheadWhale/8800600R.wav
# Analyzing file 22 of 40: data_split/train/BowheadWhale/8800600U.wav
# Analyzing file 23 of 40: data_split/train/BowheadWhale/8800600W.wav
# Analyzing file 24 of 40: data_split/train/BowheadWhale/8800600Y.wav
# Analyzing file 25 of 40: data_split/train/BowheadWhale/8800600Z.wav
# Analyzing file 26 of 40: data_split/train/BowheadWhale/88006013.wav
# Analyzing file 27 of 40: data_split/train/BowheadWhale/88006016.wav
# Analyzing file 28 of 40: data_split/train/BowheadWhale/88006017.wav
# Analyzing file 29 of 40: data_split/train/BowheadWhale/8800601B.wav
# Analyzing file 30 of 40: data_split/train/BowheadWhale/8800601C.wav
# Analyzing file 31 of 40: data_split/train/BowheadWhale/8800601U.wav
# Analyzing file 32 of 40: data_split/train/BowheadWhale/8800602S.wav
# Analyzing file 33 of 40: data_split/train/BowheadWhale/8800602Z.wav
# Analyzing file 34 of 40: data_split/train/BowheadWhale/88006030.wav
# Analyzing file 35 of 40: data_split/train/BowheadWhale/88006031.wav
# Analyzing file 36 of 40: data_split/train/BowheadWhale/88006032.wav
# Analyzing file 37 of 40: data_split/train/BowheadWhale/88006034.wav
# Analyzing file 38 of 40: data_split/train/BowheadWhale/88006036.wav
# Analyzing file 39 of 40: data_split/train/BowheadWhale/88006037.wav
# Analyzing file 40 of 40: data_split/train/BowheadWhale/88006038.wav
# Feature extraction complexity ratio: 15.7 x realtime
# Analyzing file 1 of 50: data_split/train/ClymeneDolphin/83006001.wav
# Analyzing file 2 of 50: data_split/train/ClymeneDolphin/83006002.wav
# Analyzing file 3 of 50: data_split/train/ClymeneDolphin/83006003.wav
# Analyzing file 4 of 50: data_split/train/ClymeneDolphin/83006008.wav
# Analyzing file 5 of 50: data_split/train/ClymeneDolphin/83006009.wav
# Analyzing file 6 of 50: data_split/train/ClymeneDolphin/8300600A.wav
# Analyzing file 7 of 50: data_split/train/ClymeneDolphin/8300600B.wav
# Analyzing file 8 of 50: data_split/train/ClymeneDolphin/8300600C.wav
# Analyzing file 9 of 50: data_split/train/ClymeneDolphin/8300600D.wav
# Analyzing file 10 of 50: data_split/train/ClymeneDolphin/8300600E.wav
# Analyzing file 11 of 50: data_split/train/ClymeneDolphin/8300600N.wav
# Analyzing file 12 of 50: data_split/train/ClymeneDolphin/8300601F.wav
# Analyzing file 13 of 50: data_split/train/ClymeneDolphin/8300601G.wav
# Analyzing file 14 of 50: data_split/train/ClymeneDolphin/8300601J.wav
# Analyzing file 15 of 50: data_split/train/ClymeneDolphin/8300601K.wav
# Analyzing file 16 of 50: data_split/train/ClymeneDolphin/8300601R.wav
# Analyzing file 17 of 50: data_split/train/ClymeneDolphin/8300601V.wav
# Analyzing file 18 of 50: data_split/train/ClymeneDolphin/83006022.wav
# Analyzing file 19 of 50: data_split/train/ClymeneDolphin/8300602B.wav
# Analyzing file 20 of 50: data_split/train/ClymeneDolphin/8300602C.wav
# Analyzing file 21 of 50: data_split/train/ClymeneDolphin/8300602M.wav
# Analyzing file 22 of 50: data_split/train/ClymeneDolphin/83006031.wav
# Analyzing file 23 of 50: data_split/train/ClymeneDolphin/8300603C.wav
# Analyzing file 24 of 50: data_split/train/ClymeneDolphin/8300603S.wav
# Analyzing file 25 of 50: data_split/train/ClymeneDolphin/8300603U.wav
# Analyzing file 26 of 50: data_split/train/ClymeneDolphin/83006047.wav
# Analyzing file 27 of 50: data_split/train/ClymeneDolphin/8300604A.wav
# Analyzing file 28 of 50: data_split/train/ClymeneDolphin/8300604C.wav
# Analyzing file 29 of 50: data_split/train/ClymeneDolphin/8300604D.wav
# Analyzing file 30 of 50: data_split/train/ClymeneDolphin/8300604E.wav
# Analyzing file 31 of 50: data_split/train/ClymeneDolphin/8300604G.wav
# Analyzing file 32 of 50: data_split/train/ClymeneDolphin/8300604J.wav
# Analyzing file 33 of 50: data_split/train/ClymeneDolphin/8300604L.wav
# Analyzing file 34 of 50: data_split/train/ClymeneDolphin/8300604M.wav
# Analyzing file 35 of 50: data_split/train/ClymeneDolphin/8300604N.wav
# Analyzing file 36 of 50: data_split/train/ClymeneDolphin/8300604O.wav
# Analyzing file 37 of 50: data_split/train/ClymeneDolphin/8300604P.wav
# Analyzing file 38 of 50: data_split/train/ClymeneDolphin/8300604S.wav
# Analyzing file 39 of 50: data_split/train/ClymeneDolphin/8300604T.wav
# Analyzing file 40 of 50: data_split/train/ClymeneDolphin/83035002.wav
# Analyzing file 41 of 50: data_split/train/ClymeneDolphin/83035003.wav
# Analyzing file 42 of 50: data_split/train/ClymeneDolphin/83035007.wav
# Analyzing file 43 of 50: data_split/train/ClymeneDolphin/8303500N.wav
# Analyzing file 44 of 50: data_split/train/ClymeneDolphin/8303501L.wav
# Analyzing file 45 of 50: data_split/train/ClymeneDolphin/8303501W.wav
# Analyzing file 46 of 50: data_split/train/ClymeneDolphin/8303503N.wav
# Analyzing file 47 of 50: data_split/train/ClymeneDolphin/8303503O.wav
# Analyzing file 48 of 50: data_split/train/ClymeneDolphin/8303503Q.wav
# Analyzing file 49 of 50: data_split/train/ClymeneDolphin/8303503R.wav
# Analyzing file 50 of 50: data_split/train/ClymeneDolphin/8303503S.wav
# Feature extraction complexity ratio: 15.6 x realtime
# Analyzing file 1 of 42: data_split/train/CommonDolphin/5801400J.wav
# Analyzing file 2 of 42: data_split/train/CommonDolphin/58014014.wav
# Analyzing file 3 of 42: data_split/train/CommonDolphin/58014015.wav
# Analyzing file 4 of 42: data_split/train/CommonDolphin/58014028.wav
# Analyzing file 5 of 42: data_split/train/CommonDolphin/5801402C.wav
# Analyzing file 6 of 42: data_split/train/CommonDolphin/58014034.wav
# Analyzing file 7 of 42: data_split/train/CommonDolphin/58014036.wav
# Analyzing file 8 of 42: data_split/train/CommonDolphin/5801403O.wav
# Analyzing file 9 of 42: data_split/train/CommonDolphin/5801403R.wav
# Analyzing file 10 of 42: data_split/train/CommonDolphin/5801404D.wav
# Analyzing file 11 of 42: data_split/train/CommonDolphin/5801404R.wav
# Analyzing file 12 of 42: data_split/train/CommonDolphin/5801404S.wav
# Analyzing file 13 of 42: data_split/train/CommonDolphin/5801404T.wav
# Analyzing file 14 of 42: data_split/train/CommonDolphin/5801404U.wav
# Analyzing file 15 of 42: data_split/train/CommonDolphin/5801404V.wav
# Analyzing file 16 of 42: data_split/train/CommonDolphin/7500303M.wav
# Analyzing file 17 of 42: data_split/train/CommonDolphin/7500303N.wav
# Analyzing file 18 of 42: data_split/train/CommonDolphin/7500303Q.wav
# Analyzing file 19 of 42: data_split/train/CommonDolphin/7500303R.wav
# Analyzing file 20 of 42: data_split/train/CommonDolphin/7500303Y.wav
# Analyzing file 21 of 42: data_split/train/CommonDolphin/7500303Z.wav
# Analyzing file 22 of 42: data_split/train/CommonDolphin/75003041.wav
# Analyzing file 23 of 42: data_split/train/CommonDolphin/75003042.wav
# Analyzing file 24 of 42: data_split/train/CommonDolphin/75003044.wav
# Analyzing file 25 of 42: data_split/train/CommonDolphin/75003047.wav
# Analyzing file 26 of 42: data_split/train/CommonDolphin/7500304H.wav
# Analyzing file 27 of 42: data_split/train/CommonDolphin/7500304I.wav
# Analyzing file 28 of 42: data_split/train/CommonDolphin/7500304K.wav
# Analyzing file 29 of 42: data_split/train/CommonDolphin/7500304L.wav
# Analyzing file 30 of 42: data_split/train/CommonDolphin/7500304M.wav
# Analyzing file 31 of 42: data_split/train/CommonDolphin/7500304N.wav
# Analyzing file 32 of 42: data_split/train/CommonDolphin/7500304O.wav
# Analyzing file 33 of 42: data_split/train/CommonDolphin/7500304P.wav
# Analyzing file 34 of 42: data_split/train/CommonDolphin/7500304Q.wav
# Analyzing file 35 of 42: data_split/train/CommonDolphin/75003052.wav
# Analyzing file 36 of 42: data_split/train/CommonDolphin/75003057.wav
# Analyzing file 37 of 42: data_split/train/CommonDolphin/7500305C.wav
# Analyzing file 38 of 42: data_split/train/CommonDolphin/7500305D.wav
# Analyzing file 39 of 42: data_split/train/CommonDolphin/7500305H.wav
# Analyzing file 40 of 42: data_split/train/CommonDolphin/7500305I.wav
# Analyzing file 41 of 42: data_split/train/CommonDolphin/87003005.wav
# Analyzing file 42 of 42: data_split/train/CommonDolphin/87003006.wav
# Feature extraction complexity ratio: 15.0 x realtime
# Analyzing file 1 of 47: data_split/train/FalseKillerWhale/6102100P.wav
# Analyzing file 2 of 47: data_split/train/FalseKillerWhale/6102100Q.wav
# Analyzing file 3 of 47: data_split/train/FalseKillerWhale/6102100T.wav
# Analyzing file 4 of 47: data_split/train/FalseKillerWhale/6102100W.wav
# Analyzing file 5 of 47: data_split/train/FalseKillerWhale/6102100X.wav
# Analyzing file 6 of 47: data_split/train/FalseKillerWhale/6102100Y.wav
# Analyzing file 7 of 47: data_split/train/FalseKillerWhale/61021011.wav
# Analyzing file 8 of 47: data_split/train/FalseKillerWhale/61021012.wav
# Analyzing file 9 of 47: data_split/train/FalseKillerWhale/61021019.wav
# Analyzing file 10 of 47: data_split/train/FalseKillerWhale/6102101A.wav
# Analyzing file 11 of 47: data_split/train/FalseKillerWhale/6102101C.wav
# Analyzing file 12 of 47: data_split/train/FalseKillerWhale/6102101F.wav
# Analyzing file 13 of 47: data_split/train/FalseKillerWhale/6102101N.wav
# Analyzing file 14 of 47: data_split/train/FalseKillerWhale/6102101T.wav
# Analyzing file 15 of 47: data_split/train/FalseKillerWhale/6102101U.wav
# Analyzing file 16 of 47: data_split/train/FalseKillerWhale/61023001.wav
# Analyzing file 17 of 47: data_split/train/FalseKillerWhale/61023002.wav
# Analyzing file 18 of 47: data_split/train/FalseKillerWhale/61023005.wav
# Analyzing file 19 of 47: data_split/train/FalseKillerWhale/61023006.wav
# Analyzing file 20 of 47: data_split/train/FalseKillerWhale/61023008.wav
# Analyzing file 21 of 47: data_split/train/FalseKillerWhale/6102300A.wav
# Analyzing file 22 of 47: data_split/train/FalseKillerWhale/6102300F.wav
# Analyzing file 23 of 47: data_split/train/FalseKillerWhale/6102300H.wav
# Analyzing file 24 of 47: data_split/train/FalseKillerWhale/6102300I.wav
# Analyzing file 25 of 47: data_split/train/FalseKillerWhale/6102300J.wav
# Analyzing file 26 of 47: data_split/train/FalseKillerWhale/6102300P.wav
# Analyzing file 27 of 47: data_split/train/FalseKillerWhale/6102300R.wav
# Analyzing file 28 of 47: data_split/train/FalseKillerWhale/6102300S.wav
# Analyzing file 29 of 47: data_split/train/FalseKillerWhale/6102300U.wav
# Analyzing file 30 of 47: data_split/train/FalseKillerWhale/6102300V.wav
# Analyzing file 31 of 47: data_split/train/FalseKillerWhale/6102300X.wav
# Analyzing file 32 of 47: data_split/train/FalseKillerWhale/61023015.wav
# Analyzing file 33 of 47: data_split/train/FalseKillerWhale/61023019.wav
# Analyzing file 34 of 47: data_split/train/FalseKillerWhale/6102301A.wav
# Analyzing file 35 of 47: data_split/train/FalseKillerWhale/6102301B.wav
# Analyzing file 36 of 47: data_split/train/FalseKillerWhale/6102301D.wav
# Analyzing file 37 of 47: data_split/train/FalseKillerWhale/6102301J.wav
# Analyzing file 38 of 47: data_split/train/FalseKillerWhale/95003001.wav
# Analyzing file 39 of 47: data_split/train/FalseKillerWhale/95003003.wav
# Analyzing file 40 of 47: data_split/train/FalseKillerWhale/95003004.wav
# Analyzing file 41 of 47: data_split/train/FalseKillerWhale/95003005.wav
# Analyzing file 42 of 47: data_split/train/FalseKillerWhale/95003006.wav
# Analyzing file 43 of 47: data_split/train/FalseKillerWhale/95003007.wav
# Analyzing file 44 of 47: data_split/train/FalseKillerWhale/95003008.wav
# Analyzing file 45 of 47: data_split/train/FalseKillerWhale/95003009.wav
# Analyzing file 46 of 47: data_split/train/FalseKillerWhale/9500300A.wav
# Analyzing file 47 of 47: data_split/train/FalseKillerWhale/9500300B.wav
# Feature extraction complexity ratio: 16.8 x realtime
# Analyzing file 1 of 70: data_split/train/Fraser'sDolphin/91008005.wav
# Analyzing file 2 of 70: data_split/train/Fraser'sDolphin/91008008.wav
# Analyzing file 3 of 70: data_split/train/Fraser'sDolphin/91008009.wav
# Analyzing file 4 of 70: data_split/train/Fraser'sDolphin/9100800A.wav
# Analyzing file 5 of 70: data_split/train/Fraser'sDolphin/9100800B.wav
# Analyzing file 6 of 70: data_split/train/Fraser'sDolphin/9100800C.wav
# Analyzing file 7 of 70: data_split/train/Fraser'sDolphin/9100800D.wav
# Analyzing file 8 of 70: data_split/train/Fraser'sDolphin/9100800E.wav
# Analyzing file 9 of 70: data_split/train/Fraser'sDolphin/91010004.wav
# Analyzing file 10 of 70: data_split/train/Fraser'sDolphin/9101000F.wav
# Analyzing file 11 of 70: data_split/train/Fraser'sDolphin/9101000H.wav
# Analyzing file 12 of 70: data_split/train/Fraser'sDolphin/9101000K.wav
# Analyzing file 13 of 70: data_split/train/Fraser'sDolphin/9101000W.wav
# Analyzing file 14 of 70: data_split/train/Fraser'sDolphin/9101000X.wav
# Analyzing file 15 of 70: data_split/train/Fraser'sDolphin/9101000Y.wav
# Analyzing file 16 of 70: data_split/train/Fraser'sDolphin/9101000Z.wav
# Analyzing file 17 of 70: data_split/train/Fraser'sDolphin/91010010.wav
# Analyzing file 18 of 70: data_split/train/Fraser'sDolphin/91010014.wav
# Analyzing file 19 of 70: data_split/train/Fraser'sDolphin/91010019.wav
# Analyzing file 20 of 70: data_split/train/Fraser'sDolphin/9101001H.wav
# Analyzing file 21 of 70: data_split/train/Fraser'sDolphin/9101001L.wav
# Analyzing file 22 of 70: data_split/train/Fraser'sDolphin/9101001M.wav
# Analyzing file 23 of 70: data_split/train/Fraser'sDolphin/9101001O.wav
# Analyzing file 24 of 70: data_split/train/Fraser'sDolphin/9101001Q.wav
# Analyzing file 25 of 70: data_split/train/Fraser'sDolphin/9101001R.wav
# Analyzing file 26 of 70: data_split/train/Fraser'sDolphin/9101001S.wav
# Analyzing file 27 of 70: data_split/train/Fraser'sDolphin/9101001T.wav
# Analyzing file 28 of 70: data_split/train/Fraser'sDolphin/9101001U.wav
# Analyzing file 29 of 70: data_split/train/Fraser'sDolphin/9101001V.wav
# Analyzing file 30 of 70: data_split/train/Fraser'sDolphin/9101001W.wav
# Analyzing file 31 of 70: data_split/train/Fraser'sDolphin/9101001X.wav
# Analyzing file 32 of 70: data_split/train/Fraser'sDolphin/9101001Y.wav
# Analyzing file 33 of 70: data_split/train/Fraser'sDolphin/9101001Z.wav
# Analyzing file 34 of 70: data_split/train/Fraser'sDolphin/91010020.wav
# Analyzing file 35 of 70: data_split/train/Fraser'sDolphin/91010021.wav
# Analyzing file 36 of 70: data_split/train/Fraser'sDolphin/91010023.wav
# Analyzing file 37 of 70: data_split/train/Fraser'sDolphin/91010024.wav
# Analyzing file 38 of 70: data_split/train/Fraser'sDolphin/91010025.wav
# Analyzing file 39 of 70: data_split/train/Fraser'sDolphin/91010027.wav
# Analyzing file 40 of 70: data_split/train/Fraser'sDolphin/91010028.wav
# Analyzing file 41 of 70: data_split/train/Fraser'sDolphin/91010029.wav
# Analyzing file 42 of 70: data_split/train/Fraser'sDolphin/9101002A.wav
# Analyzing file 43 of 70: data_split/train/Fraser'sDolphin/9101002B.wav
# Analyzing file 44 of 70: data_split/train/Fraser'sDolphin/91013001.wav
# Analyzing file 45 of 70: data_split/train/Fraser'sDolphin/91013002.wav
# Analyzing file 46 of 70: data_split/train/Fraser'sDolphin/91013008.wav
# Analyzing file 47 of 70: data_split/train/Fraser'sDolphin/9101300A.wav
# Analyzing file 48 of 70: data_split/train/Fraser'sDolphin/9101300C.wav
# Analyzing file 49 of 70: data_split/train/Fraser'sDolphin/9101300D.wav
# Analyzing file 50 of 70: data_split/train/Fraser'sDolphin/9101300E.wav
# Analyzing file 51 of 70: data_split/train/Fraser'sDolphin/9101300F.wav
# Analyzing file 52 of 70: data_split/train/Fraser'sDolphin/9101300H.wav
# Analyzing file 53 of 70: data_split/train/Fraser'sDolphin/9101300I.wav
# Analyzing file 54 of 70: data_split/train/Fraser'sDolphin/9101300J.wav
# Analyzing file 55 of 70: data_split/train/Fraser'sDolphin/9101300K.wav
# Analyzing file 56 of 70: data_split/train/Fraser'sDolphin/9101300N.wav
# Analyzing file 57 of 70: data_split/train/Fraser'sDolphin/9101300U.wav
# Analyzing file 58 of 70: data_split/train/Fraser'sDolphin/9101300X.wav
# Analyzing file 59 of 70: data_split/train/Fraser'sDolphin/9101300Y.wav
# Analyzing file 60 of 70: data_split/train/Fraser'sDolphin/91013014.wav
# Analyzing file 61 of 70: data_split/train/Fraser'sDolphin/9101301A.wav
# Analyzing file 62 of 70: data_split/train/Fraser'sDolphin/9101301B.wav
# Analyzing file 63 of 70: data_split/train/Fraser'sDolphin/9101301C.wav
# Analyzing file 64 of 70: data_split/train/Fraser'sDolphin/9101301G.wav
# Analyzing file 65 of 70: data_split/train/Fraser'sDolphin/9101301H.wav
# Analyzing file 66 of 70: data_split/train/Fraser'sDolphin/9101301I.wav
# Analyzing file 67 of 70: data_split/train/Fraser'sDolphin/9101301K.wav
# Analyzing file 68 of 70: data_split/train/Fraser'sDolphin/9101301L.wav
# Analyzing file 69 of 70: data_split/train/Fraser'sDolphin/9101301M.wav
# Analyzing file 70 of 70: data_split/train/Fraser'sDolphin/9101301P.wav
# Feature extraction complexity ratio: 15.9 x realtime
# Analyzing file 1 of 54: data_split/train/Grampus_Risso'sDolphin/59029001.wav
# Analyzing file 2 of 54: data_split/train/Grampus_Risso'sDolphin/59029002.wav
# Analyzing file 3 of 54: data_split/train/Grampus_Risso'sDolphin/59029003.wav
# Analyzing file 4 of 54: data_split/train/Grampus_Risso'sDolphin/59029007.wav
# Analyzing file 5 of 54: data_split/train/Grampus_Risso'sDolphin/5902900A.wav
# Analyzing file 6 of 54: data_split/train/Grampus_Risso'sDolphin/5902900J.wav
# Analyzing file 7 of 54: data_split/train/Grampus_Risso'sDolphin/5902900M.wav
# Analyzing file 8 of 54: data_split/train/Grampus_Risso'sDolphin/5902900R.wav
# Analyzing file 9 of 54: data_split/train/Grampus_Risso'sDolphin/5902900S.wav
# Analyzing file 10 of 54: data_split/train/Grampus_Risso'sDolphin/5902900U.wav
# Analyzing file 11 of 54: data_split/train/Grampus_Risso'sDolphin/5902900W.wav
# Analyzing file 12 of 54: data_split/train/Grampus_Risso'sDolphin/5902900Y.wav
# Analyzing file 13 of 54: data_split/train/Grampus_Risso'sDolphin/5902900Z.wav
# Analyzing file 14 of 54: data_split/train/Grampus_Risso'sDolphin/59029014.wav
# Analyzing file 15 of 54: data_split/train/Grampus_Risso'sDolphin/59029016.wav
# Analyzing file 16 of 54: data_split/train/Grampus_Risso'sDolphin/59029017.wav
# Analyzing file 17 of 54: data_split/train/Grampus_Risso'sDolphin/59030001.wav
# Analyzing file 18 of 54: data_split/train/Grampus_Risso'sDolphin/59030003.wav
# Analyzing file 19 of 54: data_split/train/Grampus_Risso'sDolphin/59030005.wav
# Analyzing file 20 of 54: data_split/train/Grampus_Risso'sDolphin/5903000C.wav
# Analyzing file 21 of 54: data_split/train/Grampus_Risso'sDolphin/5903001Y.wav
# Analyzing file 22 of 54: data_split/train/Grampus_Risso'sDolphin/5903001Z.wav
# Analyzing file 23 of 54: data_split/train/Grampus_Risso'sDolphin/59030021.wav
# Analyzing file 24 of 54: data_split/train/Grampus_Risso'sDolphin/59030023.wav
# Analyzing file 25 of 54: data_split/train/Grampus_Risso'sDolphin/59030024.wav
# Analyzing file 26 of 54: data_split/train/Grampus_Risso'sDolphin/59030026.wav
# Analyzing file 27 of 54: data_split/train/Grampus_Risso'sDolphin/59030029.wav
# Analyzing file 28 of 54: data_split/train/Grampus_Risso'sDolphin/5903002D.wav
# Analyzing file 29 of 54: data_split/train/Grampus_Risso'sDolphin/5903002G.wav
# Analyzing file 30 of 54: data_split/train/Grampus_Risso'sDolphin/5903002N.wav
# Analyzing file 31 of 54: data_split/train/Grampus_Risso'sDolphin/5903002Q.wav
# Analyzing file 32 of 54: data_split/train/Grampus_Risso'sDolphin/5903002S.wav
# Analyzing file 33 of 54: data_split/train/Grampus_Risso'sDolphin/5903002T.wav
# Analyzing file 34 of 54: data_split/train/Grampus_Risso'sDolphin/5903002U.wav
# Analyzing file 35 of 54: data_split/train/Grampus_Risso'sDolphin/59030033.wav
# Analyzing file 36 of 54: data_split/train/Grampus_Risso'sDolphin/59030034.wav
# Analyzing file 37 of 54: data_split/train/Grampus_Risso'sDolphin/59030035.wav
# Analyzing file 38 of 54: data_split/train/Grampus_Risso'sDolphin/85009001.wav
# Analyzing file 39 of 54: data_split/train/Grampus_Risso'sDolphin/85009002.wav
# Analyzing file 40 of 54: data_split/train/Grampus_Risso'sDolphin/85009003.wav
# Analyzing file 41 of 54: data_split/train/Grampus_Risso'sDolphin/85009006.wav
# Analyzing file 42 of 54: data_split/train/Grampus_Risso'sDolphin/85009007.wav
# Analyzing file 43 of 54: data_split/train/Grampus_Risso'sDolphin/8500900A.wav
# Analyzing file 44 of 54: data_split/train/Grampus_Risso'sDolphin/8500900J.wav
# Analyzing file 45 of 54: data_split/train/Grampus_Risso'sDolphin/8500900L.wav
# Analyzing file 46 of 54: data_split/train/Grampus_Risso'sDolphin/8500900M.wav
# Analyzing file 47 of 54: data_split/train/Grampus_Risso'sDolphin/8500900N.wav
# Analyzing file 48 of 54: data_split/train/Grampus_Risso'sDolphin/8500900O.wav
# Analyzing file 49 of 54: data_split/train/Grampus_Risso'sDolphin/8500900P.wav
# Analyzing file 50 of 54: data_split/train/Grampus_Risso'sDolphin/8500900Q.wav
# Analyzing file 51 of 54: data_split/train/Grampus_Risso'sDolphin/8500900R.wav
# Analyzing file 52 of 54: data_split/train/Grampus_Risso'sDolphin/8500900S.wav
# Analyzing file 53 of 54: data_split/train/Grampus_Risso'sDolphin/8500900T.wav
# Analyzing file 54 of 54: data_split/train/Grampus_Risso'sDolphin/8700400E.wav
# Feature extraction complexity ratio: 15.4 x realtime
# Analyzing file 1 of 37: data_split/train/HarpSeal/67008008.wav
# Analyzing file 2 of 37: data_split/train/HarpSeal/67009001.wav
# Analyzing file 3 of 37: data_split/train/HarpSeal/67009002.wav
# Analyzing file 4 of 37: data_split/train/HarpSeal/67009003.wav
# Analyzing file 5 of 37: data_split/train/HarpSeal/67009004.wav
# Analyzing file 6 of 37: data_split/train/HarpSeal/67009005.wav
# Analyzing file 7 of 37: data_split/train/HarpSeal/67009006.wav
# Analyzing file 8 of 37: data_split/train/HarpSeal/67009007.wav
# Analyzing file 9 of 37: data_split/train/HarpSeal/67009008.wav
# Analyzing file 10 of 37: data_split/train/HarpSeal/67009009.wav
# Analyzing file 11 of 37: data_split/train/HarpSeal/6700900A.wav
# Analyzing file 12 of 37: data_split/train/HarpSeal/6700900D.wav
# Analyzing file 13 of 37: data_split/train/HarpSeal/6700900E.wav
# Analyzing file 14 of 37: data_split/train/HarpSeal/6700900F.wav
# Analyzing file 15 of 37: data_split/train/HarpSeal/6700900G.wav
# Analyzing file 16 of 37: data_split/train/HarpSeal/6700900H.wav
# Analyzing file 17 of 37: data_split/train/HarpSeal/6700900I.wav
# Analyzing file 18 of 37: data_split/train/HarpSeal/6700900J.wav
# Analyzing file 19 of 37: data_split/train/HarpSeal/6700900K.wav
# Analyzing file 20 of 37: data_split/train/HarpSeal/6700900M.wav
# Analyzing file 21 of 37: data_split/train/HarpSeal/6700900P.wav
# Analyzing file 22 of 37: data_split/train/HarpSeal/6700900S.wav
# Analyzing file 23 of 37: data_split/train/HarpSeal/6700900T.wav
# Analyzing file 24 of 37: data_split/train/HarpSeal/6700900U.wav
# Analyzing file 25 of 37: data_split/train/HarpSeal/6700900W.wav
# Analyzing file 26 of 37: data_split/train/HarpSeal/67010001.wav
# Analyzing file 27 of 37: data_split/train/HarpSeal/67010002.wav
# Analyzing file 28 of 37: data_split/train/HarpSeal/67010003.wav
# Analyzing file 29 of 37: data_split/train/HarpSeal/67010004.wav
# Analyzing file 30 of 37: data_split/train/HarpSeal/67010005.wav
# Analyzing file 31 of 37: data_split/train/HarpSeal/67010007.wav
# Analyzing file 32 of 37: data_split/train/HarpSeal/6701000A.wav
# Analyzing file 33 of 37: data_split/train/HarpSeal/6701000C.wav
# Analyzing file 34 of 37: data_split/train/HarpSeal/6701000D.wav
# Analyzing file 35 of 37: data_split/train/HarpSeal/6701000E.wav
# Analyzing file 36 of 37: data_split/train/HarpSeal/6701000G.wav
# Analyzing file 37 of 37: data_split/train/HarpSeal/6701000H.wav
# Feature extraction complexity ratio: 15.9 x realtime
# Analyzing file 1 of 53: data_split/train/HumpbackWhale/55113001.wav
# Analyzing file 2 of 53: data_split/train/HumpbackWhale/55113002.wav
# Analyzing file 3 of 53: data_split/train/HumpbackWhale/55113003.wav
# Analyzing file 4 of 53: data_split/train/HumpbackWhale/55113004.wav
# Analyzing file 5 of 53: data_split/train/HumpbackWhale/55113007.wav
# Analyzing file 6 of 53: data_split/train/HumpbackWhale/5511300F.wav
# Analyzing file 7 of 53: data_split/train/HumpbackWhale/63019001.wav
# Analyzing file 8 of 53: data_split/train/HumpbackWhale/63019002.wav
# Analyzing file 9 of 53: data_split/train/HumpbackWhale/63019003.wav
# Analyzing file 10 of 53: data_split/train/HumpbackWhale/63019004.wav
# Analyzing file 11 of 53: data_split/train/HumpbackWhale/63019005.wav
# Analyzing file 12 of 53: data_split/train/HumpbackWhale/6301900B.wav
# Analyzing file 13 of 53: data_split/train/HumpbackWhale/6301900C.wav
# Analyzing file 14 of 53: data_split/train/HumpbackWhale/6301900D.wav
# Analyzing file 15 of 53: data_split/train/HumpbackWhale/6301900T.wav
# Analyzing file 16 of 53: data_split/train/HumpbackWhale/6301900V.wav
# Analyzing file 17 of 53: data_split/train/HumpbackWhale/6301900W.wav
# Analyzing file 18 of 53: data_split/train/HumpbackWhale/6301900Y.wav
# Analyzing file 19 of 53: data_split/train/HumpbackWhale/6301900Z.wav
# Analyzing file 20 of 53: data_split/train/HumpbackWhale/63019010.wav
# Analyzing file 21 of 53: data_split/train/HumpbackWhale/63019011.wav
# Analyzing file 22 of 53: data_split/train/HumpbackWhale/63019012.wav
# Analyzing file 23 of 53: data_split/train/HumpbackWhale/63019016.wav
# Analyzing file 24 of 53: data_split/train/HumpbackWhale/63019017.wav
# Analyzing file 25 of 53: data_split/train/HumpbackWhale/63019018.wav
# Analyzing file 26 of 53: data_split/train/HumpbackWhale/63019019.wav
# Analyzing file 27 of 53: data_split/train/HumpbackWhale/6301901A.wav
# Analyzing file 28 of 53: data_split/train/HumpbackWhale/6301901D.wav
# Analyzing file 29 of 53: data_split/train/HumpbackWhale/6301901E.wav
# Analyzing file 30 of 53: data_split/train/HumpbackWhale/6301901H.wav
# Analyzing file 31 of 53: data_split/train/HumpbackWhale/6301901L.wav
# Analyzing file 32 of 53: data_split/train/HumpbackWhale/6301901M.wav
# Analyzing file 33 of 53: data_split/train/HumpbackWhale/6301901N.wav
# Analyzing file 34 of 53: data_split/train/HumpbackWhale/6301901T.wav
# Analyzing file 35 of 53: data_split/train/HumpbackWhale/6301901U.wav
# Analyzing file 36 of 53: data_split/train/HumpbackWhale/6301901V.wav
# Analyzing file 37 of 53: data_split/train/HumpbackWhale/6304300E.wav
# Analyzing file 38 of 53: data_split/train/HumpbackWhale/6304300F.wav
# Analyzing file 39 of 53: data_split/train/HumpbackWhale/6304300K.wav
# Analyzing file 40 of 53: data_split/train/HumpbackWhale/6304300M.wav
# Analyzing file 41 of 53: data_split/train/HumpbackWhale/6304300N.wav
# Analyzing file 42 of 53: data_split/train/HumpbackWhale/6304300O.wav
# Analyzing file 43 of 53: data_split/train/HumpbackWhale/92201001.wav
# Analyzing file 44 of 53: data_split/train/HumpbackWhale/92201005.wav
# Analyzing file 45 of 53: data_split/train/HumpbackWhale/9220100D.wav
# Analyzing file 46 of 53: data_split/train/HumpbackWhale/9220100E.wav
# Analyzing file 47 of 53: data_split/train/HumpbackWhale/9220100F.wav
# Analyzing file 48 of 53: data_split/train/HumpbackWhale/9220100G.wav
# Analyzing file 49 of 53: data_split/train/HumpbackWhale/9220100S.wav
# Analyzing file 50 of 53: data_split/train/HumpbackWhale/9220100V.wav
# Analyzing file 51 of 53: data_split/train/HumpbackWhale/9220100W.wav
# Analyzing file 52 of 53: data_split/train/HumpbackWhale/9220100X.wav
# Analyzing file 53 of 53: data_split/train/HumpbackWhale/9220100Z.wav
# Feature extraction complexity ratio: 16.6 x realtime
# Analyzing file 1 of 28: data_split/train/KillerWhale/60026001.wav
# Analyzing file 2 of 28: data_split/train/KillerWhale/60026002.wav
# Analyzing file 3 of 28: data_split/train/KillerWhale/60026003.wav
# Analyzing file 4 of 28: data_split/train/KillerWhale/60026004.wav
# Analyzing file 5 of 28: data_split/train/KillerWhale/60026005.wav
# Analyzing file 6 of 28: data_split/train/KillerWhale/60026006.wav
# Analyzing file 7 of 28: data_split/train/KillerWhale/6002600A.wav
# Analyzing file 8 of 28: data_split/train/KillerWhale/6002600B.wav
# Analyzing file 9 of 28: data_split/train/KillerWhale/64020001.wav
# Analyzing file 10 of 28: data_split/train/KillerWhale/64020003.wav
# Analyzing file 11 of 28: data_split/train/KillerWhale/9230000L.wav
# Analyzing file 12 of 28: data_split/train/KillerWhale/92301007.wav
# Analyzing file 13 of 28: data_split/train/KillerWhale/92304008.wav
# Analyzing file 14 of 28: data_split/train/KillerWhale/9230400D.wav
# Analyzing file 15 of 28: data_split/train/KillerWhale/9750000S.wav
# Analyzing file 16 of 28: data_split/train/KillerWhale/97501009.wav
# Analyzing file 17 of 28: data_split/train/KillerWhale/97503007.wav
# Analyzing file 18 of 28: data_split/train/KillerWhale/9750300I.wav
# Analyzing file 19 of 28: data_split/train/KillerWhale/9750300V.wav
# Analyzing file 20 of 28: data_split/train/KillerWhale/97503018.wav
# Analyzing file 21 of 28: data_split/train/KillerWhale/9750301M.wav
# Analyzing file 22 of 28: data_split/train/KillerWhale/9750301O.wav
# Analyzing file 23 of 28: data_split/train/KillerWhale/9750301Q.wav
# Analyzing file 24 of 28: data_split/train/KillerWhale/9750400C.wav
# Analyzing file 25 of 28: data_split/train/KillerWhale/9750400J.wav
# Analyzing file 26 of 28: data_split/train/KillerWhale/9750400V.wav
# Analyzing file 27 of 28: data_split/train/KillerWhale/9761900T.wav
# Analyzing file 28 of 28: data_split/train/KillerWhale/97619015.wav
# Feature extraction complexity ratio: 15.2 x realtime
# Analyzing file 1 of 57: data_split/train/Long_FinnedPilotWhale/54024001.wav
# Analyzing file 2 of 57: data_split/train/Long_FinnedPilotWhale/54024002.wav
# Analyzing file 3 of 57: data_split/train/Long_FinnedPilotWhale/54024003.wav
# Analyzing file 4 of 57: data_split/train/Long_FinnedPilotWhale/54024004.wav
# Analyzing file 5 of 57: data_split/train/Long_FinnedPilotWhale/54024005.wav
# Analyzing file 6 of 57: data_split/train/Long_FinnedPilotWhale/54024006.wav
# Analyzing file 7 of 57: data_split/train/Long_FinnedPilotWhale/54024007.wav
# Analyzing file 8 of 57: data_split/train/Long_FinnedPilotWhale/54024008.wav
# Analyzing file 9 of 57: data_split/train/Long_FinnedPilotWhale/54024009.wav
# Analyzing file 10 of 57: data_split/train/Long_FinnedPilotWhale/5402400A.wav
# Analyzing file 11 of 57: data_split/train/Long_FinnedPilotWhale/5402400B.wav
# Analyzing file 12 of 57: data_split/train/Long_FinnedPilotWhale/5402400C.wav
# Analyzing file 13 of 57: data_split/train/Long_FinnedPilotWhale/7500400U.wav
# Analyzing file 14 of 57: data_split/train/Long_FinnedPilotWhale/7500401F.wav
# Analyzing file 15 of 57: data_split/train/Long_FinnedPilotWhale/75004025.wav
# Analyzing file 16 of 57: data_split/train/Long_FinnedPilotWhale/7500402F.wav
# Analyzing file 17 of 57: data_split/train/Long_FinnedPilotWhale/7500402I.wav
# Analyzing file 18 of 57: data_split/train/Long_FinnedPilotWhale/7500402O.wav
# Analyzing file 19 of 57: data_split/train/Long_FinnedPilotWhale/75004033.wav
# Analyzing file 20 of 57: data_split/train/Long_FinnedPilotWhale/7500403A.wav
# Analyzing file 21 of 57: data_split/train/Long_FinnedPilotWhale/7500403J.wav
# Analyzing file 22 of 57: data_split/train/Long_FinnedPilotWhale/7500403N.wav
# Analyzing file 23 of 57: data_split/train/Long_FinnedPilotWhale/7500502J.wav
# Analyzing file 24 of 57: data_split/train/Long_FinnedPilotWhale/7500502Q.wav
# Analyzing file 25 of 57: data_split/train/Long_FinnedPilotWhale/7500502R.wav
# Analyzing file 26 of 57: data_split/train/Long_FinnedPilotWhale/7500502T.wav
# Analyzing file 27 of 57: data_split/train/Long_FinnedPilotWhale/7500502W.wav
# Analyzing file 28 of 57: data_split/train/Long_FinnedPilotWhale/7500502X.wav
# Analyzing file 29 of 57: data_split/train/Long_FinnedPilotWhale/7500502Z.wav
# Analyzing file 30 of 57: data_split/train/Long_FinnedPilotWhale/75005031.wav
# Analyzing file 31 of 57: data_split/train/Long_FinnedPilotWhale/75005032.wav
# Analyzing file 32 of 57: data_split/train/Long_FinnedPilotWhale/75005039.wav
# Analyzing file 33 of 57: data_split/train/Long_FinnedPilotWhale/7500503L.wav
# Analyzing file 34 of 57: data_split/train/Long_FinnedPilotWhale/77028008.wav
# Analyzing file 35 of 57: data_split/train/Long_FinnedPilotWhale/77028009.wav
# Analyzing file 36 of 57: data_split/train/Long_FinnedPilotWhale/7702800V.wav
# Analyzing file 37 of 57: data_split/train/Long_FinnedPilotWhale/77028015.wav
# Analyzing file 38 of 57: data_split/train/Long_FinnedPilotWhale/77028018.wav
# Analyzing file 39 of 57: data_split/train/Long_FinnedPilotWhale/7702801D.wav
# Analyzing file 40 of 57: data_split/train/Long_FinnedPilotWhale/7702801F.wav
# Analyzing file 41 of 57: data_split/train/Long_FinnedPilotWhale/7702801K.wav
# Analyzing file 42 of 57: data_split/train/Long_FinnedPilotWhale/7702801L.wav
# Analyzing file 43 of 57: data_split/train/Long_FinnedPilotWhale/77034006.wav
# Analyzing file 44 of 57: data_split/train/Long_FinnedPilotWhale/77034008.wav
# Analyzing file 45 of 57: data_split/train/Long_FinnedPilotWhale/7703400A.wav
# Analyzing file 46 of 57: data_split/train/Long_FinnedPilotWhale/7703400B.wav
# Analyzing file 47 of 57: data_split/train/Long_FinnedPilotWhale/7703400H.wav
# Analyzing file 48 of 57: data_split/train/Long_FinnedPilotWhale/7703400J.wav
# Analyzing file 49 of 57: data_split/train/Long_FinnedPilotWhale/7703400K.wav
# Analyzing file 50 of 57: data_split/train/Long_FinnedPilotWhale/7703400L.wav
# Analyzing file 51 of 57: data_split/train/Long_FinnedPilotWhale/7703400M.wav
# Analyzing file 52 of 57: data_split/train/Long_FinnedPilotWhale/7703400O.wav
# Analyzing file 53 of 57: data_split/train/Long_FinnedPilotWhale/7703400Q.wav
# Analyzing file 54 of 57: data_split/train/Long_FinnedPilotWhale/7703400R.wav
# Analyzing file 55 of 57: data_split/train/Long_FinnedPilotWhale/7703400S.wav
# Analyzing file 56 of 57: data_split/train/Long_FinnedPilotWhale/7703400U.wav
# Analyzing file 57 of 57: data_split/train/Long_FinnedPilotWhale/7703400V.wav
# Feature extraction complexity ratio: 15.5 x realtime
# Analyzing file 1 of 47: data_split/train/MelonHeadedWhale/91012003.wav
# Analyzing file 2 of 47: data_split/train/MelonHeadedWhale/91012006.wav
# Analyzing file 3 of 47: data_split/train/MelonHeadedWhale/91012007.wav
# Analyzing file 4 of 47: data_split/train/MelonHeadedWhale/9101200C.wav
# Analyzing file 5 of 47: data_split/train/MelonHeadedWhale/9101200I.wav
# Analyzing file 6 of 47: data_split/train/MelonHeadedWhale/9101200U.wav
# Analyzing file 7 of 47: data_split/train/MelonHeadedWhale/91012016.wav
# Analyzing file 8 of 47: data_split/train/MelonHeadedWhale/91012018.wav
# Analyzing file 9 of 47: data_split/train/MelonHeadedWhale/9101201C.wav
# Analyzing file 10 of 47: data_split/train/MelonHeadedWhale/9101201F.wav
# Analyzing file 11 of 47: data_split/train/MelonHeadedWhale/9101201L.wav
# Analyzing file 12 of 47: data_split/train/MelonHeadedWhale/9101201T.wav
# Analyzing file 13 of 47: data_split/train/MelonHeadedWhale/9101201Z.wav
# Analyzing file 14 of 47: data_split/train/MelonHeadedWhale/91012022.wav
# Analyzing file 15 of 47: data_split/train/MelonHeadedWhale/91012024.wav
# Analyzing file 16 of 47: data_split/train/MelonHeadedWhale/91012026.wav
# Analyzing file 17 of 47: data_split/train/MelonHeadedWhale/9101202B.wav
# Analyzing file 18 of 47: data_split/train/MelonHeadedWhale/9101202C.wav
# Analyzing file 19 of 47: data_split/train/MelonHeadedWhale/9101202E.wav
# Analyzing file 20 of 47: data_split/train/MelonHeadedWhale/9101202G.wav
# Analyzing file 21 of 47: data_split/train/MelonHeadedWhale/9101202S.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 22 of 47: data_split/train/MelonHeadedWhale/91012037.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 23 of 47: data_split/train/MelonHeadedWhale/91012039.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 24 of 47: data_split/train/MelonHeadedWhale/9101203D.wav
# Analyzing file 25 of 47: data_split/train/MelonHeadedWhale/9101203I.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 26 of 47: data_split/train/MelonHeadedWhale/9101203J.wav
# Analyzing file 27 of 47: data_split/train/MelonHeadedWhale/9101203N.wav
# Analyzing file 28 of 47: data_split/train/MelonHeadedWhale/9101203S.wav
# Analyzing file 29 of 47: data_split/train/MelonHeadedWhale/9101203U.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 30 of 47: data_split/train/MelonHeadedWhale/9101203V.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 31 of 47: data_split/train/MelonHeadedWhale/91012040.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 32 of 47: data_split/train/MelonHeadedWhale/91012043.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 33 of 47: data_split/train/MelonHeadedWhale/91012046.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 34 of 47: data_split/train/MelonHeadedWhale/91012047.wav
# Analyzing file 35 of 47: data_split/train/MelonHeadedWhale/91012048.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 36 of 47: data_split/train/MelonHeadedWhale/91012049.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 37 of 47: data_split/train/MelonHeadedWhale/9101204D.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 38 of 47: data_split/train/MelonHeadedWhale/9101204F.wav
# Analyzing file 39 of 47: data_split/train/MelonHeadedWhale/9101204I.wav
# Analyzing file 40 of 47: data_split/train/MelonHeadedWhale/9101204J.wav
# Analyzing file 41 of 47: data_split/train/MelonHeadedWhale/9101204K.wav
# Analyzing file 42 of 47: data_split/train/MelonHeadedWhale/9101204L.wav
# Analyzing file 43 of 47: data_split/train/MelonHeadedWhale/9101204M.wav
# Analyzing file 44 of 47: data_split/train/MelonHeadedWhale/9101204N.wav
# Analyzing file 45 of 47: data_split/train/MelonHeadedWhale/9101204O.wav
# Analyzing file 46 of 47: data_split/train/MelonHeadedWhale/9101204P.wav
# Analyzing file 47 of 47: data_split/train/MelonHeadedWhale/9101204Q.wav
# Feature extraction complexity ratio: 16.7 x realtime
# Analyzing file 1 of 40: data_split/train/Narwhal/68002006.wav
# Analyzing file 2 of 40: data_split/train/Narwhal/68002007.wav
# Analyzing file 3 of 40: data_split/train/Narwhal/68002008.wav
# Analyzing file 4 of 40: data_split/train/Narwhal/6800200A.wav
# ...
# Analyzing file 2 of 11: data_split/val/SpinnerDolphin/71001032.wav
# Analyzing file 3 of 11: data_split/val/SpinnerDolphin/71003004.wav
# Analyzing file 4 of 11: data_split/val/SpinnerDolphin/7100300G.wav
# Analyzing file 5 of 11: data_split/val/SpinnerDolphin/7100300H.wav
# Analyzing file 6 of 11: data_split/val/SpinnerDolphin/7100300K.wav
# Analyzing file 7 of 11: data_split/val/SpinnerDolphin/71008002.wav
# Analyzing file 8 of 11: data_split/val/SpinnerDolphin/7100800R.wav
# Analyzing file 9 of 11: data_split/val/SpinnerDolphin/7100801L.wav
# Analyzing file 10 of 11: data_split/val/SpinnerDolphin/7100901A.wav
# Analyzing file 11 of 11: data_split/val/SpinnerDolphin/7101001E.wav
# Feature extraction complexity ratio: 14.8 x realtime
# Analyzing file 1 of 8: data_split/val/StripedDolphin/5801100E.wav
# Analyzing file 2 of 8: data_split/val/StripedDolphin/5801100O.wav
# Analyzing file 3 of 8: data_split/val/StripedDolphin/58011012.wav
# Analyzing file 4 of 8: data_split/val/StripedDolphin/7200703A.wav
# Analyzing file 5 of 8: data_split/val/StripedDolphin/7500300V.wav
# Analyzing file 6 of 8: data_split/val/StripedDolphin/7500300Z.wav
# Analyzing file 7 of 8: data_split/val/StripedDolphin/75003014.wav
# Analyzing file 8 of 8: data_split/val/StripedDolphin/8500701E.wav
# Feature extraction complexity ratio: 18.2 x realtime
# Analyzing file 1 of 3: data_split/val/Walrus/7200200F.wav
# Analyzing file 2 of 3: data_split/val/Walrus/72014003.wav
# Analyzing file 3 of 3: data_split/val/Walrus/7202000A.wav
# Feature extraction complexity ratio: 19.3 x realtime
# Analyzing file 1 of 5: data_split/val/White_beakedDolphin/5903700L.wav
# Analyzing file 2 of 5: data_split/val/White_beakedDolphin/70006003.wav
# Analyzing file 3 of 5: data_split/val/White_beakedDolphin/7001300E.wav
# Analyzing file 4 of 5: data_split/val/White_beakedDolphin/72005008.wav
# Analyzing file 5 of 5: data_split/val/White_beakedDolphin/7200500V.wav
# Feature extraction complexity ratio: 11.4 x realtime
# Analyzing file 1 of 5: data_split/val/White_sidedDolphin/6107200S.wav
# Analyzing file 2 of 5: data_split/val/White_sidedDolphin/61072023.wav
# Analyzing file 3 of 5: data_split/val/White_sidedDolphin/6107202L.wav
# Analyzing file 4 of 5: data_split/val/White_sidedDolphin/7500103D.wav
# Analyzing file 5 of 5: data_split/val/White_sidedDolphin/79004007.wav
# Feature extraction complexity ratio: 13.6 x realtime
# Analyzing file 1 of 7: data_split/test/AtlanticSpottedDolphin/6102500Q.wav
# Analyzing file 2 of 7: data_split/test/AtlanticSpottedDolphin/6102602J.wav
# Analyzing file 3 of 7: data_split/test/AtlanticSpottedDolphin/6102602T.wav
# Analyzing file 4 of 7: data_split/test/AtlanticSpottedDolphin/6102602U.wav
# Analyzing file 5 of 7: data_split/test/AtlanticSpottedDolphin/6102602W.wav
# Analyzing file 6 of 7: data_split/test/AtlanticSpottedDolphin/6102603F.wav
# Analyzing file 7 of 7: data_split/test/AtlanticSpottedDolphin/6102603I.wav
# Feature extraction complexity ratio: 17.1 x realtime
# Analyzing file 1 of 4: data_split/test/BeardedSeal/70025006.wav
# Analyzing file 2 of 4: data_split/test/BeardedSeal/71012003.wav
# Analyzing file 3 of 4: data_split/test/BeardedSeal/71012005.wav
# Analyzing file 4 of 4: data_split/test/BeardedSeal/71012008.wav
# Feature extraction complexity ratio: 19.4 x realtime
# Analyzing file 1 of 5: data_split/test/Beluga_WhiteWhale/62026009.wav
# Analyzing file 2 of 5: data_split/test/Beluga_WhiteWhale/65030001.wav
# Analyzing file 3 of 5: data_split/test/Beluga_WhiteWhale/6503000F.wav
# Analyzing file 4 of 5: data_split/test/Beluga_WhiteWhale/6503000I.wav
# Analyzing file 5 of 5: data_split/test/Beluga_WhiteWhale/6503300D.wav
# Feature extraction complexity ratio: 16.2 x realtime
# Analyzing file 1 of 3: data_split/test/BottlenoseDolphin/89514001.wav
# Analyzing file 2 of 3: data_split/test/BottlenoseDolphin/89514011.wav
# Analyzing file 3 of 3: data_split/test/BottlenoseDolphin/89514013.wav
# Feature extraction complexity ratio: 11.1 x realtime
# Analyzing file 1 of 5: data_split/test/BowheadWhale/8800600S.wav
# Analyzing file 2 of 5: data_split/test/BowheadWhale/8800601L.wav
# Analyzing file 3 of 5: data_split/test/BowheadWhale/8800601Y.wav
# Analyzing file 4 of 5: data_split/test/BowheadWhale/8800602T.wav
# Analyzing file 5 of 5: data_split/test/BowheadWhale/88006033.wav
# Feature extraction complexity ratio: 14.6 x realtime
# Analyzing file 1 of 7: data_split/test/ClymeneDolphin/8300602Q.wav
# Analyzing file 2 of 7: data_split/test/ClymeneDolphin/8300604F.wav
# Analyzing file 3 of 7: data_split/test/ClymeneDolphin/8300604H.wav
# Analyzing file 4 of 7: data_split/test/ClymeneDolphin/8300604I.wav
# Analyzing file 5 of 7: data_split/test/ClymeneDolphin/8300604K.wav
# Analyzing file 6 of 7: data_split/test/ClymeneDolphin/8300604Q.wav
# Analyzing file 7 of 7: data_split/test/ClymeneDolphin/8303503P.wav
# Feature extraction complexity ratio: 17.9 x realtime
# Analyzing file 1 of 6: data_split/test/CommonDolphin/7500302U.wav
# Analyzing file 2 of 6: data_split/test/CommonDolphin/7500304F.wav
# Analyzing file 3 of 6: data_split/test/CommonDolphin/75003051.wav
# Analyzing file 4 of 6: data_split/test/CommonDolphin/75003053.wav
# Analyzing file 5 of 6: data_split/test/CommonDolphin/75003056.wav
# Analyzing file 6 of 6: data_split/test/CommonDolphin/75003058.wav
# Feature extraction complexity ratio: 19.9 x realtime
# Analyzing file 1 of 7: data_split/test/FalseKillerWhale/6102300C.wav
# Analyzing file 2 of 7: data_split/test/FalseKillerWhale/6102300W.wav
# Analyzing file 3 of 7: data_split/test/FalseKillerWhale/6102300Z.wav
# Analyzing file 4 of 7: data_split/test/FalseKillerWhale/61023010.wav
# Analyzing file 5 of 7: data_split/test/FalseKillerWhale/61023016.wav
# Analyzing file 6 of 7: data_split/test/FalseKillerWhale/6102301E.wav
# Analyzing file 7 of 7: data_split/test/FalseKillerWhale/6102301I.wav
# Feature extraction complexity ratio: 14.0 x realtime
# Analyzing file 1 of 9: data_split/test/Fraser'sDolphin/9101001D.wav
# Analyzing file 2 of 9: data_split/test/Fraser'sDolphin/91010026.wav
# Analyzing file 3 of 9: data_split/test/Fraser'sDolphin/9101002C.wav
# Analyzing file 4 of 9: data_split/test/Fraser'sDolphin/91013003.wav
# Analyzing file 5 of 9: data_split/test/Fraser'sDolphin/91013016.wav
# Analyzing file 6 of 9: data_split/test/Fraser'sDolphin/9101301E.wav
# Analyzing file 7 of 9: data_split/test/Fraser'sDolphin/9101301F.wav
# Analyzing file 8 of 9: data_split/test/Fraser'sDolphin/9101301N.wav
# Analyzing file 9 of 9: data_split/test/Fraser'sDolphin/9101301O.wav
# Feature extraction complexity ratio: 15.4 x realtime
# Analyzing file 1 of 7: data_split/test/Grampus_Risso'sDolphin/5903000A.wav
# Analyzing file 2 of 7: data_split/test/Grampus_Risso'sDolphin/5903000W.wav
# Analyzing file 3 of 7: data_split/test/Grampus_Risso'sDolphin/59030032.wav
# Analyzing file 4 of 7: data_split/test/Grampus_Risso'sDolphin/85009005.wav
# Analyzing file 5 of 7: data_split/test/Grampus_Risso'sDolphin/85009008.wav
# Analyzing file 6 of 7: data_split/test/Grampus_Risso'sDolphin/8500900I.wav
# Analyzing file 7 of 7: data_split/test/Grampus_Risso'sDolphin/8500900U.wav
# Feature extraction complexity ratio: 16.3 x realtime
# Analyzing file 1 of 6: data_split/test/HarpSeal/6700900B.wav
# Analyzing file 2 of 6: data_split/test/HarpSeal/6700900Q.wav
# Analyzing file 3 of 6: data_split/test/HarpSeal/67010006.wav
# Analyzing file 4 of 6: data_split/test/HarpSeal/67010008.wav
# Analyzing file 5 of 6: data_split/test/HarpSeal/67010009.wav
# Analyzing file 6 of 6: data_split/test/HarpSeal/6701000B.wav
# Feature extraction complexity ratio: 11.9 x realtime
# Analyzing file 1 of 6: data_split/test/HumpbackWhale/6301901B.wav
# Analyzing file 2 of 6: data_split/test/HumpbackWhale/8002001M.wav
# Analyzing file 3 of 6: data_split/test/HumpbackWhale/92201002.wav
# Analyzing file 4 of 6: data_split/test/HumpbackWhale/92201003.wav
# Analyzing file 5 of 6: data_split/test/HumpbackWhale/92201007.wav
# Analyzing file 6 of 6: data_split/test/HumpbackWhale/9220100Q.wav
# Feature extraction complexity ratio: 19.2 x realtime
# Analyzing file 1 of 4: data_split/test/KillerWhale/89405023.wav
# Analyzing file 2 of 4: data_split/test/KillerWhale/9750300Q.wav
# Analyzing file 3 of 4: data_split/test/KillerWhale/9750300Z.wav
# Analyzing file 4 of 4: data_split/test/KillerWhale/9769201Q.wav
# Feature extraction complexity ratio: 19.5 x realtime
# Analyzing file 1 of 7: data_split/test/Long_FinnedPilotWhale/7500502U.wav
# Analyzing file 2 of 7: data_split/test/Long_FinnedPilotWhale/7702800U.wav
# Analyzing file 3 of 7: data_split/test/Long_FinnedPilotWhale/7702800X.wav
# Analyzing file 4 of 7: data_split/test/Long_FinnedPilotWhale/77028010.wav
# Analyzing file 5 of 7: data_split/test/Long_FinnedPilotWhale/77028017.wav
# Analyzing file 6 of 7: data_split/test/Long_FinnedPilotWhale/7702801M.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 7 of 7: data_split/test/Long_FinnedPilotWhale/7703400P.wav
# Feature extraction complexity ratio: 15.8 x realtime
# Analyzing file 1 of 7: data_split/test/MelonHeadedWhale/9101202T.wav
# Analyzing file 2 of 7: data_split/test/MelonHeadedWhale/9101203X.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 3 of 7: data_split/test/MelonHeadedWhale/91012041.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 4 of 7: data_split/test/MelonHeadedWhale/91012042.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 5 of 7: data_split/test/MelonHeadedWhale/91012044.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 6 of 7: data_split/test/MelonHeadedWhale/9101204A.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 7 of 7: data_split/test/MelonHeadedWhale/9101204C.wav
# Feature extraction complexity ratio: 12.6 x realtime
# Analyzing file 1 of 5: data_split/test/Narwhal/7501400C.wav
# Analyzing file 2 of 5: data_split/test/Narwhal/7501400R.wav
# Analyzing file 3 of 5: data_split/test/Narwhal/7501400T.wav
# Analyzing file 4 of 5: data_split/test/Narwhal/7501400W.wav
# Analyzing file 5 of 5: data_split/test/Narwhal/75014012.wav
# Feature extraction complexity ratio: 19.0 x realtime
# Analyzing file 1 of 6: data_split/test/NorthernRightWhale/5900300A.wav
# Analyzing file 2 of 6: data_split/test/NorthernRightWhale/70014002.wav
# Analyzing file 3 of 6: data_split/test/NorthernRightWhale/7001800H.wav
# Analyzing file 4 of 6: data_split/test/NorthernRightWhale/7001800T.wav
# Analyzing file 5 of 6: data_split/test/NorthernRightWhale/74003001.wav
# Analyzing file 6 of 6: data_split/test/NorthernRightWhale/8101402I.wav
# Feature extraction complexity ratio: 18.2 x realtime
# Analyzing file 1 of 7: data_split/test/PantropicalSpottedDolphin/9004401X.wav
# Analyzing file 2 of 7: data_split/test/PantropicalSpottedDolphin/94008008.wav
# Analyzing file 3 of 7: data_split/test/PantropicalSpottedDolphin/9400800V.wav
# Analyzing file 4 of 7: data_split/test/PantropicalSpottedDolphin/9400800W.wav
# Analyzing file 5 of 7: data_split/test/PantropicalSpottedDolphin/94008011.wav
# Analyzing file 6 of 7: data_split/test/PantropicalSpottedDolphin/9400802D.wav
# Analyzing file 7 of 7: data_split/test/PantropicalSpottedDolphin/94008085.wav
# Feature extraction complexity ratio: 18.2 x realtime
# Analyzing file 1 of 5: data_split/test/RossSeal/6608500A.wav
# Analyzing file 2 of 5: data_split/test/RossSeal/6608500L.wav
# Analyzing file 3 of 5: data_split/test/RossSeal/6608500N.wav
# Analyzing file 4 of 5: data_split/test/RossSeal/6608500Q.wav
# Analyzing file 5 of 5: data_split/test/RossSeal/6608900D.wav
# Feature extraction complexity ratio: 13.2 x realtime
# Analyzing file 1 of 5: data_split/test/Rough_ToothedDolphin/85013019.wav
# Analyzing file 2 of 5: data_split/test/Rough_ToothedDolphin/85014007.wav
# Analyzing file 3 of 5: data_split/test/Rough_ToothedDolphin/8501400F.wav
# Analyzing file 4 of 5: data_split/test/Rough_ToothedDolphin/8501400L.wav
# Analyzing file 5 of 5: data_split/test/Rough_ToothedDolphin/8501400S.wav
# Feature extraction complexity ratio: 12.5 x realtime
# Analyzing file 1 of 6: data_split/test/Short_Finned(Pacific)PilotWhale/8103700B.wav
# Analyzing file 2 of 6: data_split/test/Short_Finned(Pacific)PilotWhale/91005006.wav
# Analyzing file 3 of 6: data_split/test/Short_Finned(Pacific)PilotWhale/9100500R.wav
# Analyzing file 4 of 6: data_split/test/Short_Finned(Pacific)PilotWhale/9100500S.wav
# Analyzing file 5 of 6: data_split/test/Short_Finned(Pacific)PilotWhale/91005010.wav
# Analyzing file 6 of 6: data_split/test/Short_Finned(Pacific)PilotWhale/9100501K.wav
# Feature extraction complexity ratio: 19.6 x realtime
# Analyzing file 1 of 3: data_split/test/SouthernRightWhale/79002013.wav
# Analyzing file 2 of 3: data_split/test/SouthernRightWhale/83002002.wav
# Analyzing file 3 of 3: data_split/test/SouthernRightWhale/8300200A.wav
# Feature extraction complexity ratio: 17.6 x realtime
# Analyzing file 1 of 6: data_split/test/SpermWhale/85004003.wav
# Analyzing file 2 of 6: data_split/test/SpermWhale/87017002.wav
# Analyzing file 3 of 6: data_split/test/SpermWhale/87017004.wav
# Analyzing file 4 of 6: data_split/test/SpermWhale/8800201M.wav
# Analyzing file 5 of 6: data_split/test/SpermWhale/91003001.wav
# Analyzing file 6 of 6: data_split/test/SpermWhale/91012049.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Feature extraction complexity ratio: 19.4 x realtime
# Analyzing file 1 of 12: data_split/test/SpinnerDolphin/7100102S.wav
# Analyzing file 2 of 12: data_split/test/SpinnerDolphin/71003007.wav
# Analyzing file 3 of 12: data_split/test/SpinnerDolphin/7100300B.wav
# Analyzing file 4 of 12: data_split/test/SpinnerDolphin/7100300E.wav
# Analyzing file 5 of 12: data_split/test/SpinnerDolphin/71004015.wav
# Analyzing file 6 of 12: data_split/test/SpinnerDolphin/7100401B.wav
# Analyzing file 7 of 12: data_split/test/SpinnerDolphin/7100401C.wav
# Analyzing file 8 of 12: data_split/test/SpinnerDolphin/7100401H.wav
# Analyzing file 9 of 12: data_split/test/SpinnerDolphin/7100700C.wav
# Analyzing file 10 of 12: data_split/test/SpinnerDolphin/7100800Z.wav
# Analyzing file 11 of 12: data_split/test/SpinnerDolphin/7100801G.wav
# Analyzing file 12 of 12: data_split/test/SpinnerDolphin/7100801M.wav
# Feature extraction complexity ratio: 13.1 x realtime
# Analyzing file 1 of 9: data_split/test/StripedDolphin/5801100W.wav
# Analyzing file 2 of 9: data_split/test/StripedDolphin/75003002.wav
# Analyzing file 3 of 9: data_split/test/StripedDolphin/7500300M.wav
# Analyzing file 4 of 9: data_split/test/StripedDolphin/7500300T.wav
# Analyzing file 5 of 9: data_split/test/StripedDolphin/75003061.wav
# Analyzing file 6 of 9: data_split/test/StripedDolphin/8500701F.wav
# Analyzing file 7 of 9: data_split/test/StripedDolphin/8500701G.wav
# Analyzing file 8 of 9: data_split/test/StripedDolphin/8500701K.wav
# Analyzing file 9 of 9: data_split/test/StripedDolphin/8500701L.wav
# Feature extraction complexity ratio: 18.9 x realtime
# Analyzing file 1 of 5: data_split/test/Walrus/7200200D.wav
# Analyzing file 2 of 5: data_split/test/Walrus/72014005.wav
# Analyzing file 3 of 5: data_split/test/Walrus/72014007.wav
# Analyzing file 4 of 5: data_split/test/Walrus/72014008.wav
# Analyzing file 5 of 5: data_split/test/Walrus/72020006.wav
# Feature extraction complexity ratio: 16.3 x realtime
# Analyzing file 1 of 7: data_split/test/White_beakedDolphin/7001300B.wav
# Analyzing file 2 of 7: data_split/test/White_beakedDolphin/70014014.wav
# Analyzing file 3 of 7: data_split/test/White_beakedDolphin/72005003.wav
# Analyzing file 4 of 7: data_split/test/White_beakedDolphin/72005004.wav
# Analyzing file 5 of 7: data_split/test/White_beakedDolphin/72005007.wav
# Analyzing file 6 of 7: data_split/test/White_beakedDolphin/7200500G.wav
# Analyzing file 7 of 7: data_split/test/White_beakedDolphin/7200500H.wav
# Feature extraction complexity ratio: 13.2 x realtime
# Analyzing file 1 of 6: data_split/test/White_sidedDolphin/6107202K.wav
# Analyzing file 2 of 6: data_split/test/White_sidedDolphin/75001021.wav
# Analyzing file 3 of 6: data_split/test/White_sidedDolphin/7500102H.wav
# Analyzing file 4 of 6: data_split/test/White_sidedDolphin/7500102I.wav
# Analyzing file 5 of 6: data_split/test/White_sidedDolphin/7500102S.wav
# Analyzing file 6 of 6: data_split/test/White_sidedDolphin/7800703Q.wav
# Feature extraction complexity ratio: 18.2 x realtime

# %% [markdown]
# ## **Extract and Save Spectrograms**
#
# The following code utilizes the [librosa](https://github.com/librosa/librosa) library to extract spectrograms and melgrams from audio files.

# %%
from utils.utilities import ensure_dir
from utils.spec_functions import create_pkl_with_spectrograms

# %%
ensure_dir('spectrograms')

# %%
for set_name in ['train', 'val', 'test']:
  create_pkl_with_spectrograms(set_name, 5.0) #1.0, 2.0 & 5.0
