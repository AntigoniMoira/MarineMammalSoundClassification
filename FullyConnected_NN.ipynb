# %% [markdown]
# # **Handcrafted Features & Fully Connected NN**
#
# The following code utilizes the [pyAudioAnalysis](https://github.com/tyiannak/pyAudioAnalysis) library to extract handcrafted features from audio data and train a fully convolutional neural network model.When applied to the test set, the model achieves an accuracy of 74% and an F1 (macro) score of 72.5%.

# %%
# Importing the drive module from google.colab library
from google.colab import drive

# Mounting the Google Drive to the Colab environment
drive.mount('/content/drive')

project_path = '/content/drive/My Drive/GitHub/MarineMammalSoundClassification/'
# %cd /content/drive/My Drive/GitHub/MarineMammalSoundClassification/
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/GitHub/MarineMammalSoundClassification

# %%
# !pip install eyed3
# !pip install pydub
# !pip install pyAudioAnalysis
# Out:
# Collecting eyed3
#   Downloading eyed3-0.9.7-py3-none-any.whl (246 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.1/246.1 kB 3.7 MB/s eta 0:00:00
# Collecting coverage[toml]<6.0.0,>=5.3.1 (from eyed3)
#   Downloading coverage-5.5-cp310-cp310-manylinux1_x86_64.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.0/239.0 kB 5.3 MB/s eta 0:00:00
# Collecting deprecation<3.0.0,>=2.1.0 (from eyed3)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting filetype<2.0.0,>=1.0.7 (from eyed3)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from coverage[toml]<6.0.0,>=5.3.1->eyed3) (0.10.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from deprecation<3.0.0,>=2.1.0->eyed3) (24.0)
# Installing collected packages: filetype, deprecation, coverage, eyed3
# Successfully installed coverage-5.5 deprecation-2.1.0 eyed3-0.9.7 filetype-1.2.0
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1

# %%
import warnings
warnings.filterwarnings("ignore")

import os
from pyAudioAnalysis import MidTermFeatures as aF
import pandas as pd
import numpy as np

# %% [markdown]
# ## **Extract Handcrafted Features**
#
# We used the pyAudioAnalysis library, specifically the `MidTermFeatures.directory_feature_extraction` function, to calculate the handcrafted features for all directories in each set: train, validation, and test. The results were saved in separate CSV files for each set in the `handcrafted_features` directory to make it easier to retrieve them later.

# %%
def create_csv_with_features(set_name):
    """
    Extracts audio features from directories of audio files and saves them to a CSV file.

    Args:
    set_name (str): The name of the dataset (subdirectory in 'data_split') to process.

    This function assumes the following directory structure:
    - data_split/
        - set_name/
            - class1/
            - class2/
            - ...

    For each class directory, the function extracts audio features using
    the directory_feature_extraction function and saves the results in a CSV file
    located in the 'handcrafted_features' directory.
    """

    set_dir = os.path.join("data_split", set_name)
    set_classes = os.listdir(set_dir)
    dirs = [os.path.join(set_dir, c) for c in set_classes]

    # Define parameters for feature extraction
    m_win, m_step, s_win, s_step = 1, 1, 0.1, 0.05

    features = []

    for d in dirs:
        # Extract feature matrix, file names, and feature names for the directory
        f, files, fn = aF.directory_feature_extraction(d, m_win, m_step, s_win, s_step)

        # Get the class name from the directory path
        class_name = os.path.basename(d)

        # Remove the directory path from file names
        files = [f.replace(d + '/', '') for f in files]

        # Extend feature list with class name and file name
        extended_f = [[class_name, b] + a.tolist() for a, b in zip(f, files)]
        features.extend(extended_f)

    col_names = ['class', 'file'] + fn
    features_df = pd.DataFrame(features, columns=col_names)

    # Save the DataFrame to a CSV file in the 'handcrafted_features' directory
    features_df.to_csv(os.path.join('handcrafted_features', f'{set_name}_features.csv'), sep='\t', header=True)

# %%
if not os.path.exists('handcrafted_features'):
   os.makedirs('handcrafted_features')

for set_name in ['train', 'val', 'test']:
  create_csv_with_features(set_name)
# Out:
# Analyzing file 1 of 46: data_split/train/AtlanticSpottedDolphin/61025001.wav
# Analyzing file 2 of 46: data_split/train/AtlanticSpottedDolphin/61025002.wav
# Analyzing file 3 of 46: data_split/train/AtlanticSpottedDolphin/61025003.wav
# Analyzing file 4 of 46: data_split/train/AtlanticSpottedDolphin/61025004.wav
# Analyzing file 5 of 46: data_split/train/AtlanticSpottedDolphin/61025006.wav
# Analyzing file 6 of 46: data_split/train/AtlanticSpottedDolphin/61025007.wav
# Analyzing file 7 of 46: data_split/train/AtlanticSpottedDolphin/61025008.wav
# Analyzing file 8 of 46: data_split/train/AtlanticSpottedDolphin/61025009.wav
# Analyzing file 9 of 46: data_split/train/AtlanticSpottedDolphin/6102500A.wav
# Analyzing file 10 of 46: data_split/train/AtlanticSpottedDolphin/6102500B.wav
# Analyzing file 11 of 46: data_split/train/AtlanticSpottedDolphin/6102500D.wav
# Analyzing file 12 of 46: data_split/train/AtlanticSpottedDolphin/6102500E.wav
# Analyzing file 13 of 46: data_split/train/AtlanticSpottedDolphin/6102500F.wav
# Analyzing file 14 of 46: data_split/train/AtlanticSpottedDolphin/6102500G.wav
# Analyzing file 15 of 46: data_split/train/AtlanticSpottedDolphin/6102500H.wav
# Analyzing file 16 of 46: data_split/train/AtlanticSpottedDolphin/6102500I.wav
# Analyzing file 17 of 46: data_split/train/AtlanticSpottedDolphin/6102500J.wav
# Analyzing file 18 of 46: data_split/train/AtlanticSpottedDolphin/6102500K.wav
# Analyzing file 19 of 46: data_split/train/AtlanticSpottedDolphin/6102500M.wav
# Analyzing file 20 of 46: data_split/train/AtlanticSpottedDolphin/6102500N.wav
# Analyzing file 21 of 46: data_split/train/AtlanticSpottedDolphin/6102500P.wav
# Analyzing file 22 of 46: data_split/train/AtlanticSpottedDolphin/61026001.wav
# Analyzing file 23 of 46: data_split/train/AtlanticSpottedDolphin/61026002.wav
# Analyzing file 24 of 46: data_split/train/AtlanticSpottedDolphin/61026004.wav
# Analyzing file 25 of 46: data_split/train/AtlanticSpottedDolphin/6102600F.wav
# Analyzing file 26 of 46: data_split/train/AtlanticSpottedDolphin/6102600G.wav
# Analyzing file 27 of 46: data_split/train/AtlanticSpottedDolphin/6102601Y.wav
# Analyzing file 28 of 46: data_split/train/AtlanticSpottedDolphin/6102601Z.wav
# Analyzing file 29 of 46: data_split/train/AtlanticSpottedDolphin/61026020.wav
# Analyzing file 30 of 46: data_split/train/AtlanticSpottedDolphin/61026021.wav
# Analyzing file 31 of 46: data_split/train/AtlanticSpottedDolphin/6102602J.wav
# Analyzing file 32 of 46: data_split/train/AtlanticSpottedDolphin/6102602U.wav
# Analyzing file 33 of 46: data_split/train/AtlanticSpottedDolphin/61026031.wav
# Analyzing file 34 of 46: data_split/train/AtlanticSpottedDolphin/61026036.wav
# Analyzing file 35 of 46: data_split/train/AtlanticSpottedDolphin/6102603A.wav
# Analyzing file 36 of 46: data_split/train/AtlanticSpottedDolphin/6102603C.wav
# Analyzing file 37 of 46: data_split/train/AtlanticSpottedDolphin/6102603I.wav
# Analyzing file 38 of 46: data_split/train/AtlanticSpottedDolphin/6102603L.wav
# Analyzing file 39 of 46: data_split/train/AtlanticSpottedDolphin/6102603S.wav
# Analyzing file 40 of 46: data_split/train/AtlanticSpottedDolphin/6102603V.wav
# Analyzing file 41 of 46: data_split/train/AtlanticSpottedDolphin/6102603W.wav
# Analyzing file 42 of 46: data_split/train/AtlanticSpottedDolphin/6102603X.wav
# Analyzing file 43 of 46: data_split/train/AtlanticSpottedDolphin/6102603Z.wav
# Analyzing file 44 of 46: data_split/train/AtlanticSpottedDolphin/6102604J.wav
# Analyzing file 45 of 46: data_split/train/AtlanticSpottedDolphin/6102604K.wav
# Analyzing file 46 of 46: data_split/train/AtlanticSpottedDolphin/6102604L.wav
# Feature extraction complexity ratio: 9.1 x realtime
# Analyzing file 1 of 29: data_split/train/BeardedSeal/66038001.wav
# Analyzing file 2 of 29: data_split/train/BeardedSeal/66038002.wav
# Analyzing file 3 of 29: data_split/train/BeardedSeal/66038003.wav
# Analyzing file 4 of 29: data_split/train/BeardedSeal/66038004.wav
# Analyzing file 5 of 29: data_split/train/BeardedSeal/66038005.wav
# Analyzing file 6 of 29: data_split/train/BeardedSeal/66038007.wav
# Analyzing file 7 of 29: data_split/train/BeardedSeal/70025001.wav
# Analyzing file 8 of 29: data_split/train/BeardedSeal/70025002.wav
# Analyzing file 9 of 29: data_split/train/BeardedSeal/70025003.wav
# Analyzing file 10 of 29: data_split/train/BeardedSeal/70025006.wav
# Analyzing file 11 of 29: data_split/train/BeardedSeal/70025007.wav
# Analyzing file 12 of 29: data_split/train/BeardedSeal/70025008.wav
# Analyzing file 13 of 29: data_split/train/BeardedSeal/70025009.wav
# Analyzing file 14 of 29: data_split/train/BeardedSeal/71012001.wav
# Analyzing file 15 of 29: data_split/train/BeardedSeal/71012002.wav
# Analyzing file 16 of 29: data_split/train/BeardedSeal/71012003.wav
# Analyzing file 17 of 29: data_split/train/BeardedSeal/71012004.wav
# Analyzing file 18 of 29: data_split/train/BeardedSeal/71012005.wav
# Analyzing file 19 of 29: data_split/train/BeardedSeal/71012006.wav
# Analyzing file 20 of 29: data_split/train/BeardedSeal/71012008.wav
# Analyzing file 21 of 29: data_split/train/BeardedSeal/7202100T.wav
# Analyzing file 22 of 29: data_split/train/BeardedSeal/7202100V.wav
# Analyzing file 23 of 29: data_split/train/BeardedSeal/7202100Z.wav
# Analyzing file 24 of 29: data_split/train/BeardedSeal/78018001.wav
# Analyzing file 25 of 29: data_split/train/BeardedSeal/78018003.wav
# Analyzing file 26 of 29: data_split/train/BeardedSeal/78018005.wav
# Analyzing file 27 of 29: data_split/train/BeardedSeal/7801800B.wav
# Analyzing file 28 of 29: data_split/train/BeardedSeal/7801800D.wav
# Analyzing file 29 of 29: data_split/train/BeardedSeal/7801800M.wav
# Feature extraction complexity ratio: 21.8 x realtime
# Analyzing file 1 of 40: data_split/train/Beluga_WhiteWhale/62018001.wav
# Analyzing file 2 of 40: data_split/train/Beluga_WhiteWhale/62018002.wav
# Analyzing file 3 of 40: data_split/train/Beluga_WhiteWhale/62019001.wav
# Analyzing file 4 of 40: data_split/train/Beluga_WhiteWhale/62019007.wav
# Analyzing file 5 of 40: data_split/train/Beluga_WhiteWhale/6202200E.wav
# Analyzing file 6 of 40: data_split/train/Beluga_WhiteWhale/6202200F.wav
# Analyzing file 7 of 40: data_split/train/Beluga_WhiteWhale/6202200G.wav
# Analyzing file 8 of 40: data_split/train/Beluga_WhiteWhale/6202200P.wav
# Analyzing file 9 of 40: data_split/train/Beluga_WhiteWhale/6202200Q.wav
# Analyzing file 10 of 40: data_split/train/Beluga_WhiteWhale/6202200T.wav
# Analyzing file 11 of 40: data_split/train/Beluga_WhiteWhale/6202200Z.wav
# Analyzing file 12 of 40: data_split/train/Beluga_WhiteWhale/62022012.wav
# Analyzing file 13 of 40: data_split/train/Beluga_WhiteWhale/62022013.wav
# Analyzing file 14 of 40: data_split/train/Beluga_WhiteWhale/62022014.wav
# Analyzing file 15 of 40: data_split/train/Beluga_WhiteWhale/62022016.wav
# Analyzing file 16 of 40: data_split/train/Beluga_WhiteWhale/62022017.wav
# Analyzing file 17 of 40: data_split/train/Beluga_WhiteWhale/62022018.wav
# Analyzing file 18 of 40: data_split/train/Beluga_WhiteWhale/62026001.wav
# Analyzing file 19 of 40: data_split/train/Beluga_WhiteWhale/62026002.wav
# Analyzing file 20 of 40: data_split/train/Beluga_WhiteWhale/62026003.wav
# Analyzing file 21 of 40: data_split/train/Beluga_WhiteWhale/62026007.wav
# Analyzing file 22 of 40: data_split/train/Beluga_WhiteWhale/6202600B.wav
# Analyzing file 23 of 40: data_split/train/Beluga_WhiteWhale/6202600C.wav
# Analyzing file 24 of 40: data_split/train/Beluga_WhiteWhale/6202600D.wav
# Analyzing file 25 of 40: data_split/train/Beluga_WhiteWhale/63015001.wav
# Analyzing file 26 of 40: data_split/train/Beluga_WhiteWhale/63015002.wav
# Analyzing file 27 of 40: data_split/train/Beluga_WhiteWhale/63015003.wav
# Analyzing file 28 of 40: data_split/train/Beluga_WhiteWhale/63015004.wav
# Analyzing file 29 of 40: data_split/train/Beluga_WhiteWhale/63015005.wav
# Analyzing file 30 of 40: data_split/train/Beluga_WhiteWhale/63015006.wav
# Analyzing file 31 of 40: data_split/train/Beluga_WhiteWhale/65030009.wav
# Analyzing file 32 of 40: data_split/train/Beluga_WhiteWhale/6503000H.wav
# Analyzing file 33 of 40: data_split/train/Beluga_WhiteWhale/65033003.wav
# Analyzing file 34 of 40: data_split/train/Beluga_WhiteWhale/65033004.wav
# Analyzing file 35 of 40: data_split/train/Beluga_WhiteWhale/65033007.wav
# Analyzing file 36 of 40: data_split/train/Beluga_WhiteWhale/6503300C.wav
# Analyzing file 37 of 40: data_split/train/Beluga_WhiteWhale/6503300E.wav
# Analyzing file 38 of 40: data_split/train/Beluga_WhiteWhale/6503300H.wav
# Analyzing file 39 of 40: data_split/train/Beluga_WhiteWhale/6503300J.wav
# Analyzing file 40 of 40: data_split/train/Beluga_WhiteWhale/6503300K.wav
# Feature extraction complexity ratio: 11.8 x realtime
# Analyzing file 1 of 19: data_split/train/BottlenoseDolphin/51041C01.wav
# Analyzing file 2 of 19: data_split/train/BottlenoseDolphin/56006001.wav
# Analyzing file 3 of 19: data_split/train/BottlenoseDolphin/56006002.wav
# Analyzing file 4 of 19: data_split/train/BottlenoseDolphin/56006003.wav
# Analyzing file 5 of 19: data_split/train/BottlenoseDolphin/56006004.wav
# Analyzing file 6 of 19: data_split/train/BottlenoseDolphin/56006005.wav
# Analyzing file 7 of 19: data_split/train/BottlenoseDolphin/56006006.wav
# Analyzing file 8 of 19: data_split/train/BottlenoseDolphin/5600600A.wav
# Analyzing file 9 of 19: data_split/train/BottlenoseDolphin/5600600B.wav
# Analyzing file 10 of 19: data_split/train/BottlenoseDolphin/5600600D.wav
# Analyzing file 11 of 19: data_split/train/BottlenoseDolphin/5600600E.wav
# Analyzing file 12 of 19: data_split/train/BottlenoseDolphin/89514002.wav
# Analyzing file 13 of 19: data_split/train/BottlenoseDolphin/89514003.wav
# Analyzing file 14 of 19: data_split/train/BottlenoseDolphin/89514004.wav
# Analyzing file 15 of 19: data_split/train/BottlenoseDolphin/89514005.wav
# Analyzing file 16 of 19: data_split/train/BottlenoseDolphin/89514010.wav
# Analyzing file 17 of 19: data_split/train/BottlenoseDolphin/89514015.wav
# Analyzing file 18 of 19: data_split/train/BottlenoseDolphin/89514017.wav
# Analyzing file 19 of 19: data_split/train/BottlenoseDolphin/89514018.wav
# Feature extraction complexity ratio: 8.8 x realtime
# Analyzing file 1 of 48: data_split/train/BowheadWhale/72021005.wav
# Analyzing file 2 of 48: data_split/train/BowheadWhale/7202100Q.wav
# Analyzing file 3 of 48: data_split/train/BowheadWhale/7202100T.wav
# Analyzing file 4 of 48: data_split/train/BowheadWhale/7202100V.wav
# Analyzing file 5 of 48: data_split/train/BowheadWhale/7202100Z.wav
# Analyzing file 6 of 48: data_split/train/BowheadWhale/78018002.wav
# Analyzing file 7 of 48: data_split/train/BowheadWhale/78018003.wav
# Analyzing file 8 of 48: data_split/train/BowheadWhale/7801800B.wav
# Analyzing file 9 of 48: data_split/train/BowheadWhale/7801800D.wav
# Analyzing file 10 of 48: data_split/train/BowheadWhale/7801800H.wav
# Analyzing file 11 of 48: data_split/train/BowheadWhale/88006001.wav
# Analyzing file 12 of 48: data_split/train/BowheadWhale/88006003.wav
# Analyzing file 13 of 48: data_split/train/BowheadWhale/88006005.wav
# Analyzing file 14 of 48: data_split/train/BowheadWhale/88006006.wav
# Analyzing file 15 of 48: data_split/train/BowheadWhale/88006007.wav
# Analyzing file 16 of 48: data_split/train/BowheadWhale/88006008.wav
# Analyzing file 17 of 48: data_split/train/BowheadWhale/8800600A.wav
# Analyzing file 18 of 48: data_split/train/BowheadWhale/8800600C.wav
# Analyzing file 19 of 48: data_split/train/BowheadWhale/8800600D.wav
# Analyzing file 20 of 48: data_split/train/BowheadWhale/8800600E.wav
# Analyzing file 21 of 48: data_split/train/BowheadWhale/8800600G.wav
# Analyzing file 22 of 48: data_split/train/BowheadWhale/8800600J.wav
# Analyzing file 23 of 48: data_split/train/BowheadWhale/8800600K.wav
# Analyzing file 24 of 48: data_split/train/BowheadWhale/8800600L.wav
# Analyzing file 25 of 48: data_split/train/BowheadWhale/8800600N.wav
# Analyzing file 26 of 48: data_split/train/BowheadWhale/8800600O.wav
# Analyzing file 27 of 48: data_split/train/BowheadWhale/8800600P.wav
# Analyzing file 28 of 48: data_split/train/BowheadWhale/8800600Q.wav
# Analyzing file 29 of 48: data_split/train/BowheadWhale/8800600R.wav
# Analyzing file 30 of 48: data_split/train/BowheadWhale/8800600S.wav
# Analyzing file 31 of 48: data_split/train/BowheadWhale/8800600U.wav
# Analyzing file 32 of 48: data_split/train/BowheadWhale/8800600Z.wav
# Analyzing file 33 of 48: data_split/train/BowheadWhale/88006017.wav
# Analyzing file 34 of 48: data_split/train/BowheadWhale/8800601B.wav
# Analyzing file 35 of 48: data_split/train/BowheadWhale/8800601C.wav
# Analyzing file 36 of 48: data_split/train/BowheadWhale/8800601L.wav
# Analyzing file 37 of 48: data_split/train/BowheadWhale/8800602Q.wav
# Analyzing file 38 of 48: data_split/train/BowheadWhale/8800602S.wav
# Analyzing file 39 of 48: data_split/train/BowheadWhale/8800602U.wav
# Analyzing file 40 of 48: data_split/train/BowheadWhale/8800602Z.wav
# Analyzing file 41 of 48: data_split/train/BowheadWhale/88006030.wav
# Analyzing file 42 of 48: data_split/train/BowheadWhale/88006031.wav
# Analyzing file 43 of 48: data_split/train/BowheadWhale/88006032.wav
# Analyzing file 44 of 48: data_split/train/BowheadWhale/88006033.wav
# Analyzing file 45 of 48: data_split/train/BowheadWhale/88006034.wav
# Analyzing file 46 of 48: data_split/train/BowheadWhale/88006036.wav
# Analyzing file 47 of 48: data_split/train/BowheadWhale/88006037.wav
# Analyzing file 48 of 48: data_split/train/BowheadWhale/88006038.wav
# Feature extraction complexity ratio: 22.5 x realtime
# Analyzing file 1 of 50: data_split/train/ClymeneDolphin/83006001.wav
# Analyzing file 2 of 50: data_split/train/ClymeneDolphin/83006002.wav
# Analyzing file 3 of 50: data_split/train/ClymeneDolphin/83006003.wav
# Analyzing file 4 of 50: data_split/train/ClymeneDolphin/83006008.wav
# Analyzing file 5 of 50: data_split/train/ClymeneDolphin/83006009.wav
# Analyzing file 6 of 50: data_split/train/ClymeneDolphin/8300600A.wav
# Analyzing file 7 of 50: data_split/train/ClymeneDolphin/8300600B.wav
# Analyzing file 8 of 50: data_split/train/ClymeneDolphin/8300600C.wav
# Analyzing file 9 of 50: data_split/train/ClymeneDolphin/8300600D.wav
# Analyzing file 10 of 50: data_split/train/ClymeneDolphin/8300600E.wav
# Analyzing file 11 of 50: data_split/train/ClymeneDolphin/8300600N.wav
# Analyzing file 12 of 50: data_split/train/ClymeneDolphin/8300601F.wav
# Analyzing file 13 of 50: data_split/train/ClymeneDolphin/8300601G.wav
# Analyzing file 14 of 50: data_split/train/ClymeneDolphin/8300601J.wav
# Analyzing file 15 of 50: data_split/train/ClymeneDolphin/8300601K.wav
# Analyzing file 16 of 50: data_split/train/ClymeneDolphin/8300601R.wav
# Analyzing file 17 of 50: data_split/train/ClymeneDolphin/8300601V.wav
# Analyzing file 18 of 50: data_split/train/ClymeneDolphin/83006022.wav
# Analyzing file 19 of 50: data_split/train/ClymeneDolphin/8300602B.wav
# Analyzing file 20 of 50: data_split/train/ClymeneDolphin/8300602C.wav
# Analyzing file 21 of 50: data_split/train/ClymeneDolphin/8300602M.wav
# Analyzing file 22 of 50: data_split/train/ClymeneDolphin/83006031.wav
# Analyzing file 23 of 50: data_split/train/ClymeneDolphin/8300603C.wav
# Analyzing file 24 of 50: data_split/train/ClymeneDolphin/8300603S.wav
# Analyzing file 25 of 50: data_split/train/ClymeneDolphin/8300603U.wav
# Analyzing file 26 of 50: data_split/train/ClymeneDolphin/83006047.wav
# Analyzing file 27 of 50: data_split/train/ClymeneDolphin/8300604A.wav
# Analyzing file 28 of 50: data_split/train/ClymeneDolphin/8300604C.wav
# Analyzing file 29 of 50: data_split/train/ClymeneDolphin/8300604D.wav
# Analyzing file 30 of 50: data_split/train/ClymeneDolphin/8300604E.wav
# Analyzing file 31 of 50: data_split/train/ClymeneDolphin/8300604G.wav
# Analyzing file 32 of 50: data_split/train/ClymeneDolphin/8300604J.wav
# Analyzing file 33 of 50: data_split/train/ClymeneDolphin/8300604L.wav
# Analyzing file 34 of 50: data_split/train/ClymeneDolphin/8300604M.wav
# Analyzing file 35 of 50: data_split/train/ClymeneDolphin/8300604N.wav
# Analyzing file 36 of 50: data_split/train/ClymeneDolphin/8300604O.wav
# Analyzing file 37 of 50: data_split/train/ClymeneDolphin/8300604P.wav
# Analyzing file 38 of 50: data_split/train/ClymeneDolphin/8300604S.wav
# Analyzing file 39 of 50: data_split/train/ClymeneDolphin/8300604T.wav
# Analyzing file 40 of 50: data_split/train/ClymeneDolphin/83035002.wav
# Analyzing file 41 of 50: data_split/train/ClymeneDolphin/83035003.wav
# Analyzing file 42 of 50: data_split/train/ClymeneDolphin/83035007.wav
# Analyzing file 43 of 50: data_split/train/ClymeneDolphin/8303500N.wav
# Analyzing file 44 of 50: data_split/train/ClymeneDolphin/8303501L.wav
# Analyzing file 45 of 50: data_split/train/ClymeneDolphin/8303501W.wav
# Analyzing file 46 of 50: data_split/train/ClymeneDolphin/8303503N.wav
# Analyzing file 47 of 50: data_split/train/ClymeneDolphin/8303503O.wav
# Analyzing file 48 of 50: data_split/train/ClymeneDolphin/8303503Q.wav
# Analyzing file 49 of 50: data_split/train/ClymeneDolphin/8303503R.wav
# Analyzing file 50 of 50: data_split/train/ClymeneDolphin/8303503S.wav
# Feature extraction complexity ratio: 6.1 x realtime
# Analyzing file 1 of 41: data_split/train/CommonDolphin/5801400J.wav
# Analyzing file 2 of 41: data_split/train/CommonDolphin/58014014.wav
# Analyzing file 3 of 41: data_split/train/CommonDolphin/58014015.wav
# Analyzing file 4 of 41: data_split/train/CommonDolphin/58014028.wav
# Analyzing file 5 of 41: data_split/train/CommonDolphin/5801402C.wav
# Analyzing file 6 of 41: data_split/train/CommonDolphin/58014034.wav
# Analyzing file 7 of 41: data_split/train/CommonDolphin/58014036.wav
# Analyzing file 8 of 41: data_split/train/CommonDolphin/5801403O.wav
# Analyzing file 9 of 41: data_split/train/CommonDolphin/5801403R.wav
# Analyzing file 10 of 41: data_split/train/CommonDolphin/5801404D.wav
# Analyzing file 11 of 41: data_split/train/CommonDolphin/5801404S.wav
# Analyzing file 12 of 41: data_split/train/CommonDolphin/5801404T.wav
# Analyzing file 13 of 41: data_split/train/CommonDolphin/5801404U.wav
# Analyzing file 14 of 41: data_split/train/CommonDolphin/5801404V.wav
# Analyzing file 15 of 41: data_split/train/CommonDolphin/7500302U.wav
# Analyzing file 16 of 41: data_split/train/CommonDolphin/7500303M.wav
# Analyzing file 17 of 41: data_split/train/CommonDolphin/7500303N.wav
# Analyzing file 18 of 41: data_split/train/CommonDolphin/7500303Q.wav
# Analyzing file 19 of 41: data_split/train/CommonDolphin/7500303R.wav
# Analyzing file 20 of 41: data_split/train/CommonDolphin/7500303Y.wav
# Analyzing file 21 of 41: data_split/train/CommonDolphin/75003041.wav
# Analyzing file 22 of 41: data_split/train/CommonDolphin/75003044.wav
# Analyzing file 23 of 41: data_split/train/CommonDolphin/75003045.wav
# Analyzing file 24 of 41: data_split/train/CommonDolphin/75003047.wav
# Analyzing file 25 of 41: data_split/train/CommonDolphin/7500304F.wav
# Analyzing file 26 of 41: data_split/train/CommonDolphin/7500304G.wav
# Analyzing file 27 of 41: data_split/train/CommonDolphin/7500304H.wav
# Analyzing file 28 of 41: data_split/train/CommonDolphin/7500304I.wav
# Analyzing file 29 of 41: data_split/train/CommonDolphin/7500304K.wav
# Analyzing file 30 of 41: data_split/train/CommonDolphin/7500304L.wav
# Analyzing file 31 of 41: data_split/train/CommonDolphin/7500304N.wav
# Analyzing file 32 of 41: data_split/train/CommonDolphin/7500304Q.wav
# Analyzing file 33 of 41: data_split/train/CommonDolphin/75003053.wav
# Analyzing file 34 of 41: data_split/train/CommonDolphin/75003056.wav
# Analyzing file 35 of 41: data_split/train/CommonDolphin/75003057.wav
# Analyzing file 36 of 41: data_split/train/CommonDolphin/75003058.wav
# Analyzing file 37 of 41: data_split/train/CommonDolphin/7500305D.wav
# Analyzing file 38 of 41: data_split/train/CommonDolphin/7500305H.wav
# Analyzing file 39 of 41: data_split/train/CommonDolphin/7500305M.wav
# Analyzing file 40 of 41: data_split/train/CommonDolphin/87003005.wav
# Analyzing file 41 of 41: data_split/train/CommonDolphin/87003006.wav
# Feature extraction complexity ratio: 8.8 x realtime
# Analyzing file 1 of 47: data_split/train/FalseKillerWhale/6102100P.wav
# Analyzing file 2 of 47: data_split/train/FalseKillerWhale/6102100Q.wav
# Analyzing file 3 of 47: data_split/train/FalseKillerWhale/6102100T.wav
# Analyzing file 4 of 47: data_split/train/FalseKillerWhale/6102100W.wav
# Analyzing file 5 of 47: data_split/train/FalseKillerWhale/6102100X.wav
# Analyzing file 6 of 47: data_split/train/FalseKillerWhale/6102100Y.wav
# Analyzing file 7 of 47: data_split/train/FalseKillerWhale/61021011.wav
# Analyzing file 8 of 47: data_split/train/FalseKillerWhale/61021012.wav
# Analyzing file 9 of 47: data_split/train/FalseKillerWhale/61021019.wav
# Analyzing file 10 of 47: data_split/train/FalseKillerWhale/6102101A.wav
# Analyzing file 11 of 47: data_split/train/FalseKillerWhale/6102101C.wav
# Analyzing file 12 of 47: data_split/train/FalseKillerWhale/6102101F.wav
# Analyzing file 13 of 47: data_split/train/FalseKillerWhale/6102101N.wav
# Analyzing file 14 of 47: data_split/train/FalseKillerWhale/6102101T.wav
# Analyzing file 15 of 47: data_split/train/FalseKillerWhale/6102101U.wav
# Analyzing file 16 of 47: data_split/train/FalseKillerWhale/61023001.wav
# Analyzing file 17 of 47: data_split/train/FalseKillerWhale/61023002.wav
# Analyzing file 18 of 47: data_split/train/FalseKillerWhale/61023005.wav
# Analyzing file 19 of 47: data_split/train/FalseKillerWhale/61023006.wav
# Analyzing file 20 of 47: data_split/train/FalseKillerWhale/61023008.wav
# Analyzing file 21 of 47: data_split/train/FalseKillerWhale/6102300A.wav
# Analyzing file 22 of 47: data_split/train/FalseKillerWhale/6102300F.wav
# Analyzing file 23 of 47: data_split/train/FalseKillerWhale/6102300H.wav
# Analyzing file 24 of 47: data_split/train/FalseKillerWhale/6102300I.wav
# Analyzing file 25 of 47: data_split/train/FalseKillerWhale/6102300J.wav
# Analyzing file 26 of 47: data_split/train/FalseKillerWhale/6102300P.wav
# Analyzing file 27 of 47: data_split/train/FalseKillerWhale/6102300R.wav
# Analyzing file 28 of 47: data_split/train/FalseKillerWhale/6102300S.wav
# Analyzing file 29 of 47: data_split/train/FalseKillerWhale/6102300U.wav
# Analyzing file 30 of 47: data_split/train/FalseKillerWhale/6102300V.wav
# Analyzing file 31 of 47: data_split/train/FalseKillerWhale/6102300X.wav
# Analyzing file 32 of 47: data_split/train/FalseKillerWhale/61023015.wav
# Analyzing file 33 of 47: data_split/train/FalseKillerWhale/61023019.wav
# Analyzing file 34 of 47: data_split/train/FalseKillerWhale/6102301A.wav
# Analyzing file 35 of 47: data_split/train/FalseKillerWhale/6102301B.wav
# Analyzing file 36 of 47: data_split/train/FalseKillerWhale/6102301D.wav
# Analyzing file 37 of 47: data_split/train/FalseKillerWhale/6102301J.wav
# Analyzing file 38 of 47: data_split/train/FalseKillerWhale/95003001.wav
# Analyzing file 39 of 47: data_split/train/FalseKillerWhale/95003003.wav
# Analyzing file 40 of 47: data_split/train/FalseKillerWhale/95003004.wav
# Analyzing file 41 of 47: data_split/train/FalseKillerWhale/95003005.wav
# Analyzing file 42 of 47: data_split/train/FalseKillerWhale/95003006.wav
# Analyzing file 43 of 47: data_split/train/FalseKillerWhale/95003007.wav
# Analyzing file 44 of 47: data_split/train/FalseKillerWhale/95003008.wav
# Analyzing file 45 of 47: data_split/train/FalseKillerWhale/95003009.wav
# Analyzing file 46 of 47: data_split/train/FalseKillerWhale/9500300A.wav
# Analyzing file 47 of 47: data_split/train/FalseKillerWhale/9500300B.wav
# Feature extraction complexity ratio: 8.5 x realtime
# Analyzing file 1 of 69: data_split/train/Fraser'sDolphin/91008005.wav
# Analyzing file 2 of 69: data_split/train/Fraser'sDolphin/91008008.wav
# Analyzing file 3 of 69: data_split/train/Fraser'sDolphin/91008009.wav
# Analyzing file 4 of 69: data_split/train/Fraser'sDolphin/9100800A.wav
# Analyzing file 5 of 69: data_split/train/Fraser'sDolphin/9100800B.wav
# Analyzing file 6 of 69: data_split/train/Fraser'sDolphin/9100800C.wav
# Analyzing file 7 of 69: data_split/train/Fraser'sDolphin/9100800D.wav
# Analyzing file 8 of 69: data_split/train/Fraser'sDolphin/9100800E.wav
# Analyzing file 9 of 69: data_split/train/Fraser'sDolphin/91010004.wav
# Analyzing file 10 of 69: data_split/train/Fraser'sDolphin/9101000F.wav
# Analyzing file 11 of 69: data_split/train/Fraser'sDolphin/9101000H.wav
# Analyzing file 12 of 69: data_split/train/Fraser'sDolphin/9101000K.wav
# Analyzing file 13 of 69: data_split/train/Fraser'sDolphin/9101000W.wav
# Analyzing file 14 of 69: data_split/train/Fraser'sDolphin/9101000X.wav
# Analyzing file 15 of 69: data_split/train/Fraser'sDolphin/9101000Y.wav
# Analyzing file 16 of 69: data_split/train/Fraser'sDolphin/9101000Z.wav
# Analyzing file 17 of 69: data_split/train/Fraser'sDolphin/91010010.wav
# Analyzing file 18 of 69: data_split/train/Fraser'sDolphin/91010014.wav
# Analyzing file 19 of 69: data_split/train/Fraser'sDolphin/91010019.wav
# Analyzing file 20 of 69: data_split/train/Fraser'sDolphin/9101001H.wav
# Analyzing file 21 of 69: data_split/train/Fraser'sDolphin/9101001L.wav
# Analyzing file 22 of 69: data_split/train/Fraser'sDolphin/9101001M.wav
# Analyzing file 23 of 69: data_split/train/Fraser'sDolphin/9101001O.wav
# Analyzing file 24 of 69: data_split/train/Fraser'sDolphin/9101001Q.wav
# Analyzing file 25 of 69: data_split/train/Fraser'sDolphin/9101001R.wav
# Analyzing file 26 of 69: data_split/train/Fraser'sDolphin/9101001S.wav
# Analyzing file 27 of 69: data_split/train/Fraser'sDolphin/9101001T.wav
# Analyzing file 28 of 69: data_split/train/Fraser'sDolphin/9101001U.wav
# Analyzing file 29 of 69: data_split/train/Fraser'sDolphin/9101001V.wav
# Analyzing file 30 of 69: data_split/train/Fraser'sDolphin/9101001W.wav
# Analyzing file 31 of 69: data_split/train/Fraser'sDolphin/9101001X.wav
# Analyzing file 32 of 69: data_split/train/Fraser'sDolphin/9101001Y.wav
# Analyzing file 33 of 69: data_split/train/Fraser'sDolphin/9101001Z.wav
# Analyzing file 34 of 69: data_split/train/Fraser'sDolphin/91010020.wav
# Analyzing file 35 of 69: data_split/train/Fraser'sDolphin/91010021.wav
# Analyzing file 36 of 69: data_split/train/Fraser'sDolphin/91010023.wav
# Analyzing file 37 of 69: data_split/train/Fraser'sDolphin/91010024.wav
# Analyzing file 38 of 69: data_split/train/Fraser'sDolphin/91010026.wav
# Analyzing file 39 of 69: data_split/train/Fraser'sDolphin/91010027.wav
# Analyzing file 40 of 69: data_split/train/Fraser'sDolphin/91010028.wav
# Analyzing file 41 of 69: data_split/train/Fraser'sDolphin/9101002A.wav
# Analyzing file 42 of 69: data_split/train/Fraser'sDolphin/9101002B.wav
# Analyzing file 43 of 69: data_split/train/Fraser'sDolphin/91013003.wav
# Analyzing file 44 of 69: data_split/train/Fraser'sDolphin/91013004.wav
# Analyzing file 45 of 69: data_split/train/Fraser'sDolphin/91013008.wav
# Analyzing file 46 of 69: data_split/train/Fraser'sDolphin/9101300A.wav
# Analyzing file 47 of 69: data_split/train/Fraser'sDolphin/9101300B.wav
# Analyzing file 48 of 69: data_split/train/Fraser'sDolphin/9101300C.wav
# Analyzing file 49 of 69: data_split/train/Fraser'sDolphin/9101300D.wav
# Analyzing file 50 of 69: data_split/train/Fraser'sDolphin/9101300E.wav
# Analyzing file 51 of 69: data_split/train/Fraser'sDolphin/9101300F.wav
# Analyzing file 52 of 69: data_split/train/Fraser'sDolphin/9101300H.wav
# Analyzing file 53 of 69: data_split/train/Fraser'sDolphin/9101300I.wav
# Analyzing file 54 of 69: data_split/train/Fraser'sDolphin/9101300K.wav
# Analyzing file 55 of 69: data_split/train/Fraser'sDolphin/9101300N.wav
# Analyzing file 56 of 69: data_split/train/Fraser'sDolphin/9101300U.wav
# Analyzing file 57 of 69: data_split/train/Fraser'sDolphin/9101300Y.wav
# Analyzing file 58 of 69: data_split/train/Fraser'sDolphin/91013014.wav
# Analyzing file 59 of 69: data_split/train/Fraser'sDolphin/91013016.wav
# Analyzing file 60 of 69: data_split/train/Fraser'sDolphin/9101301A.wav
# Analyzing file 61 of 69: data_split/train/Fraser'sDolphin/9101301D.wav
# Analyzing file 62 of 69: data_split/train/Fraser'sDolphin/9101301E.wav
# Analyzing file 63 of 69: data_split/train/Fraser'sDolphin/9101301F.wav
# Analyzing file 64 of 69: data_split/train/Fraser'sDolphin/9101301I.wav
# Analyzing file 65 of 69: data_split/train/Fraser'sDolphin/9101301K.wav
# Analyzing file 66 of 69: data_split/train/Fraser'sDolphin/9101301L.wav
# Analyzing file 67 of 69: data_split/train/Fraser'sDolphin/9101301M.wav
# Analyzing file 68 of 69: data_split/train/Fraser'sDolphin/9101301O.wav
# Analyzing file 69 of 69: data_split/train/Fraser'sDolphin/9101301P.wav
# Feature extraction complexity ratio: 8.7 x realtime
# Analyzing file 1 of 53: data_split/train/Grampus_Risso'sDolphin/59029001.wav
# Analyzing file 2 of 53: data_split/train/Grampus_Risso'sDolphin/59029002.wav
# Analyzing file 3 of 53: data_split/train/Grampus_Risso'sDolphin/59029003.wav
# Analyzing file 4 of 53: data_split/train/Grampus_Risso'sDolphin/59029007.wav
# Analyzing file 5 of 53: data_split/train/Grampus_Risso'sDolphin/5902900A.wav
# Analyzing file 6 of 53: data_split/train/Grampus_Risso'sDolphin/5902900J.wav
# Analyzing file 7 of 53: data_split/train/Grampus_Risso'sDolphin/5902900M.wav
# Analyzing file 8 of 53: data_split/train/Grampus_Risso'sDolphin/5902900R.wav
# Analyzing file 9 of 53: data_split/train/Grampus_Risso'sDolphin/5902900S.wav
# Analyzing file 10 of 53: data_split/train/Grampus_Risso'sDolphin/5902900U.wav
# Analyzing file 11 of 53: data_split/train/Grampus_Risso'sDolphin/5902900W.wav
# Analyzing file 12 of 53: data_split/train/Grampus_Risso'sDolphin/5902900Y.wav
# Analyzing file 13 of 53: data_split/train/Grampus_Risso'sDolphin/5902900Z.wav
# Analyzing file 14 of 53: data_split/train/Grampus_Risso'sDolphin/59029014.wav
# Analyzing file 15 of 53: data_split/train/Grampus_Risso'sDolphin/59029016.wav
# Analyzing file 16 of 53: data_split/train/Grampus_Risso'sDolphin/59029017.wav
# Analyzing file 17 of 53: data_split/train/Grampus_Risso'sDolphin/59030001.wav
# Analyzing file 18 of 53: data_split/train/Grampus_Risso'sDolphin/59030003.wav
# Analyzing file 19 of 53: data_split/train/Grampus_Risso'sDolphin/59030005.wav
# Analyzing file 20 of 53: data_split/train/Grampus_Risso'sDolphin/5903000C.wav
# Analyzing file 21 of 53: data_split/train/Grampus_Risso'sDolphin/5903000W.wav
# Analyzing file 22 of 53: data_split/train/Grampus_Risso'sDolphin/5903001Y.wav
# Analyzing file 23 of 53: data_split/train/Grampus_Risso'sDolphin/5903001Z.wav
# Analyzing file 24 of 53: data_split/train/Grampus_Risso'sDolphin/59030021.wav
# Analyzing file 25 of 53: data_split/train/Grampus_Risso'sDolphin/59030023.wav
# Analyzing file 26 of 53: data_split/train/Grampus_Risso'sDolphin/59030024.wav
# Analyzing file 27 of 53: data_split/train/Grampus_Risso'sDolphin/59030026.wav
# Analyzing file 28 of 53: data_split/train/Grampus_Risso'sDolphin/59030029.wav
# Analyzing file 29 of 53: data_split/train/Grampus_Risso'sDolphin/5903002D.wav
# Analyzing file 30 of 53: data_split/train/Grampus_Risso'sDolphin/5903002G.wav
# Analyzing file 31 of 53: data_split/train/Grampus_Risso'sDolphin/5903002N.wav
# Analyzing file 32 of 53: data_split/train/Grampus_Risso'sDolphin/5903002Q.wav
# Analyzing file 33 of 53: data_split/train/Grampus_Risso'sDolphin/5903002S.wav
# Analyzing file 34 of 53: data_split/train/Grampus_Risso'sDolphin/5903002T.wav
# Analyzing file 35 of 53: data_split/train/Grampus_Risso'sDolphin/5903002U.wav
# Analyzing file 36 of 53: data_split/train/Grampus_Risso'sDolphin/59030033.wav
# Analyzing file 37 of 53: data_split/train/Grampus_Risso'sDolphin/59030035.wav
# Analyzing file 38 of 53: data_split/train/Grampus_Risso'sDolphin/85009001.wav
# Analyzing file 39 of 53: data_split/train/Grampus_Risso'sDolphin/85009003.wav
# Analyzing file 40 of 53: data_split/train/Grampus_Risso'sDolphin/85009008.wav
# Analyzing file 41 of 53: data_split/train/Grampus_Risso'sDolphin/85009009.wav
# Analyzing file 42 of 53: data_split/train/Grampus_Risso'sDolphin/8500900A.wav
# Analyzing file 43 of 53: data_split/train/Grampus_Risso'sDolphin/8500900I.wav
# Analyzing file 44 of 53: data_split/train/Grampus_Risso'sDolphin/8500900J.wav
# Analyzing file 45 of 53: data_split/train/Grampus_Risso'sDolphin/8500900L.wav
# Analyzing file 46 of 53: data_split/train/Grampus_Risso'sDolphin/8500900M.wav
# Analyzing file 47 of 53: data_split/train/Grampus_Risso'sDolphin/8500900O.wav
# Analyzing file 48 of 53: data_split/train/Grampus_Risso'sDolphin/8500900P.wav
# Analyzing file 49 of 53: data_split/train/Grampus_Risso'sDolphin/8500900Q.wav
# Analyzing file 50 of 53: data_split/train/Grampus_Risso'sDolphin/8500900R.wav
# Analyzing file 51 of 53: data_split/train/Grampus_Risso'sDolphin/8500900S.wav
# Analyzing file 52 of 53: data_split/train/Grampus_Risso'sDolphin/8500900U.wav
# Analyzing file 53 of 53: data_split/train/Grampus_Risso'sDolphin/8700400E.wav
# Feature extraction complexity ratio: 8.7 x realtime
# Analyzing file 1 of 37: data_split/train/HarpSeal/67008008.wav
# Analyzing file 2 of 37: data_split/train/HarpSeal/67009001.wav
# Analyzing file 3 of 37: data_split/train/HarpSeal/67009002.wav
# Analyzing file 4 of 37: data_split/train/HarpSeal/67009003.wav
# Analyzing file 5 of 37: data_split/train/HarpSeal/67009004.wav
# Analyzing file 6 of 37: data_split/train/HarpSeal/67009005.wav
# Analyzing file 7 of 37: data_split/train/HarpSeal/67009006.wav
# Analyzing file 8 of 37: data_split/train/HarpSeal/67009007.wav
# Analyzing file 9 of 37: data_split/train/HarpSeal/67009008.wav
# Analyzing file 10 of 37: data_split/train/HarpSeal/67009009.wav
# Analyzing file 11 of 37: data_split/train/HarpSeal/6700900B.wav
# Analyzing file 12 of 37: data_split/train/HarpSeal/6700900D.wav
# Analyzing file 13 of 37: data_split/train/HarpSeal/6700900E.wav
# Analyzing file 14 of 37: data_split/train/HarpSeal/6700900F.wav
# Analyzing file 15 of 37: data_split/train/HarpSeal/6700900G.wav
# Analyzing file 16 of 37: data_split/train/HarpSeal/6700900H.wav
# Analyzing file 17 of 37: data_split/train/HarpSeal/6700900I.wav
# Analyzing file 18 of 37: data_split/train/HarpSeal/6700900J.wav
# Analyzing file 19 of 37: data_split/train/HarpSeal/6700900L.wav
# Analyzing file 20 of 37: data_split/train/HarpSeal/6700900N.wav
# Analyzing file 21 of 37: data_split/train/HarpSeal/6700900R.wav
# Analyzing file 22 of 37: data_split/train/HarpSeal/6700900S.wav
# Analyzing file 23 of 37: data_split/train/HarpSeal/6700900T.wav
# Analyzing file 24 of 37: data_split/train/HarpSeal/6700900U.wav
# Analyzing file 25 of 37: data_split/train/HarpSeal/6700900W.wav
# Analyzing file 26 of 37: data_split/train/HarpSeal/67010001.wav
# Analyzing file 27 of 37: data_split/train/HarpSeal/67010002.wav
# Analyzing file 28 of 37: data_split/train/HarpSeal/67010003.wav
# Analyzing file 29 of 37: data_split/train/HarpSeal/67010004.wav
# Analyzing file 30 of 37: data_split/train/HarpSeal/67010006.wav
# Analyzing file 31 of 37: data_split/train/HarpSeal/67010009.wav
# Analyzing file 32 of 37: data_split/train/HarpSeal/6701000B.wav
# Analyzing file 33 of 37: data_split/train/HarpSeal/6701000C.wav
# Analyzing file 34 of 37: data_split/train/HarpSeal/6701000D.wav
# Analyzing file 35 of 37: data_split/train/HarpSeal/6701000E.wav
# Analyzing file 36 of 37: data_split/train/HarpSeal/6701000G.wav
# Analyzing file 37 of 37: data_split/train/HarpSeal/6701000H.wav
# Feature extraction complexity ratio: 20.2 x realtime
# Analyzing file 1 of 51: data_split/train/HumpbackWhale/55113001.wav
# Analyzing file 2 of 51: data_split/train/HumpbackWhale/55113002.wav
# Analyzing file 3 of 51: data_split/train/HumpbackWhale/55113003.wav
# Analyzing file 4 of 51: data_split/train/HumpbackWhale/55113004.wav
# Analyzing file 5 of 51: data_split/train/HumpbackWhale/55113007.wav
# Analyzing file 6 of 51: data_split/train/HumpbackWhale/5511300F.wav
# Analyzing file 7 of 51: data_split/train/HumpbackWhale/63019001.wav
# Analyzing file 8 of 51: data_split/train/HumpbackWhale/63019002.wav
# Analyzing file 9 of 51: data_split/train/HumpbackWhale/63019003.wav
# Analyzing file 10 of 51: data_split/train/HumpbackWhale/63019004.wav
# Analyzing file 11 of 51: data_split/train/HumpbackWhale/63019007.wav
# Analyzing file 12 of 51: data_split/train/HumpbackWhale/6301900B.wav
# Analyzing file 13 of 51: data_split/train/HumpbackWhale/6301900C.wav
# Analyzing file 14 of 51: data_split/train/HumpbackWhale/6301900D.wav
# Analyzing file 15 of 51: data_split/train/HumpbackWhale/6301900T.wav
# Analyzing file 16 of 51: data_split/train/HumpbackWhale/6301900V.wav
# Analyzing file 17 of 51: data_split/train/HumpbackWhale/6301900W.wav
# Analyzing file 18 of 51: data_split/train/HumpbackWhale/6301900Y.wav
# Analyzing file 19 of 51: data_split/train/HumpbackWhale/63019010.wav
# Analyzing file 20 of 51: data_split/train/HumpbackWhale/63019012.wav
# Analyzing file 21 of 51: data_split/train/HumpbackWhale/63019017.wav
# Analyzing file 22 of 51: data_split/train/HumpbackWhale/63019018.wav
# Analyzing file 23 of 51: data_split/train/HumpbackWhale/63019019.wav
# Analyzing file 24 of 51: data_split/train/HumpbackWhale/6301901A.wav
# Analyzing file 25 of 51: data_split/train/HumpbackWhale/6301901B.wav
# Analyzing file 26 of 51: data_split/train/HumpbackWhale/6301901C.wav
# Analyzing file 27 of 51: data_split/train/HumpbackWhale/6301901D.wav
# Analyzing file 28 of 51: data_split/train/HumpbackWhale/6301901E.wav
# Analyzing file 29 of 51: data_split/train/HumpbackWhale/6301901H.wav
# Analyzing file 30 of 51: data_split/train/HumpbackWhale/6301901L.wav
# Analyzing file 31 of 51: data_split/train/HumpbackWhale/6301901M.wav
# Analyzing file 32 of 51: data_split/train/HumpbackWhale/6301901U.wav
# Analyzing file 33 of 51: data_split/train/HumpbackWhale/6301901V.wav
# Analyzing file 34 of 51: data_split/train/HumpbackWhale/6304300F.wav
# Analyzing file 35 of 51: data_split/train/HumpbackWhale/6304300K.wav
# Analyzing file 36 of 51: data_split/train/HumpbackWhale/6304300M.wav
# Analyzing file 37 of 51: data_split/train/HumpbackWhale/6304300N.wav
# Analyzing file 38 of 51: data_split/train/HumpbackWhale/6304300O.wav
# Analyzing file 39 of 51: data_split/train/HumpbackWhale/92201001.wav
# Analyzing file 40 of 51: data_split/train/HumpbackWhale/92201002.wav
# Analyzing file 41 of 51: data_split/train/HumpbackWhale/92201007.wav
# Analyzing file 42 of 51: data_split/train/HumpbackWhale/9220100D.wav
# Analyzing file 43 of 51: data_split/train/HumpbackWhale/9220100E.wav
# Analyzing file 44 of 51: data_split/train/HumpbackWhale/9220100F.wav
# Analyzing file 45 of 51: data_split/train/HumpbackWhale/9220100G.wav
# Analyzing file 46 of 51: data_split/train/HumpbackWhale/9220100Q.wav
# Analyzing file 47 of 51: data_split/train/HumpbackWhale/9220100S.wav
# Analyzing file 48 of 51: data_split/train/HumpbackWhale/9220100T.wav
# Analyzing file 49 of 51: data_split/train/HumpbackWhale/9220100V.wav
# Analyzing file 50 of 51: data_split/train/HumpbackWhale/9220100W.wav
# Analyzing file 51 of 51: data_split/train/HumpbackWhale/9220100X.wav
# Feature extraction complexity ratio: 21.2 x realtime
# Analyzing file 1 of 28: data_split/train/KillerWhale/60026001.wav
# Analyzing file 2 of 28: data_split/train/KillerWhale/60026002.wav
# Analyzing file 3 of 28: data_split/train/KillerWhale/60026003.wav
# Analyzing file 4 of 28: data_split/train/KillerWhale/60026004.wav
# Analyzing file 5 of 28: data_split/train/KillerWhale/60026005.wav
# Analyzing file 6 of 28: data_split/train/KillerWhale/60026006.wav
# Analyzing file 7 of 28: data_split/train/KillerWhale/6002600A.wav
# Analyzing file 8 of 28: data_split/train/KillerWhale/6002600B.wav
# Analyzing file 9 of 28: data_split/train/KillerWhale/64020001.wav
# Analyzing file 10 of 28: data_split/train/KillerWhale/64020003.wav
# Analyzing file 11 of 28: data_split/train/KillerWhale/9230000L.wav
# Analyzing file 12 of 28: data_split/train/KillerWhale/92301007.wav
# Analyzing file 13 of 28: data_split/train/KillerWhale/92304008.wav
# Analyzing file 14 of 28: data_split/train/KillerWhale/9230400D.wav
# Analyzing file 15 of 28: data_split/train/KillerWhale/9750000S.wav
# Analyzing file 16 of 28: data_split/train/KillerWhale/97501009.wav
# Analyzing file 17 of 28: data_split/train/KillerWhale/97503007.wav
# Analyzing file 18 of 28: data_split/train/KillerWhale/9750300I.wav
# Analyzing file 19 of 28: data_split/train/KillerWhale/9750300V.wav
# Analyzing file 20 of 28: data_split/train/KillerWhale/97503018.wav
# Analyzing file 21 of 28: data_split/train/KillerWhale/9750301M.wav
# Analyzing file 22 of 28: data_split/train/KillerWhale/9750301O.wav
# Analyzing file 23 of 28: data_split/train/KillerWhale/9750301Q.wav
# Analyzing file 24 of 28: data_split/train/KillerWhale/9750400C.wav
# Analyzing file 25 of 28: data_split/train/KillerWhale/9750400J.wav
# Analyzing file 26 of 28: data_split/train/KillerWhale/9750400V.wav
# Analyzing file 27 of 28: data_split/train/KillerWhale/9761900T.wav
# Analyzing file 28 of 28: data_split/train/KillerWhale/97619015.wav
# Feature extraction complexity ratio: 14.1 x realtime
# Analyzing file 1 of 56: data_split/train/Long_FinnedPilotWhale/54024001.wav
# Analyzing file 2 of 56: data_split/train/Long_FinnedPilotWhale/54024002.wav
# Analyzing file 3 of 56: data_split/train/Long_FinnedPilotWhale/54024003.wav
# Analyzing file 4 of 56: data_split/train/Long_FinnedPilotWhale/54024004.wav
# Analyzing file 5 of 56: data_split/train/Long_FinnedPilotWhale/54024005.wav
# Analyzing file 6 of 56: data_split/train/Long_FinnedPilotWhale/54024006.wav
# Analyzing file 7 of 56: data_split/train/Long_FinnedPilotWhale/54024007.wav
# Analyzing file 8 of 56: data_split/train/Long_FinnedPilotWhale/54024008.wav
# Analyzing file 9 of 56: data_split/train/Long_FinnedPilotWhale/54024009.wav
# Analyzing file 10 of 56: data_split/train/Long_FinnedPilotWhale/5402400A.wav
# Analyzing file 11 of 56: data_split/train/Long_FinnedPilotWhale/5402400B.wav
# Analyzing file 12 of 56: data_split/train/Long_FinnedPilotWhale/5402400C.wav
# Analyzing file 13 of 56: data_split/train/Long_FinnedPilotWhale/7500400U.wav
# Analyzing file 14 of 56: data_split/train/Long_FinnedPilotWhale/75004025.wav
# Analyzing file 15 of 56: data_split/train/Long_FinnedPilotWhale/7500402E.wav
# Analyzing file 16 of 56: data_split/train/Long_FinnedPilotWhale/7500402F.wav
# Analyzing file 17 of 56: data_split/train/Long_FinnedPilotWhale/7500402I.wav
# Analyzing file 18 of 56: data_split/train/Long_FinnedPilotWhale/7500402O.wav
# Analyzing file 19 of 56: data_split/train/Long_FinnedPilotWhale/75004033.wav
# Analyzing file 20 of 56: data_split/train/Long_FinnedPilotWhale/7500403A.wav
# Analyzing file 21 of 56: data_split/train/Long_FinnedPilotWhale/7500403N.wav
# Analyzing file 22 of 56: data_split/train/Long_FinnedPilotWhale/7500502Q.wav
# Analyzing file 23 of 56: data_split/train/Long_FinnedPilotWhale/7500502S.wav
# Analyzing file 24 of 56: data_split/train/Long_FinnedPilotWhale/7500502T.wav
# Analyzing file 25 of 56: data_split/train/Long_FinnedPilotWhale/7500502U.wav
# Analyzing file 26 of 56: data_split/train/Long_FinnedPilotWhale/7500502V.wav
# Analyzing file 27 of 56: data_split/train/Long_FinnedPilotWhale/7500502W.wav
# Analyzing file 28 of 56: data_split/train/Long_FinnedPilotWhale/7500502X.wav
# Analyzing file 29 of 56: data_split/train/Long_FinnedPilotWhale/7500502Z.wav
# Analyzing file 30 of 56: data_split/train/Long_FinnedPilotWhale/75005031.wav
# Analyzing file 31 of 56: data_split/train/Long_FinnedPilotWhale/75005032.wav
# Analyzing file 32 of 56: data_split/train/Long_FinnedPilotWhale/75005039.wav
# Analyzing file 33 of 56: data_split/train/Long_FinnedPilotWhale/7500503L.wav
# Analyzing file 34 of 56: data_split/train/Long_FinnedPilotWhale/77028008.wav
# Analyzing file 35 of 56: data_split/train/Long_FinnedPilotWhale/77028009.wav
# Analyzing file 36 of 56: data_split/train/Long_FinnedPilotWhale/7702800V.wav
# Analyzing file 37 of 56: data_split/train/Long_FinnedPilotWhale/7702800X.wav
# Analyzing file 38 of 56: data_split/train/Long_FinnedPilotWhale/77028015.wav
# Analyzing file 39 of 56: data_split/train/Long_FinnedPilotWhale/77028018.wav
# Analyzing file 40 of 56: data_split/train/Long_FinnedPilotWhale/7702801F.wav
# Analyzing file 41 of 56: data_split/train/Long_FinnedPilotWhale/7702801M.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 42 of 56: data_split/train/Long_FinnedPilotWhale/77034002.wav
# Analyzing file 43 of 56: data_split/train/Long_FinnedPilotWhale/77034006.wav
# Analyzing file 44 of 56: data_split/train/Long_FinnedPilotWhale/77034008.wav
# Analyzing file 45 of 56: data_split/train/Long_FinnedPilotWhale/77034009.wav
# Analyzing file 46 of 56: data_split/train/Long_FinnedPilotWhale/7703400B.wav
# Analyzing file 47 of 56: data_split/train/Long_FinnedPilotWhale/7703400D.wav
# Analyzing file 48 of 56: data_split/train/Long_FinnedPilotWhale/7703400H.wav
# Analyzing file 49 of 56: data_split/train/Long_FinnedPilotWhale/7703400J.wav
# Analyzing file 50 of 56: data_split/train/Long_FinnedPilotWhale/7703400K.wav
# Analyzing file 51 of 56: data_split/train/Long_FinnedPilotWhale/7703400L.wav
# Analyzing file 52 of 56: data_split/train/Long_FinnedPilotWhale/7703400M.wav
# Analyzing file 53 of 56: data_split/train/Long_FinnedPilotWhale/7703400O.wav
# Analyzing file 54 of 56: data_split/train/Long_FinnedPilotWhale/7703400P.wav
# Analyzing file 55 of 56: data_split/train/Long_FinnedPilotWhale/7703400Q.wav
# Analyzing file 56 of 56: data_split/train/Long_FinnedPilotWhale/7703400S.wav
# Feature extraction complexity ratio: 9.3 x realtime
# Analyzing file 1 of 50: data_split/train/MelonHeadedWhale/91012003.wav
# Analyzing file 2 of 50: data_split/train/MelonHeadedWhale/91012006.wav
# Analyzing file 3 of 50: data_split/train/MelonHeadedWhale/91012007.wav
# Analyzing file 4 of 50: data_split/train/MelonHeadedWhale/91012009.wav
# Analyzing file 5 of 50: data_split/train/MelonHeadedWhale/9101200B.wav
# Analyzing file 6 of 50: data_split/train/MelonHeadedWhale/9101200C.wav
# Analyzing file 7 of 50: data_split/train/MelonHeadedWhale/9101200I.wav
# Analyzing file 8 of 50: data_split/train/MelonHeadedWhale/9101200K.wav
# Analyzing file 9 of 50: data_split/train/MelonHeadedWhale/9101200U.wav
# Analyzing file 10 of 50: data_split/train/MelonHeadedWhale/91012016.wav
# Analyzing file 11 of 50: data_split/train/MelonHeadedWhale/9101201C.wav
# Analyzing file 12 of 50: data_split/train/MelonHeadedWhale/9101201E.wav
# Analyzing file 13 of 50: data_split/train/MelonHeadedWhale/9101201F.wav
# Analyzing file 14 of 50: data_split/train/MelonHeadedWhale/9101201I.wav
# Analyzing file 15 of 50: data_split/train/MelonHeadedWhale/9101201L.wav
# Analyzing file 16 of 50: data_split/train/MelonHeadedWhale/9101201T.wav
# Analyzing file 17 of 50: data_split/train/MelonHeadedWhale/9101201Z.wav
# Analyzing file 18 of 50: data_split/train/MelonHeadedWhale/91012022.wav
# Analyzing file 19 of 50: data_split/train/MelonHeadedWhale/91012024.wav
# Analyzing file 20 of 50: data_split/train/MelonHeadedWhale/91012026.wav
# Analyzing file 21 of 50: data_split/train/MelonHeadedWhale/9101202C.wav
# Analyzing file 22 of 50: data_split/train/MelonHeadedWhale/9101202R.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 23 of 50: data_split/train/MelonHeadedWhale/9101202S.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 24 of 50: data_split/train/MelonHeadedWhale/9101202T.wav
# Analyzing file 25 of 50: data_split/train/MelonHeadedWhale/9101202U.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 26 of 50: data_split/train/MelonHeadedWhale/91012037.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 27 of 50: data_split/train/MelonHeadedWhale/91012039.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 28 of 50: data_split/train/MelonHeadedWhale/9101203D.wav
# Analyzing file 29 of 50: data_split/train/MelonHeadedWhale/9101203I.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 30 of 50: data_split/train/MelonHeadedWhale/9101203J.wav
# Analyzing file 31 of 50: data_split/train/MelonHeadedWhale/9101203S.wav
# Analyzing file 32 of 50: data_split/train/MelonHeadedWhale/9101203X.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 33 of 50: data_split/train/MelonHeadedWhale/91012041.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 34 of 50: data_split/train/MelonHeadedWhale/91012042.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 35 of 50: data_split/train/MelonHeadedWhale/91012043.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 36 of 50: data_split/train/MelonHeadedWhale/91012044.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 37 of 50: data_split/train/MelonHeadedWhale/91012045.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 38 of 50: data_split/train/MelonHeadedWhale/91012048.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 39 of 50: data_split/train/MelonHeadedWhale/91012049.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 40 of 50: data_split/train/MelonHeadedWhale/9101204C.wav
# ...
# Analyzing file 9 of 11: data_split/val/SpinnerDolphin/7100801L.wav
# Analyzing file 10 of 11: data_split/val/SpinnerDolphin/7100801M.wav
# Analyzing file 11 of 11: data_split/val/SpinnerDolphin/7101001E.wav
# Feature extraction complexity ratio: 8.9 x realtime
# Analyzing file 1 of 8: data_split/val/StripedDolphin/5801100E.wav
# Analyzing file 2 of 8: data_split/val/StripedDolphin/5801100O.wav
# Analyzing file 3 of 8: data_split/val/StripedDolphin/58011012.wav
# Analyzing file 4 of 8: data_split/val/StripedDolphin/7200703A.wav
# Analyzing file 5 of 8: data_split/val/StripedDolphin/7500300V.wav
# Analyzing file 6 of 8: data_split/val/StripedDolphin/7500300Z.wav
# Analyzing file 7 of 8: data_split/val/StripedDolphin/75003014.wav
# Analyzing file 8 of 8: data_split/val/StripedDolphin/8500701E.wav
# Feature extraction complexity ratio: 7.7 x realtime
# Analyzing file 1 of 3: data_split/val/Walrus/7200200F.wav
# Analyzing file 2 of 3: data_split/val/Walrus/72014003.wav
# Analyzing file 3 of 3: data_split/val/Walrus/7202000A.wav
# Feature extraction complexity ratio: 19.0 x realtime
# Analyzing file 1 of 5: data_split/val/White_beakedDolphin/5903700L.wav
# Analyzing file 2 of 5: data_split/val/White_beakedDolphin/70006003.wav
# Analyzing file 3 of 5: data_split/val/White_beakedDolphin/7001300E.wav
# Analyzing file 4 of 5: data_split/val/White_beakedDolphin/72005008.wav
# Analyzing file 5 of 5: data_split/val/White_beakedDolphin/7200500V.wav
# Feature extraction complexity ratio: 10.3 x realtime
# Analyzing file 1 of 5: data_split/val/White_sidedDolphin/6107200S.wav
# Analyzing file 2 of 5: data_split/val/White_sidedDolphin/61072023.wav
# Analyzing file 3 of 5: data_split/val/White_sidedDolphin/6107202L.wav
# Analyzing file 4 of 5: data_split/val/White_sidedDolphin/7500102S.wav
# Analyzing file 5 of 5: data_split/val/White_sidedDolphin/7800703Q.wav
# Feature extraction complexity ratio: 4.5 x realtime
# Analyzing file 1 of 7: data_split/test/AtlanticSpottedDolphin/6102500Q.wav
# Analyzing file 2 of 7: data_split/test/AtlanticSpottedDolphin/6102602I.wav
# Analyzing file 3 of 7: data_split/test/AtlanticSpottedDolphin/6102602K.wav
# Analyzing file 4 of 7: data_split/test/AtlanticSpottedDolphin/6102602T.wav
# Analyzing file 5 of 7: data_split/test/AtlanticSpottedDolphin/6102602V.wav
# Analyzing file 6 of 7: data_split/test/AtlanticSpottedDolphin/6102603E.wav
# Analyzing file 7 of 7: data_split/test/AtlanticSpottedDolphin/6102603F.wav
# Feature extraction complexity ratio: 8.9 x realtime
# Analyzing file 1 of 5: data_split/test/BeardedSeal/70025005.wav
# Analyzing file 2 of 5: data_split/test/BeardedSeal/71012007.wav
# Analyzing file 3 of 5: data_split/test/BeardedSeal/71012009.wav
# Analyzing file 4 of 5: data_split/test/BeardedSeal/72021005.wav
# Analyzing file 5 of 5: data_split/test/BeardedSeal/7801800H.wav
# Feature extraction complexity ratio: 24.8 x realtime
# Analyzing file 1 of 5: data_split/test/Beluga_WhiteWhale/62026009.wav
# Analyzing file 2 of 5: data_split/test/Beluga_WhiteWhale/65030001.wav
# Analyzing file 3 of 5: data_split/test/Beluga_WhiteWhale/6503000F.wav
# Analyzing file 4 of 5: data_split/test/Beluga_WhiteWhale/6503000I.wav
# Analyzing file 5 of 5: data_split/test/Beluga_WhiteWhale/6503300D.wav
# Feature extraction complexity ratio: 11.4 x realtime
# Analyzing file 1 of 3: data_split/test/BottlenoseDolphin/89514001.wav
# Analyzing file 2 of 3: data_split/test/BottlenoseDolphin/89514011.wav
# Analyzing file 3 of 3: data_split/test/BottlenoseDolphin/89514013.wav
# Feature extraction complexity ratio: 5.2 x realtime
# Analyzing file 1 of 6: data_split/test/BowheadWhale/8800600H.wav
# Analyzing file 2 of 6: data_split/test/BowheadWhale/8800600T.wav
# Analyzing file 3 of 6: data_split/test/BowheadWhale/8800600W.wav
# Analyzing file 4 of 6: data_split/test/BowheadWhale/8800600Y.wav
# Analyzing file 5 of 6: data_split/test/BowheadWhale/88006013.wav
# Analyzing file 6 of 6: data_split/test/BowheadWhale/8800601U.wav
# Feature extraction complexity ratio: 25.9 x realtime
# Analyzing file 1 of 7: data_split/test/ClymeneDolphin/8300602Q.wav
# Analyzing file 2 of 7: data_split/test/ClymeneDolphin/8300604F.wav
# Analyzing file 3 of 7: data_split/test/ClymeneDolphin/8300604H.wav
# Analyzing file 4 of 7: data_split/test/ClymeneDolphin/8300604I.wav
# Analyzing file 5 of 7: data_split/test/ClymeneDolphin/8300604K.wav
# Analyzing file 6 of 7: data_split/test/ClymeneDolphin/8300604Q.wav
# Analyzing file 7 of 7: data_split/test/ClymeneDolphin/8303503P.wav
# Feature extraction complexity ratio: 5.5 x realtime
# Analyzing file 1 of 6: data_split/test/CommonDolphin/75003042.wav
# Analyzing file 2 of 6: data_split/test/CommonDolphin/7500304M.wav
# Analyzing file 3 of 6: data_split/test/CommonDolphin/7500304O.wav
# Analyzing file 4 of 6: data_split/test/CommonDolphin/7500304P.wav
# Analyzing file 5 of 6: data_split/test/CommonDolphin/75003051.wav
# Analyzing file 6 of 6: data_split/test/CommonDolphin/7500305C.wav
# Feature extraction complexity ratio: 8.1 x realtime
# Analyzing file 1 of 7: data_split/test/FalseKillerWhale/6102300C.wav
# Analyzing file 2 of 7: data_split/test/FalseKillerWhale/6102300W.wav
# Analyzing file 3 of 7: data_split/test/FalseKillerWhale/6102300Z.wav
# Analyzing file 4 of 7: data_split/test/FalseKillerWhale/61023010.wav
# Analyzing file 5 of 7: data_split/test/FalseKillerWhale/61023016.wav
# Analyzing file 6 of 7: data_split/test/FalseKillerWhale/6102301E.wav
# Analyzing file 7 of 7: data_split/test/FalseKillerWhale/6102301I.wav
# Feature extraction complexity ratio: 10.3 x realtime
# Analyzing file 1 of 10: data_split/test/Fraser'sDolphin/9101001D.wav
# Analyzing file 2 of 10: data_split/test/Fraser'sDolphin/91010022.wav
# Analyzing file 3 of 10: data_split/test/Fraser'sDolphin/91010025.wav
# Analyzing file 4 of 10: data_split/test/Fraser'sDolphin/91010029.wav
# Analyzing file 5 of 10: data_split/test/Fraser'sDolphin/9101002C.wav
# Analyzing file 6 of 10: data_split/test/Fraser'sDolphin/9101300X.wav
# Analyzing file 7 of 10: data_split/test/Fraser'sDolphin/9101301B.wav
# Analyzing file 8 of 10: data_split/test/Fraser'sDolphin/9101301C.wav
# Analyzing file 9 of 10: data_split/test/Fraser'sDolphin/9101301H.wav
# Analyzing file 10 of 10: data_split/test/Fraser'sDolphin/9101301N.wav
# Feature extraction complexity ratio: 7.1 x realtime
# Analyzing file 1 of 8: data_split/test/Grampus_Risso'sDolphin/5903000A.wav
# Analyzing file 2 of 8: data_split/test/Grampus_Risso'sDolphin/5903000E.wav
# Analyzing file 3 of 8: data_split/test/Grampus_Risso'sDolphin/59030032.wav
# Analyzing file 4 of 8: data_split/test/Grampus_Risso'sDolphin/59030034.wav
# Analyzing file 5 of 8: data_split/test/Grampus_Risso'sDolphin/85009002.wav
# Analyzing file 6 of 8: data_split/test/Grampus_Risso'sDolphin/85009006.wav
# Analyzing file 7 of 8: data_split/test/Grampus_Risso'sDolphin/85009007.wav
# Analyzing file 8 of 8: data_split/test/Grampus_Risso'sDolphin/8500900N.wav
# Feature extraction complexity ratio: 11.3 x realtime
# Analyzing file 1 of 6: data_split/test/HarpSeal/6700900A.wav
# Analyzing file 2 of 6: data_split/test/HarpSeal/6700900P.wav
# Analyzing file 3 of 6: data_split/test/HarpSeal/67010005.wav
# Analyzing file 4 of 6: data_split/test/HarpSeal/67010007.wav
# Analyzing file 5 of 6: data_split/test/HarpSeal/67010008.wav
# Analyzing file 6 of 6: data_split/test/HarpSeal/6701000A.wav
# Feature extraction complexity ratio: 24.5 x realtime
# Analyzing file 1 of 7: data_split/test/HumpbackWhale/63019005.wav
# Analyzing file 2 of 7: data_split/test/HumpbackWhale/6301901N.wav
# Analyzing file 3 of 7: data_split/test/HumpbackWhale/6301901T.wav
# Analyzing file 4 of 7: data_split/test/HumpbackWhale/8002001M.wav
# Analyzing file 5 of 7: data_split/test/HumpbackWhale/92201003.wav
# Analyzing file 6 of 7: data_split/test/HumpbackWhale/9220100B.wav
# Analyzing file 7 of 7: data_split/test/HumpbackWhale/9220100Z.wav
# Feature extraction complexity ratio: 23.8 x realtime
# Analyzing file 1 of 4: data_split/test/KillerWhale/89405023.wav
# Analyzing file 2 of 4: data_split/test/KillerWhale/9750300Q.wav
# Analyzing file 3 of 4: data_split/test/KillerWhale/9750300Z.wav
# Analyzing file 4 of 4: data_split/test/KillerWhale/9769201Q.wav
# Feature extraction complexity ratio: 12.6 x realtime
# Analyzing file 1 of 7: data_split/test/Long_FinnedPilotWhale/7500403J.wav
# Analyzing file 2 of 7: data_split/test/Long_FinnedPilotWhale/7702800U.wav
# Analyzing file 3 of 7: data_split/test/Long_FinnedPilotWhale/77028010.wav
# Analyzing file 4 of 7: data_split/test/Long_FinnedPilotWhale/7702801D.wav
# Analyzing file 5 of 7: data_split/test/Long_FinnedPilotWhale/7702801L.wav
# Analyzing file 6 of 7: data_split/test/Long_FinnedPilotWhale/7703400U.wav
# Analyzing file 7 of 7: data_split/test/Long_FinnedPilotWhale/7703400V.wav
# Feature extraction complexity ratio: 9.7 x realtime
# Analyzing file 1 of 7: data_split/test/MelonHeadedWhale/9101202E.wav
# Analyzing file 2 of 7: data_split/test/MelonHeadedWhale/9101203N.wav
# Analyzing file 3 of 7: data_split/test/MelonHeadedWhale/9101203U.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 4 of 7: data_split/test/MelonHeadedWhale/9101203V.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 5 of 7: data_split/test/MelonHeadedWhale/91012040.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 6 of 7: data_split/test/MelonHeadedWhale/91012046.wav
#   (AUDIO FILE TOO SMALL - SKIPPING)
# Analyzing file 7 of 7: data_split/test/MelonHeadedWhale/9101204N.wav
# Feature extraction complexity ratio: 8.4 x realtime
# Analyzing file 1 of 5: data_split/test/Narwhal/7501400C.wav
# Analyzing file 2 of 5: data_split/test/Narwhal/7501400R.wav
# Analyzing file 3 of 5: data_split/test/Narwhal/7501400T.wav
# Analyzing file 4 of 5: data_split/test/Narwhal/7501400W.wav
# Analyzing file 5 of 5: data_split/test/Narwhal/75014012.wav
# Feature extraction complexity ratio: 6.1 x realtime
# Analyzing file 1 of 6: data_split/test/NorthernRightWhale/5900300A.wav
# Analyzing file 2 of 6: data_split/test/NorthernRightWhale/70014002.wav
# Analyzing file 3 of 6: data_split/test/NorthernRightWhale/7001800H.wav
# Analyzing file 4 of 6: data_split/test/NorthernRightWhale/7001800T.wav
# Analyzing file 5 of 6: data_split/test/NorthernRightWhale/74003001.wav
# Analyzing file 6 of 6: data_split/test/NorthernRightWhale/8101402I.wav
# Feature extraction complexity ratio: 26.4 x realtime
# Analyzing file 1 of 7: data_split/test/PantropicalSpottedDolphin/9004401V.wav
# Analyzing file 2 of 7: data_split/test/PantropicalSpottedDolphin/9004401Y.wav
# Analyzing file 3 of 7: data_split/test/PantropicalSpottedDolphin/9400800V.wav
# Analyzing file 4 of 7: data_split/test/PantropicalSpottedDolphin/9400801I.wav
# Analyzing file 5 of 7: data_split/test/PantropicalSpottedDolphin/9400802D.wav
# Analyzing file 6 of 7: data_split/test/PantropicalSpottedDolphin/9400807P.wav
# Analyzing file 7 of 7: data_split/test/PantropicalSpottedDolphin/94008085.wav
# Feature extraction complexity ratio: 7.2 x realtime
# Analyzing file 1 of 5: data_split/test/RossSeal/6608500A.wav
# Analyzing file 2 of 5: data_split/test/RossSeal/6608500L.wav
# Analyzing file 3 of 5: data_split/test/RossSeal/6608500N.wav
# Analyzing file 4 of 5: data_split/test/RossSeal/6608500Q.wav
# Analyzing file 5 of 5: data_split/test/RossSeal/6608900D.wav
# Feature extraction complexity ratio: 21.0 x realtime
# Analyzing file 1 of 5: data_split/test/Rough_ToothedDolphin/85013019.wav
# Analyzing file 2 of 5: data_split/test/Rough_ToothedDolphin/85014007.wav
# Analyzing file 3 of 5: data_split/test/Rough_ToothedDolphin/8501400F.wav
# Analyzing file 4 of 5: data_split/test/Rough_ToothedDolphin/8501400L.wav
# Analyzing file 5 of 5: data_split/test/Rough_ToothedDolphin/8501400S.wav
# Feature extraction complexity ratio: 9.3 x realtime
# Analyzing file 1 of 8: data_split/test/Short_Finned(Pacific)PilotWhale/81037002.wav
# Analyzing file 2 of 8: data_split/test/Short_Finned(Pacific)PilotWhale/81037005.wav
# Analyzing file 3 of 8: data_split/test/Short_Finned(Pacific)PilotWhale/81037007.wav
# Analyzing file 4 of 8: data_split/test/Short_Finned(Pacific)PilotWhale/91005006.wav
# Analyzing file 5 of 8: data_split/test/Short_Finned(Pacific)PilotWhale/9100500R.wav
# Analyzing file 6 of 8: data_split/test/Short_Finned(Pacific)PilotWhale/91005011.wav
# Analyzing file 7 of 8: data_split/test/Short_Finned(Pacific)PilotWhale/9100501D.wav
# Analyzing file 8 of 8: data_split/test/Short_Finned(Pacific)PilotWhale/9100502F.wav
# Feature extraction complexity ratio: 10.5 x realtime
# Analyzing file 1 of 3: data_split/test/SouthernRightWhale/79002013.wav
# Analyzing file 2 of 3: data_split/test/SouthernRightWhale/83002002.wav
# Analyzing file 3 of 3: data_split/test/SouthernRightWhale/8300200A.wav
# Feature extraction complexity ratio: 51.1 x realtime
# Analyzing file 1 of 8: data_split/test/SpermWhale/8401400A.wav
# Analyzing file 2 of 8: data_split/test/SpermWhale/87017001.wav
# Analyzing file 3 of 8: data_split/test/SpermWhale/87017004.wav
# Analyzing file 4 of 8: data_split/test/SpermWhale/91003001.wav
# Analyzing file 5 of 8: data_split/test/SpermWhale/91003005.wav
# Analyzing file 6 of 8: data_split/test/SpermWhale/91012009.wav
# Analyzing file 7 of 8: data_split/test/SpermWhale/9357001A.wav
# Analyzing file 8 of 8: data_split/test/SpermWhale/9400500C.wav
# Feature extraction complexity ratio: 8.7 x realtime
# Analyzing file 1 of 12: data_split/test/SpinnerDolphin/7100102S.wav
# Analyzing file 2 of 12: data_split/test/SpinnerDolphin/71003004.wav
# Analyzing file 3 of 12: data_split/test/SpinnerDolphin/71003008.wav
# Analyzing file 4 of 12: data_split/test/SpinnerDolphin/7100300B.wav
# Analyzing file 5 of 12: data_split/test/SpinnerDolphin/7100300W.wav
# Analyzing file 6 of 12: data_split/test/SpinnerDolphin/71004018.wav
# Analyzing file 7 of 12: data_split/test/SpinnerDolphin/71004019.wav
# Analyzing file 8 of 12: data_split/test/SpinnerDolphin/7100401E.wav
# Analyzing file 9 of 12: data_split/test/SpinnerDolphin/7100401G.wav
# Analyzing file 10 of 12: data_split/test/SpinnerDolphin/7100800D.wav
# Analyzing file 11 of 12: data_split/test/SpinnerDolphin/7100800Z.wav
# Analyzing file 12 of 12: data_split/test/SpinnerDolphin/7100801J.wav
# Feature extraction complexity ratio: 8.6 x realtime
# Analyzing file 1 of 9: data_split/test/StripedDolphin/5801100W.wav
# Analyzing file 2 of 9: data_split/test/StripedDolphin/75003002.wav
# Analyzing file 3 of 9: data_split/test/StripedDolphin/7500300M.wav
# Analyzing file 4 of 9: data_split/test/StripedDolphin/7500300T.wav
# Analyzing file 5 of 9: data_split/test/StripedDolphin/75003061.wav
# Analyzing file 6 of 9: data_split/test/StripedDolphin/8500701F.wav
# Analyzing file 7 of 9: data_split/test/StripedDolphin/8500701G.wav
# Analyzing file 8 of 9: data_split/test/StripedDolphin/8500701K.wav
# Analyzing file 9 of 9: data_split/test/StripedDolphin/8500701L.wav
# Feature extraction complexity ratio: 8.8 x realtime
# Analyzing file 1 of 5: data_split/test/Walrus/7200200D.wav
# Analyzing file 2 of 5: data_split/test/Walrus/72014005.wav
# Analyzing file 3 of 5: data_split/test/Walrus/72014007.wav
# Analyzing file 4 of 5: data_split/test/Walrus/72014008.wav
# Analyzing file 5 of 5: data_split/test/Walrus/72020006.wav
# Feature extraction complexity ratio: 15.5 x realtime
# Analyzing file 1 of 7: data_split/test/White_beakedDolphin/7001300B.wav
# Analyzing file 2 of 7: data_split/test/White_beakedDolphin/70014014.wav
# Analyzing file 3 of 7: data_split/test/White_beakedDolphin/72005003.wav
# Analyzing file 4 of 7: data_split/test/White_beakedDolphin/72005004.wav
# Analyzing file 5 of 7: data_split/test/White_beakedDolphin/72005007.wav
# Analyzing file 6 of 7: data_split/test/White_beakedDolphin/7200500G.wav
# Analyzing file 7 of 7: data_split/test/White_beakedDolphin/7200500H.wav
# Feature extraction complexity ratio: 10.9 x realtime
# Analyzing file 1 of 6: data_split/test/White_sidedDolphin/6107202K.wav
# Analyzing file 2 of 6: data_split/test/White_sidedDolphin/7500101P.wav
# Analyzing file 3 of 6: data_split/test/White_sidedDolphin/7500102G.wav
# Analyzing file 4 of 6: data_split/test/White_sidedDolphin/7500102H.wav
# Analyzing file 5 of 6: data_split/test/White_sidedDolphin/7500102R.wav
# Analyzing file 6 of 6: data_split/test/White_sidedDolphin/78007038.wav
# Feature extraction complexity ratio: 4.6 x realtime

# %% [markdown]
# ## **Fully Connected Neural Network**
#
# A fully connected neural network consists of a series of fully connected layers that connect every neuron in one layer to every neuron in the other layer. The [TensorFlow](https://www.tensorflow.org/) library was used to set up and train the model.

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow import keras
from keras.utils import to_categorical
from keras import layers, Sequential
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import confusion_matrix
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import regularizers
import tensorflow as tf
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

# %%
# Functions for each step of the model training and evaluation process

def load_data(file_path, sep='\t'):
    """
    Loads data from a CSV file and prepares it for training the model.

    Args:
    file_path (str): The path to the CSV file containing the data.
    sep (str, optional): The delimiter of the CSV file. Defaults to '\t'.

    Returns:
    tuple: A tuple containing:
        - X (numpy.ndarray): The feature matrix.
        - y (numpy.ndarray): The one-hot encoded labels.
        - encoder (LabelEncoder): The label encoder fitted on the class labels.
    """
    df = pd.read_csv(file_path, sep=sep)
    X = np.array(df.iloc[:, 3:].values.tolist())
    encoder = LabelEncoder()
    y = encoder.fit_transform(df['class'])
    y = to_categorical(y, num_classes=28)
    return X, y, encoder

def create_model(initial_dimensionality, input_shape, num_classes, batch_norm=True, dropout=False):
    """
    Creates a neural network model with decreasing dimensionality.

    Args:
    initial_dimensionality (int): The number of units in the first dense layer.
    input_shape (int): The shape of the input data.
    num_classes (int): The number of output classes.
    batch_norm (bool, optional): Whether to include batch normalization layers. Defaults to True.
    dropout (bool, optional): Whether to include dropout layers. Defaults to False.

    Returns:
    tensorflow.keras.Sequential: The compiled Keras model.
    """
    model = Sequential()
    model.add(layers.Dense(initial_dimensionality, activation='relu', input_shape=(input_shape,)))
    if batch_norm:
        model.add(layers.BatchNormalization())
    if dropout:
        model.add(layers.Dropout(0.1))

    dim = initial_dimensionality
    while dim > 64:
      dim //= 2
      model.add(layers.Dense(dim, activation='relu'))
      if batch_norm:
          model.add(layers.BatchNormalization())
      if dropout:
          model.add(layers.Dropout(0.1))

    model.add(layers.Dense(num_classes, activation='softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

def train_model(model, trainX, trainY, valX, valY, epochs=100, batch_size=32, patience=5):
    """
    Trains the given model using the provided training and validation data.

    Args:
    model (tensorflow.keras.Model): The Keras model to be trained.
    trainX (numpy.ndarray): Training data features.
    trainY (numpy.ndarray): Training data labels.
    valX (numpy.ndarray): Validation data features.
    valY (numpy.ndarray): Validation data labels.
    epochs (int, optional): The number of epochs to train the model. Defaults to 100.
    batch_size (int, optional): The batch size to use during training. Defaults to 32.
    patience (int, optional): The number of epochs with no improvement after which training will be stopped. Defaults to 5.

    Returns:
    tensorflow.keras.callbacks.History: The history object that holds training and validation loss and accuracy values.
    """
    # Define callbacks
    early_stopping = EarlyStopping(monitor='val_accuracy', patience=patience, restore_best_weights=True)
    reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=5, min_lr=1e-5)

    history = model.fit(trainX, trainY,
                        validation_data=(valX, valY),
                        epochs=epochs,
                        batch_size=batch_size,
                        callbacks=[early_stopping, reduce_lr])
    return history

def evaluate_model(model, testX, testY):
    """
    Evaluates the given model using the provided test data.

    Args:
    model (tensorflow.keras.Model): The Keras model to be evaluated.
    testX (numpy.ndarray): Test data features.
    testY (numpy.ndarray): Test data labels.

    Returns:
    tuple: A tuple containing:
        - conf_matrix (numpy.ndarray): The confusion matrix of the test predictions.
        - accuracy (float): The accuracy score of the test predictions.
        - f1 (float): The F1 score of the test predictions.
    """
    test_predictions = np.argmax(model.predict(testX), axis=1)
    test_true = np.argmax(testY, axis=1)
    conf_matrix = confusion_matrix(test_true, test_predictions)
    accuracy = accuracy_score(test_true, test_predictions)
    f1 = f1_score(test_true, test_predictions, average='macro')
    return conf_matrix, accuracy, f1


def save_model(model, file_path):
    """
    Saves the given model to the specified file path.

    Args:
    model (tensorflow.keras.Model): The Keras model to be saved.
    file_path (str): The path where the model will be saved.
    """
    model.save(file_path)

def load_model(file_path):
    """
    Loads a Keras model from the specified file path.

    Args:
    file_path (str): The path from where the model will be loaded.

    Returns:
    tensorflow.keras.Model: The loaded Keras model.
    """
    return tf.keras.models.load_model(file_path)

# %%
import utils.tyiannak_utilities as ut
import IPython


trainX, trainY, _ = load_data('handcrafted_features/train_features.csv')
valX, valY, _ = load_data('handcrafted_features/val_features.csv')

def process_pipeline(model_name, initial_units=2048, batch_norm=True, dropout=False, epochs=100, batch_size=32, patience=5):
    """
    Performs the entire pipeline of processing, training, evaluating, and saving a neural network model.

    Args:
    model_name (str): The name to be used for saving the model and HTML output.
    initial_units (int, optional): The number of units in the first dense layer. Defaults to 2048.
    batch_norm (bool, optional): Whether to include batch normalization layers. Defaults to True.
    dropout (bool, optional): Whether to include dropout layers. Defaults to False.
    epochs (int, optional): The number of epochs to train the model. Defaults to 100.
    batch_size (int, optional): The batch size to use during training. Defaults to 32.
    patience (int, optional): The number of epochs with no improvement after which training will be stopped. Defaults to 5.
    """
    # Create and train the model
    model = create_model(initial_units, trainX.shape[1], 28, batch_norm, dropout)
    train_model(model, trainX, trainY, valX, valY, epochs, batch_size, patience)

    # Create directory for saving models if it doesn't exist
    if not os.path.exists('models/NN'):
        os.makedirs('models/NN')

    # Save the trained model
    model_path = os.path.join('models/NN', model_name+'.keras')
    save_model(model, model_path)

    # Load the saved model
    loaded_model = load_model(model_path)

    # Load test data and evaluate the model
    testX, testY, encoder = load_data('handcrafted_features/test_features.csv')
    conf_matrix, accuracy, f1 = evaluate_model(loaded_model, testX, testY)
    print(f'Test Accuracy: {accuracy:.2f}')
    print(f'Test F1 score: {f1:.2f}')

    # Generate and display HTML report for classification results
    output_html = os.path.join('models/NN', model_name+'.html')
    labels = list(encoder.classes_)
    ut.plotly_classification_results(conf_matrix, labels, output_html)

    return IPython.display.HTML(filename=output_html)

# %%
process_pipeline('2048_150_32_20', 2048, True, False, 150, 32, 20)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
process_pipeline('1024_150_32_20', 1024, True, False, 150, 32, 20)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
process_pipeline('512_150_32_20', 512, True, False, 150, 32, 20)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
process_pipeline('2048_150_32_30', 2048, True, False, 150, 32, 30)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
process_pipeline('2048_150_16_20', 2048, True, False, 150, 16, 20)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
process_pipeline('2048_200_32_20', 2048, True, False, 200, 32, 20)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
process_pipeline('2048_150_32_20', 2048, True, False, 250, 32, 20)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
process_pipeline('512_200_32_20', 512, True, False, 200, 32, 20)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
process_pipeline('512_200_32_30', 512, True, False, 200, 32, 30)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
process_pipeline('512_200_32_20', 512, True, False, 200, 16, 20)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
