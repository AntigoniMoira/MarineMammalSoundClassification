# %% [markdown]
# # **Exploratory Data - Step 1**

# %%
# Importing the drive module from google.colab library
from google.colab import drive

# Mounting the Google Drive to the Colab environment
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Changing the current directory to the 'GitHub' sub-directory "MarineMammalSoundClassification" located in the 'My Drive' directory on Google Drive
# %cd drive/My Drive/GitHub/MarineMammalSoundClassification/data/
# Out:
# /content/drive/.shortcut-targets-by-id/1oJSL58N419Ve8pd0wCvgXEy52hLM2tJN/MarineMammalSoundClassification/data

# %%
# Define the path
path = '/content/drive/My Drive/GitHub/MarineMammalSoundClassification/data/'

# %%
# Import required libraries
import librosa
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
print(os.listdir(path))
# Out:
# ['AtlanticSpottedDolphin', 'BeardedSeal', 'Beluga_WhiteWhale', 'BottlenoseDolphin', 'BowheadWhale', 'ClymeneDolphin', 'CommonDolphin', 'FalseKillerWhale', "Fraser'sDolphin", "Grampus_Risso'sDolphin", 'HarpSeal', 'HumpbackWhale', 'KillerWhale', 'Long_FinnedPilotWhale', 'MelonHeadedWhale', 'Narwhal', 'NorthernRightWhale', 'PantropicalSpottedDolphin', 'RossSeal', 'Rough_ToothedDolphin', 'Short_Finned(Pacific)PilotWhale', 'SouthernRightWhale', 'SpermWhale', 'SpinnerDolphin', 'StripedDolphin', 'Walrus', 'White_beakedDolphin', 'White_sidedDolphin', 'Fin_FinbackWhale', 'LeopardSeal', 'MinkeWhale', 'WeddellSeal']

# %% [markdown]
# ## **Overview of EDA**
#
# During the initial exploratory data analysis (EDA), we aimed to gain a comprehensive understanding of our dataset. The EDA process involved the following steps:
#
# * **Initital Data Exploration**:  We examined the duration and sample rate (sr) of each file, utilizing histograms to visualize and better understand their distributions.
#
# * **Class Distribution Analysis**:  We explored the distribution of files across different classes, employing appropriate visualizations to highlight any imbalances or trends.
#
# * **Statistical Summary**:  We investigated the five-number summary (minimum, first quartile, median, third quartile, and maximum) for each class concerning the files' duration, providing a concise statistical overview of the data.

# %% [markdown]
# ## **Initial Data Exploration**

# %%
# Load each WAV in the data directory, creating a a list of audio data and a list of sample rate using indexes
directory = '//content/drive/My Drive/GitHub/MarineMammalSoundClassification/data'

## Lists to store audio data and sample rates
audio_data_list = []
sample_rate_list = []
duration_list = []

## Recursively iterate over all files in the directory and subdirectories
for root, dirs, files in os.walk(directory):
    for filename in files:
        if filename.endswith('.wav'):
            # Load the WAV file with the original sample rate
            filepath = os.path.join(root, filename)
            try:
                audio_data, sample_rate = librosa.load(filepath, sr=None)

                # Compute file duration
                duration = len(audio_data) / sample_rate

                # Append audio data and sample rate to lists
                audio_data_list.append(audio_data)
                sample_rate_list.append(sample_rate)
                duration_list.append(duration)

                # Print information about the loaded file
                print("File:", filename)
                print("Sample Rate:", sample_rate)
                print("Duration (seconds):", duration)
                print("Shape of Audio Data:", audio_data.shape)
                print()
            except Exception as e:
                print(f"Error loading {filename}: {e}")
# Out:
# Streaming output truncated to the last 5000 lines.
# File: 9750400C.wav
# Sample Rate: 21900
# Duration (seconds): 3.2847488584474887
# Shape of Audio Data: (71936,)
#
# File: 9750400J.wav
# Sample Rate: 21900
# Duration (seconds): 2.6063013698630138
# Shape of Audio Data: (57078,)
#
# File: 9750400V.wav
# Sample Rate: 21900
# Duration (seconds): 4.573835616438356
# Shape of Audio Data: (100167,)
#
# File: 9761900T.wav
# Sample Rate: 21900
# Duration (seconds): 3.0590867579908676
# Shape of Audio Data: (66994,)
#
# File: 97619015.wav
# Sample Rate: 21900
# Duration (seconds): 2.177077625570776
# Shape of Audio Data: (47678,)
#
# File: 9769201Q.wav
# Sample Rate: 21900
# Duration (seconds): 2.0305479452054795
# Shape of Audio Data: (44469,)
#
# File: 54024004.wav
# Sample Rate: 30000
# Duration (seconds): 3.5002
# Shape of Audio Data: (105006,)
#
# File: 54024002.wav
# Sample Rate: 30000
# Duration (seconds): 4.3265
# Shape of Audio Data: (129795,)
#
# File: 54024003.wav
# Sample Rate: 30000
# Duration (seconds): 3.6655
# Shape of Audio Data: (109965,)
#
# File: 54024001.wav
# Sample Rate: 30000
# Duration (seconds): 4.5744
# Shape of Audio Data: (137232,)
#
# File: 54024005.wav
# Sample Rate: 30000
# Duration (seconds): 4.491733333333333
# Shape of Audio Data: (134752,)
#
# File: 54024006.wav
# Sample Rate: 60600
# Duration (seconds): 52.59585808580858
# Shape of Audio Data: (3187309,)
#
# File: 54024007.wav
# Sample Rate: 60600
# Duration (seconds): 41.56693069306931
# Shape of Audio Data: (2518956,)
#
# File: 54024008.wav
# Sample Rate: 60600
# Duration (seconds): 29.473366336633664
# Shape of Audio Data: (1786086,)
#
# File: 54024009.wav
# Sample Rate: 60600
# Duration (seconds): 52.14415841584158
# Shape of Audio Data: (3159936,)
#
# File: 5402400A.wav
# Sample Rate: 60600
# Duration (seconds): 20.561336633663366
# Shape of Audio Data: (1246017,)
#
# File: 5402400B.wav
# Sample Rate: 60600
# Duration (seconds): 69.98128712871286
# Shape of Audio Data: (4240866,)
#
# File: 7500400U.wav
# Sample Rate: 81600
# Duration (seconds): 0.2784313725490196
# Shape of Audio Data: (22720,)
#
# File: 5402400C.wav
# Sample Rate: 60600
# Duration (seconds): 42.449389438943896
# Shape of Audio Data: (2572433,)
#
# File: 7500401F.wav
# Sample Rate: 81600
# Duration (seconds): 2.1253676470588236
# Shape of Audio Data: (173430,)
#
# File: 75004025.wav
# Sample Rate: 81600
# Duration (seconds): 0.7446078431372549
# Shape of Audio Data: (60760,)
#
# File: 7500402E.wav
# Sample Rate: 81600
# Duration (seconds): 1.95125
# Shape of Audio Data: (159222,)
#
# File: 7500402F.wav
# Sample Rate: 81600
# Duration (seconds): 1.9529411764705882
# Shape of Audio Data: (159360,)
#
# File: 7500402I.wav
# Sample Rate: 81600
# Duration (seconds): 1.6862745098039216
# Shape of Audio Data: (137600,)
#
# File: 7500402O.wav
# Sample Rate: 81600
# Duration (seconds): 1.5214705882352941
# Shape of Audio Data: (124152,)
#
# File: 75004033.wav
# Sample Rate: 81600
# Duration (seconds): 1.3861642156862746
# Shape of Audio Data: (113111,)
#
# File: 7500403A.wav
# Sample Rate: 81600
# Duration (seconds): 0.8861764705882353
# Shape of Audio Data: (72312,)
#
# File: 7500403J.wav
# Sample Rate: 81600
# Duration (seconds): 2.251176470588235
# Shape of Audio Data: (183696,)
#
# File: 7500403N.wav
# Sample Rate: 81600
# Duration (seconds): 1.0676470588235294
# Shape of Audio Data: (87120,)
#
# File: 7500502J.wav
# Sample Rate: 80000
# Duration (seconds): 2.2792
# Shape of Audio Data: (182336,)
#
# File: 7500502Q.wav
# Sample Rate: 80000
# Duration (seconds): 1.48
# Shape of Audio Data: (118400,)
#
# File: 7500502R.wav
# Sample Rate: 80000
# Duration (seconds): 1.3838
# Shape of Audio Data: (110704,)
#
# File: 7500502S.wav
# Sample Rate: 80000
# Duration (seconds): 1.7094
# Shape of Audio Data: (136752,)
#
# File: 7500502T.wav
# Sample Rate: 80000
# Duration (seconds): 1.046525
# Shape of Audio Data: (83722,)
#
# File: 7500502U.wav
# Sample Rate: 80000
# Duration (seconds): 2.1094
# Shape of Audio Data: (168752,)
#
# File: 7500502V.wav
# Sample Rate: 80000
# Duration (seconds): 2.035
# Shape of Audio Data: (162800,)
#
# File: 7500502W.wav
# Sample Rate: 80000
# Duration (seconds): 2.0498
# Shape of Audio Data: (163984,)
#
# File: 7500502X.wav
# Sample Rate: 80000
# Duration (seconds): 3.76635
# Shape of Audio Data: (301308,)
#
# File: 7500502Z.wav
# Sample Rate: 80000
# Duration (seconds): 3.49125
# Shape of Audio Data: (279300,)
#
# File: 75005031.wav
# Sample Rate: 80000
# Duration (seconds): 1.2681875
# Shape of Audio Data: (101455,)
#
# File: 75005032.wav
# Sample Rate: 80000
# Duration (seconds): 4.7481
# Shape of Audio Data: (379848,)
#
# File: 75005039.wav
# Sample Rate: 80000
# Duration (seconds): 2.9206625
# Shape of Audio Data: (233653,)
#
# File: 7500503L.wav
# Sample Rate: 80000
# Duration (seconds): 1.8509
# Shape of Audio Data: (148072,)
#
# File: 77028008.wav
# Sample Rate: 81920
# Duration (seconds): 1.0328369140625
# Shape of Audio Data: (84610,)
#
# File: 77028009.wav
# Sample Rate: 81920
# Duration (seconds): 1.1109375
# Shape of Audio Data: (91008,)
#
# File: 7702800U.wav
# Sample Rate: 81920
# Duration (seconds): 0.93984375
# Shape of Audio Data: (76992,)
#
# File: 7702800V.wav
# Sample Rate: 81920
# Duration (seconds): 1.040625
# Shape of Audio Data: (85248,)
#
# File: 7702800X.wav
# Sample Rate: 81920
# Duration (seconds): 1.32890625
# Shape of Audio Data: (108864,)
#
# File: 77028010.wav
# Sample Rate: 81920
# Duration (seconds): 1.25390625
# Shape of Audio Data: (102720,)
#
# File: 77028015.wav
# Sample Rate: 81920
# Duration (seconds): 1.3640625
# Shape of Audio Data: (111744,)
#
# File: 77028017.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 77028018.wav
# Sample Rate: 81920
# Duration (seconds): 1.1953125
# Shape of Audio Data: (97920,)
#
# File: 7702801D.wav
# Sample Rate: 81920
# Duration (seconds): 1.36640625
# Shape of Audio Data: (111936,)
#
# File: 7702801F.wav
# Sample Rate: 81920
# Duration (seconds): 1.29609375
# Shape of Audio Data: (106176,)
#
# File: 7702801K.wav
# Sample Rate: 81920
# Duration (seconds): 0.89765625
# Shape of Audio Data: (73536,)
#
# File: 7702801L.wav
# Sample Rate: 81920
# Duration (seconds): 0.45703125
# Shape of Audio Data: (37440,)
#
# File: 7702801M.wav
# Sample Rate: 81920
# Duration (seconds): 0.09998779296875
# Shape of Audio Data: (8191,)
#
# File: 77034002.wav
# Sample Rate: 81920
# Duration (seconds): 2.5171875
# Shape of Audio Data: (206208,)
#
# File: 77034006.wav
# Sample Rate: 81920
# Duration (seconds): 0.89765625
# Shape of Audio Data: (73536,)
#
# File: 77034008.wav
# Sample Rate: 81920
# Duration (seconds): 0.73828125
# Shape of Audio Data: (60480,)
#
# File: 77034009.wav
# Sample Rate: 81920
# Duration (seconds): 1.10936279296875
# Shape of Audio Data: (90879,)
#
# File: 7703400A.wav
# Sample Rate: 81920
# Duration (seconds): 0.5578125
# Shape of Audio Data: (45696,)
#
# File: 7703400D.wav
# Sample Rate: 81920
# Duration (seconds): 0.83203125
# Shape of Audio Data: (68160,)
#
# File: 7703400B.wav
# Sample Rate: 81920
# Duration (seconds): 1.20234375
# Shape of Audio Data: (98496,)
#
# File: 7703400H.wav
# Sample Rate: 81920
# Duration (seconds): 1.00311279296875
# Shape of Audio Data: (82175,)
#
# File: 7703400J.wav
# Sample Rate: 81920
# Duration (seconds): 0.63123779296875
# Shape of Audio Data: (51711,)
#
# File: 7703400K.wav
# Sample Rate: 81920
# Duration (seconds): 0.97811279296875
# Shape of Audio Data: (80127,)
#
# File: 7703400L.wav
# Sample Rate: 81920
# Duration (seconds): 0.7171875
# Shape of Audio Data: (58752,)
#
# File: 7703400M.wav
# Sample Rate: 81920
# Duration (seconds): 0.72890625
# Shape of Audio Data: (59712,)
#
# File: 7703400O.wav
# Sample Rate: 81920
# Duration (seconds): 0.7546875
# Shape of Audio Data: (61824,)
#
# File: 7703400P.wav
# Sample Rate: 81920
# Duration (seconds): 0.721875
# Shape of Audio Data: (59136,)
#
# File: 7703400Q.wav
# Sample Rate: 81920
# Duration (seconds): 0.75
# Shape of Audio Data: (61440,)
#
# File: 7703400R.wav
# Sample Rate: 81920
# Duration (seconds): 0.609375
# Shape of Audio Data: (49920,)
#
# File: 7703400S.wav
# Sample Rate: 81920
# Duration (seconds): 1.09373779296875
# Shape of Audio Data: (89599,)
#
# File: 7703400U.wav
# Sample Rate: 60600
# Duration (seconds): 65.59049504950495
# Shape of Audio Data: (3974784,)
#
# File: 7703400V.wav
# Sample Rate: 60600
# Duration (seconds): 54.41029702970297
# Shape of Audio Data: (3297264,)
#
# File: 91012009.wav
# Sample Rate: 81920
# Duration (seconds): 0.94530029296875
# Shape of Audio Data: (77439,)
#
# File: 9101200B.wav
# Sample Rate: 81920
# Duration (seconds): 1.13096923828125
# Shape of Audio Data: (92649,)
#
# File: 91012006.wav
# Sample Rate: 81920
# Duration (seconds): 0.94530029296875
# Shape of Audio Data: (77439,)
#
# File: 91012003.wav
# Sample Rate: 81920
# Duration (seconds): 0.98885498046875
# Shape of Audio Data: (81007,)
#
# File: 9101200K.wav
# Sample Rate: 81920
# Duration (seconds): 1.04818115234375
# Shape of Audio Data: (85867,)
#
# File: 91012007.wav
# Sample Rate: 81920
# Duration (seconds): 0.94530029296875
# Shape of Audio Data: (77439,)
#
# File: 9101200C.wav
# Sample Rate: 81920
# Duration (seconds): 1.89061279296875
# Shape of Audio Data: (154879,)
#
# File: 9101200I.wav
# Sample Rate: 81920
# Duration (seconds): 1.89061279296875
# Shape of Audio Data: (154879,)
#
# File: 9101201E.wav
# Sample Rate: 81920
# Duration (seconds): 0.60311279296875
# Shape of Audio Data: (49407,)
#
# File: 9101200U.wav
# Sample Rate: 81920
# Duration (seconds): 0.94530029296875
# Shape of Audio Data: (77439,)
#
# File: 91012016.wav
# Sample Rate: 81920
# Duration (seconds): 1.36854248046875
# Shape of Audio Data: (112111,)
#
# File: 91012018.wav
# Sample Rate: 81920
# Duration (seconds): 0.94530029296875
# Shape of Audio Data: (77439,)
#
# File: 9101201C.wav
# Sample Rate: 81920
# Duration (seconds): 1.3715087890625
# Shape of Audio Data: (112354,)
#
# File: 9101201F.wav
# Sample Rate: 81920
# Duration (seconds): 1.8547119140625
# Shape of Audio Data: (151938,)
#
# File: 9101201I.wav
# Sample Rate: 81920
# Duration (seconds): 0.96568603515625
# Shape of Audio Data: (79109,)
#
# File: 9101201L.wav
# Sample Rate: 81920
# Duration (seconds): 1.14310302734375
# Shape of Audio Data: (93643,)
#
# File: 9101201T.wav
# Sample Rate: 81920
# Duration (seconds): 0.61453857421875
# Shape of Audio Data: (50343,)
#
# File: 9101201Z.wav
# Sample Rate: 81920
# Duration (seconds): 1.12498779296875
# Shape of Audio Data: (92159,)
#
# File: 91012022.wav
# Sample Rate: 81920
# Duration (seconds): 0.85311279296875
# Shape of Audio Data: (69887,)
#
# File: 91012024.wav
# Sample Rate: 81920
# Duration (seconds): 0.58436279296875
# Shape of Audio Data: (47871,)
#
# File: 91012026.wav
# Sample Rate: 81920
# Duration (seconds): 0.43280029296875
# Shape of Audio Data: (35455,)
#
# File: 9101202B.wav
# Sample Rate: 81920
# Duration (seconds): 1.80936279296875
# Shape of Audio Data: (148223,)
#
# File: 9101202C.wav
# Sample Rate: 81920
# Duration (seconds): 0.84061279296875
# Shape of Audio Data: (68863,)
#
# File: 9101202E.wav
# Sample Rate: 81920
# Duration (seconds): 0.6790771484375
# Shape of Audio Data: (55630,)
#
# File: 9101202G.wav
# Sample Rate: 81920
# Duration (seconds): 0.39107666015625
# Shape of Audio Data: (32037,)
#
# File: 9101202R.wav
# Sample Rate: 81920
# Duration (seconds): 0.1485107421875
# Shape of Audio Data: (12166,)
#
# File: 9101202T.wav
# Sample Rate: 81920
# Duration (seconds): 0.21710205078125
# Shape of Audio Data: (17785,)
#
# File: 9101202S.wav
# Sample Rate: 81920
# Duration (seconds): 0.18729248046875
# Shape of Audio Data: (15343,)
#
# File: 9101202U.wav
# Sample Rate: 81920
# Duration (seconds): 0.12445068359375
# Shape of Audio Data: (10195,)
#
# File: 91012039.wav
# Sample Rate: 81920
# Duration (seconds): 0.19029541015625
# Shape of Audio Data: (15589,)
#
# File: 91012037.wav
# Sample Rate: 81920
# Duration (seconds): 0.19317626953125
# Shape of Audio Data: (15825,)
#
# File: 9101203D.wav
# Sample Rate: 81920
# Duration (seconds): 0.89986572265625
# Shape of Audio Data: (73717,)
#
# File: 9101203I.wav
# Sample Rate: 81920
# Duration (seconds): 0.19322509765625
# Shape of Audio Data: (15829,)
#
# File: 9101203J.wav
# Sample Rate: 81920
# Duration (seconds): 0.28258056640625
# Shape of Audio Data: (23149,)
#
# File: 9101203N.wav
# Sample Rate: 81920
# Duration (seconds): 0.25130615234375
# Shape of Audio Data: (20587,)
#
# File: 9101203S.wav
# Sample Rate: 81920
# Duration (seconds): 0.20859375
# Shape of Audio Data: (17088,)
#
# File: 9101203U.wav
# Sample Rate: 81920
# Duration (seconds): 0.0536865234375
# Shape of Audio Data: (4398,)
#
# File: 9101203V.wav
# Sample Rate: 81920
# Duration (seconds): 0.15721435546875
# Shape of Audio Data: (12879,)
#
# File: 9101203X.wav
# Sample Rate: 81920
# Duration (seconds): 0.06617431640625
# Shape of Audio Data: (5421,)
#
# File: 91012040.wav
# Sample Rate: 81920
# Duration (seconds): 0.1628173828125
# Shape of Audio Data: (13338,)
#
# File: 91012041.wav
# Sample Rate: 81920
# Duration (seconds): 0.08214111328125
# Shape of Audio Data: (6729,)
#
# File: 91012042.wav
# Sample Rate: 81920
# Duration (seconds): 0.1013671875
# Shape of Audio Data: (8304,)
#
# File: 91012043.wav
# Sample Rate: 81920
# Duration (seconds): 0.12108154296875
# Shape of Audio Data: (9919,)
#
# File: 91012044.wav
# Sample Rate: 81920
# Duration (seconds): 0.10880126953125
# Shape of Audio Data: (8913,)
#
# File: 91012045.wav
# Sample Rate: 81920
# Duration (seconds): 0.065625
# Shape of Audio Data: (5376,)
#
# File: 91012046.wav
# Sample Rate: 81920
# Duration (seconds): 0.15498046875
# Shape of Audio Data: (12696,)
#
# File: 91012047.wav
# Sample Rate: 81920
# Duration (seconds): 0.2443359375
# Shape of Audio Data: (20016,)
#
# File: 91012048.wav
# Sample Rate: 81920
# Duration (seconds): 0.163916015625
# Shape of Audio Data: (13428,)
#
# File: 91012049.wav
# Sample Rate: 81920
# Duration (seconds): 0.163916015625
# Shape of Audio Data: (13428,)
#
# File: 9101204C.wav
# Sample Rate: 81920
# Duration (seconds): 0.2281494140625
# Shape of Audio Data: (18690,)
#
# File: 9101204A.wav
# Sample Rate: 81920
# Duration (seconds): 0.1468505859375
# Shape of Audio Data: (12030,)
#
# File: 9101204D.wav
# Sample Rate: 81920
# Duration (seconds): 0.10078125
# Shape of Audio Data: (8256,)
#
# File: 9101204F.wav
# Sample Rate: 60600
# Duration (seconds): 17.646732673267326
# Shape of Audio Data: (1069392,)
#
# File: 9101204H.wav
# Sample Rate: 60600
# Duration (seconds): 11.078547854785478
# Shape of Audio Data: (671360,)
#
# File: 9101204I.wav
# Sample Rate: 60600
# Duration (seconds): 27.69108910891089
# Shape of Audio Data: (1678080,)
#
# File: 9101204J.wav
# Sample Rate: 60600
# Duration (seconds): 6.49463696369637
# Shape of Audio Data: (393575,)
#
# File: 9101204K.wav
# Sample Rate: 60600
# Duration (seconds): 13.347772277227723
# Shape of Audio Data: (808875,)
#
# File: 9101204L.wav
# Sample Rate: 60600
# Duration (seconds): 6.406930693069307
# Shape of Audio Data: (388260,)
#
# File: 9101204M.wav
# Sample Rate: 60600
# Duration (seconds): 6.940841584158416
# Shape of Audio Data: (420615,)
#
# File: 9101204N.wav
# Sample Rate: 60600
# Duration (seconds): 8.021930693069306
# Shape of Audio Data: (486129,)
#
# File: 9101204O.wav
# Sample Rate: 60600
# Duration (seconds): 4.6112211221122115
# Shape of Audio Data: (279440,)
#
# File: 9101204Q.wav
# Sample Rate: 60600
# Duration (seconds): 16.404356435643564
# Shape of Audio Data: (994104,)
#
# File: 9101204P.wav
# Sample Rate: 60600
# Duration (seconds): 5.313531353135313
# Shape of Audio Data: (322000,)
#
# File: 68002006.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 68002007.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 6800200B.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 68002008.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 6800200A.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 6800200C.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 6800200D.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 6800200E.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 6800200F.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 6800200G.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 6804000C.wav
# Sample Rate: 60600
# Duration (seconds): 5.861386138613861
# Shape of Audio Data: (355200,)
#
# File: 6804000D.wav
# Sample Rate: 60600
# Duration (seconds): 5.861386138613861
# Shape of Audio Data: (355200,)
#
# File: 6804000Q.wav
# Sample Rate: 60600
# Duration (seconds): 1.196039603960396
# Shape of Audio Data: (72480,)
#
# File: 6804000S.wav
# Sample Rate: 60600
# Duration (seconds): 3.1794059405940596
# Shape of Audio Data: (192672,)
#
# File: 75014001.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 75014002.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 75014003.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 75014005.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 75014006.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 75014007.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 75014009.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 7501400A.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 7501400B.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 7501400C.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 7501400F.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 7501400G.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 7501400I.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 7501400J.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 7501400K.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 7501400L.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 7501400M.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 7501400N.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 7501400O.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 7501400Q.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 7501400R.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 7501400S.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 7501400T.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 7501400U.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 7501400V.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 7501400W.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 7501400X.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 7501400Y.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 7501400Z.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 75014010.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 75014011.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 75014012.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 75014014.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 75014015.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 75014016.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 75014017.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 5601601O.wav
# Sample Rate: 8000
# Duration (seconds): 1.450875
# Shape of Audio Data: (11607,)
#
# File: 56017007.wav
# Sample Rate: 10200
# Duration (seconds): 3.6573529411764705
# Shape of Audio Data: (37305,)
#
# File: 5601700B.wav
# Sample Rate: 10200
# Duration (seconds): 1.3508823529411764
# Shape of Audio Data: (13779,)
#
# File: 56017008.wav
# Sample Rate: 10200
# Duration (seconds): 1.6329411764705883
# Shape of Audio Data: (16656,)
#
# File: 5601700F.wav
# Sample Rate: 10200
# Duration (seconds): 0.8734313725490196
# Shape of Audio Data: (8909,)
#
# File: 5601700O.wav
# Sample Rate: 10200
# Duration (seconds): 2.7754901960784313
# Shape of Audio Data: (28310,)
#
# File: 5601700U.wav
# Sample Rate: 10200
# Duration (seconds): 0.8766666666666667
# Shape of Audio Data: (8942,)
#
# File: 5601700V.wav
# Sample Rate: 10200
# Duration (seconds): 0.6864705882352942
# Shape of Audio Data: (7002,)
#
# File: 56017010.wav
# Sample Rate: 10200
# Duration (seconds): 1.180686274509804
# Shape of Audio Data: (12043,)
#
# File: 56017018.wav
# Sample Rate: 10200
# Duration (seconds): 0.5933333333333334
# Shape of Audio Data: (6052,)
#
# File: 56018001.wav
# Sample Rate: 8000
# Duration (seconds): 1.636375
# Shape of Audio Data: (13091,)
#
# File: 56018002.wav
# Sample Rate: 8000
# Duration (seconds): 3.895
# Shape of Audio Data: (31160,)
#
# File: 56018004.wav
# Sample Rate: 8000
# Duration (seconds): 2.243625
# Shape of Audio Data: (17949,)
#
# File: 56025001.wav
# Sample Rate: 10200
# Duration (seconds): 2.2668627450980394
# Shape of Audio Data: (23122,)
#
# File: 56018003.wav
# Sample Rate: 8000
# Duration (seconds): 1.867125
# Shape of Audio Data: (14937,)
#
# File: 56025006.wav
# Sample Rate: 10200
# Duration (seconds): 1.435686274509804
# Shape of Audio Data: (14644,)
#
# File: 56025009.wav
# Sample Rate: 10200
# Duration (seconds): 2.901764705882353
# Shape of Audio Data: (29598,)
#
# File: 5602500N.wav
# Sample Rate: 10200
# Duration (seconds): 1.8031372549019609
# Shape of Audio Data: (18392,)
#
# File: 56026002.wav
# Sample Rate: 10200
# Duration (seconds): 4.5678431372549015
# Shape of Audio Data: (46592,)
#
# File: 56026007.wav
# Sample Rate: 10200
# Duration (seconds): 2.851372549019608
# Shape of Audio Data: (29084,)
#
# File: 5602600A.wav
# Sample Rate: 10200
# Duration (seconds): 2.6947058823529413
# Shape of Audio Data: (27486,)
#
# File: 56028001.wav
# Sample Rate: 10200
# Duration (seconds): 2.067745098039216
# Shape of Audio Data: (21091,)
#
# File: 59003001.wav
# Sample Rate: 10000
# Duration (seconds): 2.1824
# Shape of Audio Data: (21824,)
#
# File: 5900300A.wav
# Sample Rate: 10000
# Duration (seconds): 2.1576
# Shape of Audio Data: (21576,)
#
# File: 5900300B.wav
# Sample Rate: 10000
# Duration (seconds): 2.1824
# Shape of Audio Data: (21824,)
#
# File: 5900300G.wav
# Sample Rate: 10000
# Duration (seconds): 2.108
# Shape of Audio Data: (21080,)
#
# File: 5900300J.wav
# Sample Rate: 10000
# Duration (seconds): 2.3808
# Shape of Audio Data: (23808,)
#
# File: 5900300M.wav
# Sample Rate: 10000
# Duration (seconds): 2.406
# Shape of Audio Data: (24060,)
#
# File: 5900300N.wav
# Sample Rate: 10000
# Duration (seconds): 2.4552
# Shape of Audio Data: (24552,)
#
# File: 5900300O.wav
# Sample Rate: 10000
# Duration (seconds): 2.0584
# Shape of Audio Data: (20584,)
#
# File: 59004002.wav
# Sample Rate: 14900
# Duration (seconds): 2.2475167785234897
# Shape of Audio Data: (33488,)
#
# File: 59004005.wav
# Sample Rate: 14900
# Duration (seconds): 2.2230872483221478
# Shape of Audio Data: (33124,)
#
# File: 59005004.wav
# Sample Rate: 10000
# Duration (seconds): 2.0706
# Shape of Audio Data: (20706,)
#
# File: 59005002.wav
# Sample Rate: 10000
# Duration (seconds): 2.9274
# Shape of Audio Data: (29274,)
#
# File: 70014002.wav
# Sample Rate: 20480
# Duration (seconds): 1.17890625
# Shape of Audio Data: (24144,)
#
# File: 7001800B.wav
# Sample Rate: 10000
# Duration (seconds): 2.1161
# Shape of Audio Data: (21161,)
#
# File: 7001800H.wav
# Sample Rate: 10000
# Duration (seconds): 1.666
# Shape of Audio Data: (16660,)
#
# File: 7001800T.wav
# Sample Rate: 10000
# Duration (seconds): 2.0335
# Shape of Audio Data: (20335,)
#
# File: 7001800U.wav
# Sample Rate: 10000
# Duration (seconds): 2.0602
# Shape of Audio Data: (20602,)
#
# File: 74003001.wav
# Sample Rate: 5120
# Duration (seconds): 1.5
# Shape of Audio Data: (7680,)
#
# File: 74003002.wav
# Sample Rate: 5120
# Duration (seconds): 1.5
# Shape of Audio Data: (7680,)
#
# File: 74003004.wav
# Sample Rate: 5120
# Duration (seconds): 1.5
# Shape of Audio Data: (7680,)
#
# File: 81013007.wav
# Sample Rate: 14900
# Duration (seconds): 2.7256375838926172
# Shape of Audio Data: (40612,)
#
# File: 81014029.wav
# Sample Rate: 14900
# Duration (seconds): 3.8871140939597315
# Shape of Audio Data: (57918,)
#
# File: 8101402F.wav
# Sample Rate: 14900
# Duration (seconds): 2.3291275167785237
# Shape of Audio Data: (34704,)
#
# File: 8101402I.wav
# Sample Rate: 14900
# Duration (seconds): 2.255436241610738
# Shape of Audio Data: (33606,)
#
# File: 81014033.wav
# Sample Rate: 14900
# Duration (seconds): 2.4186577181208055
# Shape of Audio Data: (36038,)
#
# File: 81014034.wav
# Sample Rate: 14900
# Duration (seconds): 3.0024832214765103
# Shape of Audio Data: (44737,)
#
# File: 81014036.wav
# Sample Rate: 14900
# Duration (seconds): 3.525436241610738
# Shape of Audio Data: (52529,)
#
# File: 8101403B.wav
# Sample Rate: 14900
# Duration (seconds): 2.5493959731543625
# Shape of Audio Data: (37986,)
#
# File: 8101403Z.wav
# Sample Rate: 14900
# Duration (seconds): 2.157181208053691
# Shape of Audio Data: (32142,)
#
# File: 81014040.wav
# Sample Rate: 14900
# Duration (seconds): 1.993758389261745
# Shape of Audio Data: (29707,)
#
# File: 81015002.wav
# Sample Rate: 14900
# Duration (seconds): 2.61255033557047
# Shape of Audio Data: (38927,)
#
# File: 81015005.wav
# Sample Rate: 14900
# Duration (seconds): 3.20006711409396
# Shape of Audio Data: (47681,)
#
# File: 64005009.wav
# Sample Rate: 55500
# Duration (seconds): 1.949009009009009
# Shape of Audio Data: (108170,)
#
# File: 6400500D.wav
# Sample Rate: 55500
# Duration (seconds): 1.599153153153153
# Shape of Audio Data: (88753,)
#
# File: 64005015.wav
# Sample Rate: 55500
# Duration (seconds): 1.93790990990991
# Shape of Audio Data: (107554,)
#
# File: 64005016.wav
# Sample Rate: 55500
# Duration (seconds): 2.7996036036036034
# Shape of Audio Data: (155378,)
#
# File: 64005017.wav
# Sample Rate: 55500
# Duration (seconds): 1.8454774774774774
# Shape of Audio Data: (102424,)
#
# File: 64005018.wav
# Sample Rate: 55500
# Duration (seconds): 2.5027747747747746
# Shape of Audio Data: (138904,)
#
# File: 84021003.wav
# Sample Rate: 40960
# Duration (seconds): 2.8359375
# Shape of Audio Data: (116160,)
#
# File: 64005019.wav
# Sample Rate: 55500
# Duration (seconds): 1.5475315315315314
# Shape of Audio Data: (85888,)
#
# File: 6400501A.wav
# Sample Rate: 55500
# Duration (seconds): 3.2643243243243245
# Shape of Audio Data: (181170,)
#
# File: 6400501B.wav
# Sample Rate: 55500
# Duration (seconds): 4.244054054054054
# Shape of Audio Data: (235545,)
#
# File: 6400501C.wav
# Sample Rate: 55500
# Duration (seconds): 7.272432432432432
# Shape of Audio Data: (403620,)
#
# File: 6400501D.wav
# Sample Rate: 55500
# Duration (seconds): 3.1083783783783785
# Shape of Audio Data: (172515,)
#
# File: 90028007.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 90028008.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 90028009.wav
# Sample Rate: 81920
# Duration (seconds): 0.708984375
# Shape of Audio Data: (58080,)
#
# File: 9002800A.wav
# Sample Rate: 81920
# Duration (seconds): 1.41796875
# Shape of Audio Data: (116160,)
#
# File: 9002800F.wav
# Sample Rate: 81920
# Duration (seconds): 0.710498046875
# Shape of Audio Data: (58204,)
#
# File: 9004400O.wav
# Sample Rate: 60600
# Duration (seconds): 1.194983498349835
# Shape of Audio Data: (72416,)
#
# File: 9004400Y.wav
# Sample Rate: 60600
# Duration (seconds): 1.1178877887788778
# Shape of Audio Data: (67744,)
#
# File: 9004401S.wav
# Sample Rate: 60600
# Duration (seconds): 1.0518151815181518
# Shape of Audio Data: (63740,)
#
# File: 9004401T.wav
# Sample Rate: 60600
# Duration (seconds): 0.936963696369637
# Shape of Audio Data: (56780,)
#
# File: 9004401U.wav
# Sample Rate: 60600
# Duration (seconds): 1.0043894389438943
# Shape of Audio Data: (60866,)
#
# File: 90058068.wav
# Sample Rate: 60600
# Duration (seconds): 1.8343234323432343
# Shape of Audio Data: (111160,)
#
# File: 9004401V.wav
# Sample Rate: 60600
# Duration (seconds): 0.9920792079207921
# Shape of Audio Data: (60120,)
#
# File: 9005807N.wav
# Sample Rate: 60600
# Duration (seconds): 1.0592739273927392
# Shape of Audio Data: (64192,)
#
# File: 9004401W.wav
# Sample Rate: 60600
# Duration (seconds): 1.2575907590759077
# Shape of Audio Data: (76210,)
#
# File: 9005807O.wav
# Sample Rate: 60600
# Duration (seconds): 1.3843894389438944
# Shape of Audio Data: (83894,)
#
# File: 9004401X.wav
# Sample Rate: 60600
# Duration (seconds): 0.9896039603960396
# Shape of Audio Data: (59970,)
#
# File: 9005807P.wav
# Sample Rate: 60600
# Duration (seconds): 1.4417161716171618
# Shape of Audio Data: (87368,)
#
# File: 9004401Y.wav
# Sample Rate: 60600
# Duration (seconds): 0.8207590759075908
# Shape of Audio Data: (49738,)
#
# File: 9004401Z.wav
# Sample Rate: 60600
# Duration (seconds): 0.788976897689769
# Shape of Audio Data: (47812,)
#
# File: 90044021.wav
# Sample Rate: 60600
# Duration (seconds): 0.9884983498349835
# Shape of Audio Data: (59903,)
#
# File: 93001008.wav
# Sample Rate: 60600
# Duration (seconds): 1.8402640264026402
# Shape of Audio Data: (111520,)
#
# File: 9300100D.wav
# Sample Rate: 60600
# Duration (seconds): 1.2448844884488448
# Shape of Audio Data: (75440,)
#
# File: 9300100H.wav
# Sample Rate: 60600
# Duration (seconds): 0.273003300330033
# Shape of Audio Data: (16544,)
#
# File: 94006003.wav
# Sample Rate: 80000
# Duration (seconds): 0.7107
# Shape of Audio Data: (56856,)
#
# File: 94006004.wav
# Sample Rate: 80000
# Duration (seconds): 0.726375
# Shape of Audio Data: (58110,)
#
# File: 94006005.wav
# Sample Rate: 80000
# Duration (seconds): 0.304
# Shape of Audio Data: (24320,)
#
# File: 94008006.wav
# Sample Rate: 80000
# Duration (seconds): 1.5799
# Shape of Audio Data: (126392,)
#
# File: 94008008.wav
# Sample Rate: 80000
# Duration (seconds): 0.6138125
# Shape of Audio Data: (49105,)
#
# File: 9400800U.wav
# Sample Rate: 80000
# Duration (seconds): 0.883575
# Shape of Audio Data: (70686,)
#
# File: 9400800V.wav
# Sample Rate: 80000
# Duration (seconds): 0.4218
# Shape of Audio Data: (33744,)
#
# File: 9400800W.wav
# Sample Rate: 80000
# Duration (seconds): 0.9933
# Shape of Audio Data: (79464,)
#
# File: 94008010.wav
# Sample Rate: 80000
# Duration (seconds): 0.372
# Shape of Audio Data: (29760,)
#
# File: 94008011.wav
# Sample Rate: 80000
# Duration (seconds): 0.6938
# Shape of Audio Data: (55504,)
#
# File: 94008017.wav
# Sample Rate: 80000
# Duration (seconds): 1.0161
# Shape of Audio Data: (81288,)
#
# File: 9400801H.wav
# Sample Rate: 80000
# Duration (seconds): 0.8333125
# Shape of Audio Data: (66665,)
#
# File: 9400801I.wav
# Sample Rate: 80000
# Duration (seconds): 0.4978
# Shape of Audio Data: (39824,)
#
# File: 9400801R.wav
# Sample Rate: 80000
# Duration (seconds): 1.2586875
# Shape of Audio Data: (100695,)
#
# File: 9400801U.wav
# Sample Rate: 80000
# Duration (seconds): 1.085
# Shape of Audio Data: (86800,)
#
# File: 9400802D.wav
# Sample Rate: 80000
# Duration (seconds): 1.032
# Shape of Audio Data: (82560,)
#
# File: 9400805S.wav
# Sample Rate: 148100
# Duration (seconds): 15.293450371370696
# Shape of Audio Data: (2264960,)
#
# File: 9400807P.wav
# Sample Rate: 80000
# Duration (seconds): 1.1846
# Shape of Audio Data: (94768,)
#
# File: 94008060.wav
# Sample Rate: 148100
# Duration (seconds): 15.004733288318704
# Shape of Audio Data: (2222201,)
#
# File: 9400807Q.wav
# Sample Rate: 80000
# Duration (seconds): 0.775125
# Shape of Audio Data: (62010,)
#
# File: 9400807R.wav
# Sample Rate: 80000
# Duration (seconds): 0.876375
# Shape of Audio Data: (70110,)
#
# File: 9400807S.wav
# Sample Rate: 80000
# Duration (seconds): 1.011375
# Shape of Audio Data: (80910,)
#
# File: 9400807T.wav
# Sample Rate: 80000
# Duration (seconds): 0.8506375
# Shape of Audio Data: (68051,)
#
# File: 9400807U.wav
# Sample Rate: 80000
# Duration (seconds): 0.8808875
# Shape of Audio Data: (70471,)
#
# File: 9400807V.wav
# Sample Rate: 80000
# Duration (seconds): 0.731075
# Shape of Audio Data: (58486,)
#
# File: 9400807X.wav
# Sample Rate: 80000
# Duration (seconds): 0.6034625
# Shape of Audio Data: (48277,)
#
# File: 9400807Y.wav
# Sample Rate: 80000
# Duration (seconds): 0.8471125
# Shape of Audio Data: (67769,)
#
# File: 94008081.wav
# Sample Rate: 80000
# Duration (seconds): 1.0412
# Shape of Audio Data: (83296,)
#
# File: 94008082.wav
# Sample Rate: 80000
# Duration (seconds): 0.7785125
# Shape of Audio Data: (62281,)
#
# File: 94008087.wav
# Sample Rate: 80000
# Duration (seconds): 0.7315875
# Shape of Audio Data: (58527,)
#
# File: 94008085.wav
# Sample Rate: 80000
# Duration (seconds): 0.85125
# Shape of Audio Data: (68100,)
#
# File: 66002A02.wav
# Sample Rate: 30000
# Duration (seconds): 1.3835
# Shape of Audio Data: (41505,)
#
# File: 66002A03.wav
# Sample Rate: 16000
# Duration (seconds): 1.924875
# Shape of Audio Data: (30798,)
#
# File: 66002A01.wav
# Sample Rate: 30000
# Duration (seconds): 3.334966666666667
# Shape of Audio Data: (100049,)
#
# File: 66002A04.wav
# Sample Rate: 16000
# Duration (seconds): 2.201875
# Shape of Audio Data: (35230,)
#
# File: 66002A05.wav
# Sample Rate: 16000
# Duration (seconds): 1.7759375
# Shape of Audio Data: (28415,)
#
# File: 66034001.wav
# Sample Rate: 30000
# Duration (seconds): 4.904866666666667
# Shape of Audio Data: (147146,)
#
# File: 66034002.wav
# Sample Rate: 30000
# Duration (seconds): 3.9959666666666664
# Shape of Audio Data: (119879,)
#
# File: 66034004.wav
# Sample Rate: 30000
# Duration (seconds): 3.7481
# Shape of Audio Data: (112443,)
#
# File: 66084001.wav
# Sample Rate: 20000
# Duration (seconds): 4.6257
# Shape of Audio Data: (92514,)
#
# File: 66084002.wav
# Sample Rate: 20000
# Duration (seconds): 3.0699
# Shape of Audio Data: (61398,)
#
# File: 66084003.wav
# Sample Rate: 20000
# Duration (seconds): 3.2585
# Shape of Audio Data: (65170,)
#
# File: 66084004.wav
# Sample Rate: 20000
# Duration (seconds): 2.65825
# Shape of Audio Data: (53165,)
#
# File: 66084005.wav
# Sample Rate: 20000
# Duration (seconds): 4.3561
# Shape of Audio Data: (87122,)
#
# File: 66084006.wav
# Sample Rate: 20000
# Duration (seconds): 2.5382
# Shape of Audio Data: (50764,)
#
# File: 66084007.wav
# Sample Rate: 20000
# Duration (seconds): 2.8812
# Shape of Audio Data: (57624,)
#
# File: 66084008.wav
# Sample Rate: 20000
# Duration (seconds): 3.9102
# Shape of Audio Data: (78204,)
#
# File: 66084009.wav
# Sample Rate: 20000
# Duration (seconds): 2.0923
# Shape of Audio Data: (41846,)
#
# File: 6608400A.wav
# Sample Rate: 20000
# Duration (seconds): 2.6068
# Shape of Audio Data: (52136,)
#
# File: 6608400B.wav
# Sample Rate: 20000
# Duration (seconds): 2.38385
# Shape of Audio Data: (47677,)
#
# File: 6608400C.wav
# Sample Rate: 20000
# Duration (seconds): 3.1213
# Shape of Audio Data: (62426,)
#
# File: 6608400D.wav
# Sample Rate: 20000
# Duration (seconds): 2.04085
# Shape of Audio Data: (40817,)
#
# File: 6608400E.wav
# Sample Rate: 20000
# Duration (seconds): 2.5382
# Shape of Audio Data: (50764,)
#
# File: 6608400F.wav
# Sample Rate: 20000
# Duration (seconds): 2.55535
# Shape of Audio Data: (51107,)
#
# File: 6608500A.wav
# Sample Rate: 20000
# Duration (seconds): 2.6796
# Shape of Audio Data: (53592,)
#
# File: 6608500B.wav
# Sample Rate: 20000
# Duration (seconds): 3.35965
# Shape of Audio Data: (67193,)
#
# File: 6608500C.wav
# Sample Rate: 20000
# Duration (seconds): 4.25285
# Shape of Audio Data: (85057,)
#
# File: 6608500D.wav
# Sample Rate: 20000
# Duration (seconds): 3.05515
# Shape of Audio Data: (61103,)
#
# File: 6608500E.wav
# Sample Rate: 20000
# Duration (seconds): 2.26345
# Shape of Audio Data: (45269,)
#
# File: 6608500F.wav
# Sample Rate: 20000
# Duration (seconds): 2.89275
# Shape of Audio Data: (57855,)
#
# File: 6608500G.wav
# Sample Rate: 20000
# Duration (seconds): 2.8623
# Shape of Audio Data: (57246,)
#
# File: 6608500H.wav
# Sample Rate: 20000
# Duration (seconds): 2.97395
# Shape of Audio Data: (59479,)
#
# File: 6608500I.wav
# Sample Rate: 20000
# Duration (seconds): 3.52205
# Shape of Audio Data: (70441,)
#
# File: 6608500K.wav
# Sample Rate: 20000
# Duration (seconds): 2.9841
# Shape of Audio Data: (59682,)
#
# File: 6608500J.wav
# Sample Rate: 20000
# Duration (seconds): 5.06485
# Shape of Audio Data: (101297,)
#
# File: 6608500L.wav
# Sample Rate: 20000
# Duration (seconds): 3.64385
# Shape of Audio Data: (72877,)
#
# File: 6608500M.wav
# Sample Rate: 20000
# Duration (seconds): 3.35965
# Shape of Audio Data: (67193,)
#
# File: 6608500N.wav
# Sample Rate: 20000
# Duration (seconds): 2.3142
# Shape of Audio Data: (46284,)
#
# File: 6608500O.wav
# Sample Rate: 20000
# Duration (seconds): 4.2224
# Shape of Audio Data: (84448,)
#
# File: 6608500P.wav
# Sample Rate: 20000
# Duration (seconds): 3.37995
# Shape of Audio Data: (67599,)
#
# File: 6608500Q.wav
# Sample Rate: 20000
# Duration (seconds): 3.3698
# Shape of Audio Data: (67396,)
#
# File: 6608500R.wav
# Sample Rate: 20000
# Duration (seconds): 3.1668
# Shape of Audio Data: (63336,)
#
# File: 6608500S.wav
# Sample Rate: 20000
# Duration (seconds): 2.9232
# Shape of Audio Data: (58464,)
#
# File: 6608900A.wav
# Sample Rate: 20000
# Duration (seconds): 3.0951
# Shape of Audio Data: (61902,)
#
# File: 6608900B.wav
# Sample Rate: 20000
# Duration (seconds): 3.2066
# Shape of Audio Data: (64132,)
#
# File: 6608900C.wav
# Sample Rate: 20000
# Duration (seconds): 3.40605
# Shape of Audio Data: (68121,)
#
# File: 6608900D.wav
# Sample Rate: 20000
# Duration (seconds): 3.0015
# Shape of Audio Data: (60030,)
#
# File: 6608900E.wav
# Sample Rate: 20000
# Duration (seconds): 5.1417
# Shape of Audio Data: (102834,)
#
# File: 6608900F.wav
# Sample Rate: 20000
# Duration (seconds): 4.29345
# Shape of Audio Data: (85869,)
#
# File: 6608900G.wav
# Sample Rate: 20000
# Duration (seconds): 4.0716
# Shape of Audio Data: (81432,)
#
# File: 6608900H.wav
# Sample Rate: 20000
# Duration (seconds): 5.65065
# Shape of Audio Data: (113013,)
#
# File: 85013002.wav
# Sample Rate: 81920
# Duration (seconds): 1.89061279296875
# Shape of Audio Data: (154879,)
#
# File: 85013007.wav
# Sample Rate: 81920
# Duration (seconds): 1.89061279296875
# Shape of Audio Data: (154879,)
#
# File: 85013009.wav
# Sample Rate: 81920
# Duration (seconds): 1.89061279296875
# Shape of Audio Data: (154879,)
#
# File: 8501300A.wav
# Sample Rate: 81920
# Duration (seconds): 1.89061279296875
# Shape of Audio Data: (154879,)
#
# File: 8501300D.wav
# Sample Rate: 81920
# Duration (seconds): 1.89061279296875
# Shape of Audio Data: (154879,)
#
# File: 8501300E.wav
# Sample Rate: 81920
# Duration (seconds): 1.89061279296875
# Shape of Audio Data: (154879,)
#
# File: 8501300H.wav
# Sample Rate: 81920
# Duration (seconds): 1.21873779296875
# Shape of Audio Data: (99839,)
#
# File: 8501300I.wav
# Sample Rate: 81920
# Duration (seconds): 1.03828125
# Shape of Audio Data: (85056,)
#
# File: 8501300J.wav
# Sample Rate: 81920
# Duration (seconds): 1.67811279296875
# Shape of Audio Data: (137471,)
#
# File: 8501300K.wav
# Sample Rate: 81920
# Duration (seconds): 1.14686279296875
# Shape of Audio Data: (93951,)
#
# File: 8501300L.wav
# Sample Rate: 81920
# Duration (seconds): 1.08046875
# Shape of Audio Data: (88512,)
#
# File: 8501300M.wav
# Sample Rate: 81920
# Duration (seconds): 1.44061279296875
# Shape of Audio Data: (118015,)
#
# File: 8501300N.wav
# Sample Rate: 81920
# Duration (seconds): 1.44061279296875
# Shape of Audio Data: (118015,)
#
# File: 8501300P.wav
# Sample Rate: 81920
# Duration (seconds): 1.72811279296875
# Shape of Audio Data: (141567,)
#
# File: 8501300R.wav
# Sample Rate: 81920
# Duration (seconds): 0.99140625
# Shape of Audio Data: (81216,)
#
# File: 8501300S.wav
# Sample Rate: 81920
# Duration (seconds): 1.32186279296875
# Shape of Audio Data: (108287,)
#
# File: 8501300T.wav
# Sample Rate: 81920
# Duration (seconds): 1.11248779296875
# Shape of Audio Data: (91135,)
#
# File: 8501300X.wav
# Sample Rate: 81920
# Duration (seconds): 1.28123779296875
# Shape of Audio Data: (104959,)
#
# File: 8501300Y.wav
# Sample Rate: 81920
# Duration (seconds): 0.95859375
# Shape of Audio Data: (78528,)
#
# File: 85013010.wav
# Sample Rate: 81920
# Duration (seconds): 1.27811279296875
# Shape of Audio Data: (104703,)
#
# File: 85013011.wav
# Sample Rate: 81920
# Duration (seconds): 1.27811279296875
# Shape of Audio Data: (104703,)
#
# File: 85013014.wav
# Sample Rate: 81920
# Duration (seconds): 1.36248779296875
# Shape of Audio Data: (111615,)
#
# File: 85013015.wav
# Sample Rate: 81920
# Duration (seconds): 1.57186279296875
# Shape of Audio Data: (128767,)
#
# File: 85013019.wav
# Sample Rate: 81920
# Duration (seconds): 0.80936279296875
# Shape of Audio Data: (66303,)
#
# File: 8501301A.wav
# Sample Rate: 81920
# Duration (seconds): 1.38436279296875
# Shape of Audio Data: (113407,)
#
# File: 8501301C.wav
# Sample Rate: 81920
# Duration (seconds): 1.44061279296875
# Shape of Audio Data: (118015,)
#
# File: 8501301D.wav
# Sample Rate: 81920
# Duration (seconds): 1.44061279296875
# Shape of Audio Data: (118015,)
#
# File: 8501301F.wav
# Sample Rate: 81920
# Duration (seconds): 1.34998779296875
# Shape of Audio Data: (110591,)
#
# File: 8501301H.wav
# Sample Rate: 81920
# Duration (seconds): 1.15623779296875
# Shape of Audio Data: (94719,)
#
# File: 8501301J.wav
# Sample Rate: 81920
# Duration (seconds): 0.456005859375
# Shape of Audio Data: (37356,)
#
# File: 85014001.wav
# Sample Rate: 81920
# Duration (seconds): 1.35311279296875
# Shape of Audio Data: (110847,)
#
# File: 85014003.wav
# Sample Rate: 81920
# Duration (seconds): 0.90311279296875
# Shape of Audio Data: (73983,)
#
# File: 85014005.wav
# Sample Rate: 81920
# Duration (seconds): 1.0640625
# Shape of Audio Data: (87168,)
#
# File: 85014006.wav
# Sample Rate: 81920
# Duration (seconds): 0.71248779296875
# Shape of Audio Data: (58367,)
#
# File: 85014007.wav
# Sample Rate: 81920
# Duration (seconds): 1.59998779296875
# Shape of Audio Data: (131071,)
#
# File: 8501400B.wav
# Sample Rate: 81920
# Duration (seconds): 1.39686279296875
# Shape of Audio Data: (114431,)
#
# File: 8501400F.wav
# Sample Rate: 81920
# Duration (seconds): 0.89373779296875
# Shape of Audio Data: (73215,)
#
# File: 8501400G.wav
# Sample Rate: 81920
# Duration (seconds): 0.93748779296875
# Shape of Audio Data: (76799,)
#
# File: 8501400H.wav
# Sample Rate: 81920
# Duration (seconds): 1.55311279296875
# Shape of Audio Data: (127231,)
#
# File: 8501400L.wav
# Sample Rate: 81920
# Duration (seconds): 1.62186279296875
# Shape of Audio Data: (132863,)
#
# File: 8501400M.wav
# Sample Rate: 81920
# Duration (seconds): 1.00078125
# Shape of Audio Data: (81984,)
#
# File: 8501400N.wav
# Sample Rate: 81920
# Duration (seconds): 1.59998779296875
# Shape of Audio Data: (131071,)
#
# File: 8501400P.wav
# Sample Rate: 81920
# Duration (seconds): 1.29373779296875
# Shape of Audio Data: (105983,)
#
# File: 8501400Q.wav
# Sample Rate: 81920
# Duration (seconds): 1.0875
# Shape of Audio Data: (89088,)
#
# File: 8501400R.wav
# Sample Rate: 81920
# Duration (seconds): 1.46561279296875
# Shape of Audio Data: (120063,)
#
# File: 8501400S.wav
# Sample Rate: 81920
# Duration (seconds): 1.09373779296875
# Shape of Audio Data: (89599,)
#
# File: 8501400T.wav
# Sample Rate: 81920
# Duration (seconds): 1.09373779296875
# Shape of Audio Data: (89599,)
#
# File: 8501400U.wav
# Sample Rate: 81920
# Duration (seconds): 1.09373779296875
# Shape of Audio Data: (89599,)
#
# File: 8501400V.wav
# Sample Rate: 81920
# Duration (seconds): 0.8203125
# Shape of Audio Data: (67200,)
#
# File: 8501400Y.wav
# Sample Rate: 81920
# Duration (seconds): 1.14686279296875
# Shape of Audio Data: (93951,)
#
# File: 57021003.wav
# Sample Rate: 30000
# Duration (seconds): 2.012966666666667
# Shape of Audio Data: (60389,)
#
# File: 57021002.wav
# Sample Rate: 30000
# Duration (seconds): 6.0991333333333335
# Shape of Audio Data: (182974,)
#
# File: 57021001.wav
# Sample Rate: 30000
# Duration (seconds): 3.4551
# Shape of Audio Data: (103653,)
#
# File: 57021004.wav
# Sample Rate: 30000
# Duration (seconds): 4.446633333333334
# Shape of Audio Data: (133399,)
#
# File: 57021007.wav
# Sample Rate: 30000
# Duration (seconds): 0.9357333333333333
# Shape of Audio Data: (28072,)
#
# File: 57021005.wav
# Sample Rate: 30000
# Duration (seconds): 6.209266666666666
# Shape of Audio Data: (186278,)
#
# File: 57021008.wav
# Sample Rate: 30000
# Duration (seconds): 1.6571666666666667
# Shape of Audio Data: (49715,)
#
# File: 57021009.wav
# Sample Rate: 30000
# Duration (seconds): 1.4212
# Shape of Audio Data: (42636,)
#
# File: 5702100A.wav
# Sample Rate: 30000
# Duration (seconds): 1.1995666666666667
# Shape of Audio Data: (35987,)
#
# File: 5702100B.wav
# Sample Rate: 30000
# Duration (seconds): 1.0616666666666668
# Shape of Audio Data: (31850,)
#
# File: 5702100C.wav
# Sample Rate: 30000
# Duration (seconds): 0.9106
# Shape of Audio Data: (27318,)
#
# File: 5702100D.wav
# Sample Rate: 30000
# Duration (seconds): 0.6981666666666667
# Shape of Audio Data: (20945,)
#
# File: 5702100E.wav
# Sample Rate: 30000
# Duration (seconds): 1.8537666666666666
# Shape of Audio Data: (55613,)
#
# File: 5702100F.wav
# Sample Rate: 30000
# Duration (seconds): 1.8537666666666666
# Shape of Audio Data: (55613,)
#
# File: 5702100G.wav
# Sample Rate: 30000
# Duration (seconds): 1.4834666666666667
# Shape of Audio Data: (44504,)
#
# File: 5702100H.wav
# Sample Rate: 30000
# Duration (seconds): 1.6490666666666667
# Shape of Audio Data: (49472,)
#
# File: 5702100I.wav
# Sample Rate: 30000
# Duration (seconds): 1.0418666666666667
# Shape of Audio Data: (31256,)
#
# File: 5702100J.wav
# Sample Rate: 60600
# Duration (seconds): 55.24851485148515
# Shape of Audio Data: (3348060,)
#
# File: 5702100L.wav
# Sample Rate: 60600
# Duration (seconds): 79.32346534653465
# Shape of Audio Data: (4807002,)
#
# File: 5702100K.wav
# Sample Rate: 60600
# Duration (seconds): 187.34529702970298
# Shape of Audio Data: (11353125,)
#
# File: 5702100N.wav
# Sample Rate: 60600
# Duration (seconds): 35.295
# Shape of Audio Data: (2138877,)
#
# File: 81037001.wav
# Sample Rate: 30000
# Duration (seconds): 2.2345
# Shape of Audio Data: (67035,)
#
# File: 81037002.wav
# Sample Rate: 30000
# Duration (seconds): 3.5002
# Shape of Audio Data: (105006,)
#
# File: 81037004.wav
# Sample Rate: 30000
# Duration (seconds): 4.2438
# Shape of Audio Data: (127314,)
#
# File: 81037005.wav
# Sample Rate: 30000
# Duration (seconds): 4.574366666666666
# Shape of Audio Data: (137231,)
#
# File: 81037007.wav
# Sample Rate: 40960
# Duration (seconds): 1.4203125
# Shape of Audio Data: (58176,)
#
# File: 81037008.wav
# Sample Rate: 40960
# Duration (seconds): 1.4203125
# Shape of Audio Data: (58176,)
#
# File: 8103700A.wav
# Sample Rate: 40960
# Duration (seconds): 1.125
# Shape of Audio Data: (46080,)
#
# File: 8103700B.wav
# Sample Rate: 40960
# Duration (seconds): 1.4203125
# Shape of Audio Data: (58176,)
#
# File: 8103700C.wav
# Sample Rate: 40960
# Duration (seconds): 1.4203125
# Shape of Audio Data: (58176,)
#
# File: 8103700E.wav
# Sample Rate: 40960
# Duration (seconds): 1.4203125
# Shape of Audio Data: (58176,)
#
# File: 8103700F.wav
# Sample Rate: 40960
# Duration (seconds): 1.4203125
# Shape of Audio Data: (58176,)
#
# File: 8103700G.wav
# Sample Rate: 40960
# Duration (seconds): 1.4203125
# Shape of Audio Data: (58176,)
#
# File: 8103700L.wav
# Sample Rate: 40960
# Duration (seconds): 1.4203125
# Shape of Audio Data: (58176,)
#
# File: 8103700H.wav
# Sample Rate: 40960
# Duration (seconds): 1.4203125
# Shape of Audio Data: (58176,)
#
# File: 8103700P.wav
# Sample Rate: 40960
# Duration (seconds): 0.9375
# Shape of Audio Data: (38400,)
#
# File: 81037011.wav
# Sample Rate: 40960
# Duration (seconds): 0.3861328125
# Shape of Audio Data: (15816,)
#
# File: 8103700V.wav
# Sample Rate: 40960
# Duration (seconds): 1.4203125
# Shape of Audio Data: (58176,)
#
# File: 8103700U.wav
# Sample Rate: 40960
# Duration (seconds): 1.4203125
# Shape of Audio Data: (58176,)
#
# File: 84016002.wav
# Sample Rate: 40000
# Duration (seconds): 43.962325
# Shape of Audio Data: (1758493,)
#
# File: 8401600B.wav
# Sample Rate: 44100
# Duration (seconds): 1260.0
# Shape of Audio Data: (55566000,)
#
# File: 9100500N.wav
# Sample Rate: 40000
# Duration (seconds): 1.31075
# Shape of Audio Data: (52430,)
#
# File: 9100500R.wav
# Sample Rate: 40000
# Duration (seconds): 1.457
# Shape of Audio Data: (58280,)
#
# File: 91005006.wav
# Sample Rate: 40000
# Duration (seconds): 1.39125
# Shape of Audio Data: (55650,)
#
# File: 9100500S.wav
# Sample Rate: 40000
# Duration (seconds): 1.786
# Shape of Audio Data: (71440,)
#
# File: 9100500Y.wav
# Sample Rate: 40000
# Duration (seconds): 2.0915
# Shape of Audio Data: (83660,)
#
# File: 91005011.wav
# Sample Rate: 40000
# Duration (seconds): 1.204375
# Shape of Audio Data: (48175,)
#
# File: 91005012.wav
# Sample Rate: 40000
# Duration (seconds): 1.462875
# Shape of Audio Data: (58515,)
#
# File: 91005010.wav
# Sample Rate: 40000
# Duration (seconds): 2.632
# Shape of Audio Data: (105280,)
#
# File: 91005014.wav
# Sample Rate: 40000
# Duration (seconds): 1.974
# Shape of Audio Data: (78960,)
#
# File: 91005015.wav
# Sample Rate: 40000
# Duration (seconds): 4.422
# Shape of Audio Data: (176880,)
#
# File: 9100501K.wav
# Sample Rate: 40000
# Duration (seconds): 0.698375
# Shape of Audio Data: (27935,)
#
# File: 9100501D.wav
# Sample Rate: 40000
# Duration (seconds): 1.9825
# Shape of Audio Data: (79300,)
#
# File: 9100501S.wav
# Sample Rate: 40000
# Duration (seconds): 0.83605
# Shape of Audio Data: (33442,)
#
# File: 9100501T.wav
# Sample Rate: 40000
# Duration (seconds): 0.5432
# Shape of Audio Data: (21728,)
#
# File: 9100501V.wav
# Sample Rate: 40000
# Duration (seconds): 0.7672
# Shape of Audio Data: (30688,)
#
# File: 91005020.wav
# Sample Rate: 40000
# Duration (seconds): 0.6748
# Shape of Audio Data: (26992,)
#
# File: 9100501W.wav
# Sample Rate: 40000
# Duration (seconds): 0.8428
# Shape of Audio Data: (33712,)
#
# File: 91005029.wav
# Sample Rate: 40000
# Duration (seconds): 1.1655
# Shape of Audio Data: (46620,)
#
# ...
# Shape of Audio Data: (151368,)
#
# File: 70014011.wav
# Sample Rate: 80000
# Duration (seconds): 1.6779
# Shape of Audio Data: (134232,)
#
# File: 72005001.wav
# Sample Rate: 60600
# Duration (seconds): 1.9685478547854784
# Shape of Audio Data: (119294,)
#
# File: 72005004.wav
# Sample Rate: 60600
# Duration (seconds): 2.6025577557755777
# Shape of Audio Data: (157715,)
#
# File: 72005003.wav
# Sample Rate: 60600
# Duration (seconds): 1.6511716171617161
# Shape of Audio Data: (100061,)
#
# File: 72005005.wav
# Sample Rate: 60600
# Duration (seconds): 2.5064686468646866
# Shape of Audio Data: (151892,)
#
# File: 72005007.wav
# Sample Rate: 60600
# Duration (seconds): 2.0126072607260728
# Shape of Audio Data: (121964,)
#
# File: 7200500C.wav
# Sample Rate: 60600
# Duration (seconds): 2.6688778877887787
# Shape of Audio Data: (161734,)
#
# File: 72005008.wav
# Sample Rate: 60600
# Duration (seconds): 2.436930693069307
# Shape of Audio Data: (147678,)
#
# File: 7200500D.wav
# Sample Rate: 60600
# Duration (seconds): 2.5223762376237624
# Shape of Audio Data: (152856,)
#
# File: 7200500E.wav
# Sample Rate: 60600
# Duration (seconds): 2.2866996699669966
# Shape of Audio Data: (138574,)
#
# File: 7200500F.wav
# Sample Rate: 60600
# Duration (seconds): 1.7367161716171617
# Shape of Audio Data: (105245,)
#
# File: 7200500G.wav
# Sample Rate: 60600
# Duration (seconds): 1.4001155115511552
# Shape of Audio Data: (84847,)
#
# File: 7200500H.wav
# Sample Rate: 60600
# Duration (seconds): 1.6973267326732673
# Shape of Audio Data: (102858,)
#
# File: 7200500K.wav
# Sample Rate: 60600
# Duration (seconds): 3.3264851485148514
# Shape of Audio Data: (201585,)
#
# File: 7200500L.wav
# Sample Rate: 60600
# Duration (seconds): 2.6910891089108913
# Shape of Audio Data: (163080,)
#
# File: 7200500M.wav
# Sample Rate: 60600
# Duration (seconds): 1.965990099009901
# Shape of Audio Data: (119139,)
#
# File: 7200500N.wav
# Sample Rate: 60600
# Duration (seconds): 2.765841584158416
# Shape of Audio Data: (167610,)
#
# File: 7200500P.wav
# Sample Rate: 60600
# Duration (seconds): 2.907871287128713
# Shape of Audio Data: (176217,)
#
# File: 7200500U.wav
# Sample Rate: 60600
# Duration (seconds): 2.024257425742574
# Shape of Audio Data: (122670,)
#
# File: 7200500V.wav
# Sample Rate: 60600
# Duration (seconds): 2.407095709570957
# Shape of Audio Data: (145870,)
#
# File: 7200500W.wav
# Sample Rate: 60600
# Duration (seconds): 2.2443894389438945
# Shape of Audio Data: (136010,)
#
# File: 7200500Y.wav
# Sample Rate: 60600
# Duration (seconds): 2.565016501650165
# Shape of Audio Data: (155440,)
#
# File: 7200500Z.wav
# Sample Rate: 60600
# Duration (seconds): 2.1582508250825083
# Shape of Audio Data: (130790,)
#
# File: 61072006.wav
# Sample Rate: 80000
# Duration (seconds): 3.1389625
# Shape of Audio Data: (251117,)
#
# File: 6107200E.wav
# Sample Rate: 80000
# Duration (seconds): 2.0598875
# Shape of Audio Data: (164791,)
#
# File: 61072004.wav
# Sample Rate: 80000
# Duration (seconds): 2.2615875
# Shape of Audio Data: (180927,)
#
# File: 61072005.wav
# Sample Rate: 80000
# Duration (seconds): 1.936
# Shape of Audio Data: (154880,)
#
# File: 6107200G.wav
# Sample Rate: 80000
# Duration (seconds): 2.702225
# Shape of Audio Data: (216178,)
#
# File: 6107200H.wav
# Sample Rate: 80000
# Duration (seconds): 1.7274375
# Shape of Audio Data: (138195,)
#
# File: 6107200K.wav
# Sample Rate: 80000
# Duration (seconds): 2.35875
# Shape of Audio Data: (188700,)
#
# File: 6107200M.wav
# Sample Rate: 80000
# Duration (seconds): 1.91475
# Shape of Audio Data: (153180,)
#
# File: 6107200O.wav
# Sample Rate: 80000
# Duration (seconds): 2.150625
# Shape of Audio Data: (172050,)
#
# File: 6107200R.wav
# Sample Rate: 80000
# Duration (seconds): 2.1991875
# Shape of Audio Data: (175935,)
#
# File: 6107200S.wav
# Sample Rate: 80000
# Duration (seconds): 2.442
# Shape of Audio Data: (195360,)
#
# File: 6107200T.wav
# Sample Rate: 80000
# Duration (seconds): 1.80375
# Shape of Audio Data: (144300,)
#
# File: 6107200Z.wav
# Sample Rate: 80000
# Duration (seconds): 2.54
# Shape of Audio Data: (203200,)
#
# File: 6107201H.wav
# Sample Rate: 80000
# Duration (seconds): 1.8084
# Shape of Audio Data: (144672,)
#
# File: 61072013.wav
# Sample Rate: 80000
# Duration (seconds): 2.5781
# Shape of Audio Data: (206248,)
#
# File: 6107201N.wav
# Sample Rate: 80000
# Duration (seconds): 1.6166
# Shape of Audio Data: (129328,)
#
# File: 6107201P.wav
# Sample Rate: 80000
# Duration (seconds): 2.3016
# Shape of Audio Data: (184128,)
#
# File: 6107201X.wav
# Sample Rate: 80000
# Duration (seconds): 1.507
# Shape of Audio Data: (120560,)
#
# File: 61072020.wav
# Sample Rate: 80000
# Duration (seconds): 1.37
# Shape of Audio Data: (109600,)
#
# File: 61072021.wav
# Sample Rate: 80000
# Duration (seconds): 1.3508625
# Shape of Audio Data: (108069,)
#
# File: 61072022.wav
# Sample Rate: 80000
# Duration (seconds): 1.4337375
# Shape of Audio Data: (114699,)
#
# File: 61072023.wav
# Sample Rate: 80000
# Duration (seconds): 2.3205
# Shape of Audio Data: (185640,)
#
# File: 6107202D.wav
# Sample Rate: 80000
# Duration (seconds): 2.79295
# Shape of Audio Data: (223436,)
#
# File: 6107202K.wav
# Sample Rate: 80000
# Duration (seconds): 3.1210375
# Shape of Audio Data: (249683,)
#
# File: 6107202N.wav
# Sample Rate: 80000
# Duration (seconds): 2.8686625
# Shape of Audio Data: (229493,)
#
# File: 6107202L.wav
# Sample Rate: 80000
# Duration (seconds): 3.482775
# Shape of Audio Data: (278622,)
#
# File: 6107202O.wav
# Sample Rate: 80000
# Duration (seconds): 2.3302625
# Shape of Audio Data: (186421,)
#
# File: 6107202R.wav
# Sample Rate: 80000
# Duration (seconds): 2.910725
# Shape of Audio Data: (232858,)
#
# File: 6107202T.wav
# Sample Rate: 80000
# Duration (seconds): 3.078975
# Shape of Audio Data: (246318,)
#
# File: 61072031.wav
# Sample Rate: 60600
# Duration (seconds): 23.230610561056107
# Shape of Audio Data: (1407775,)
#
# File: 61072032.wav
# Sample Rate: 60600
# Duration (seconds): 46.62925742574257
# Shape of Audio Data: (2825733,)
#
# File: 7500100Y.wav
# Sample Rate: 166600
# Duration (seconds): 2.409795918367347
# Shape of Audio Data: (401472,)
#
# File: 75001019.wav
# Sample Rate: 166600
# Duration (seconds): 1.9689795918367348
# Shape of Audio Data: (328032,)
#
# File: 7500101N.wav
# Sample Rate: 166600
# Duration (seconds): 2.6351020408163266
# Shape of Audio Data: (439008,)
#
# File: 7500101P.wav
# Sample Rate: 166600
# Duration (seconds): 3.9281632653061225
# Shape of Audio Data: (654432,)
#
# File: 75001021.wav
# Sample Rate: 166600
# Duration (seconds): 2.1648979591836737
# Shape of Audio Data: (360672,)
#
# File: 7500102G.wav
# Sample Rate: 166600
# Duration (seconds): 2.84187274909964
# Shape of Audio Data: (473456,)
#
# File: 7500102H.wav
# Sample Rate: 166600
# Duration (seconds): 3.177527010804322
# Shape of Audio Data: (529376,)
#
# File: 7500102I.wav
# Sample Rate: 166600
# Duration (seconds): 1.7342136854741896
# Shape of Audio Data: (288920,)
#
# File: 7500102R.wav
# Sample Rate: 166600
# Duration (seconds): 1.6894597839135654
# Shape of Audio Data: (281464,)
#
# File: 7500102S.wav
# Sample Rate: 166600
# Duration (seconds): 3.9830972388955583
# Shape of Audio Data: (663584,)
#
# File: 7500103D.wav
# Sample Rate: 166600
# Duration (seconds): 2.9649459783913565
# Shape of Audio Data: (493960,)
#
# File: 7500103V.wav
# Sample Rate: 166600
# Duration (seconds): 2.3831452581032413
# Shape of Audio Data: (397032,)
#
# File: 78007015.wav
# Sample Rate: 148100
# Duration (seconds): 1.8835313977042538
# Shape of Audio Data: (278951,)
#
# File: 7800701J.wav
# Sample Rate: 148100
# Duration (seconds): 1.0587440918298447
# Shape of Audio Data: (156800,)
#
# File: 78007038.wav
# Sample Rate: 148100
# Duration (seconds): 1.3505469277515192
# Shape of Audio Data: (200016,)
#
# File: 7800703Q.wav
# Sample Rate: 148100
# Duration (seconds): 2.217380148548278
# Shape of Audio Data: (328394,)
#
# File: 79004007.wav
# Sample Rate: 148100
# Duration (seconds): 1.253801485482782
# Shape of Audio Data: (185688,)
#
# File: 79004016.wav
# Sample Rate: 148100
# Duration (seconds): 1.3336529372045915
# Shape of Audio Data: (197514,)
#
# File: 79006014.wav
# Sample Rate: 81920
# Duration (seconds): 1.1983154296875
# Shape of Audio Data: (98166,)
#
# File: 79006015.wav
# Sample Rate: 81920
# Duration (seconds): 1.01107177734375
# Shape of Audio Data: (82827,)
#
# File: 79006016.wav
# Sample Rate: 81920
# Duration (seconds): 1.490625
# Shape of Audio Data: (122112,)
#
# File: 79006017.wav
# Sample Rate: 81920
# Duration (seconds): 0.8896728515625
# Shape of Audio Data: (72882,)
#
# File: 79006018.wav
# Sample Rate: 81920
# Duration (seconds): 0.7308837890625
# Shape of Audio Data: (59874,)
#
# File: 79006019.wav
# Sample Rate: 81920
# Duration (seconds): 0.7752685546875
# Shape of Audio Data: (63510,)
#
# File: 60009005.wav
# Sample Rate: 600
# Duration (seconds): 44.20166666666667
# Shape of Audio Data: (26521,)
#
# File: 60009006.wav
# Sample Rate: 600
# Duration (seconds): 35.428333333333335
# Shape of Audio Data: (21257,)
#
# File: 60009007.wav
# Sample Rate: 600
# Duration (seconds): 24.908333333333335
# Shape of Audio Data: (14945,)
#
# File: 6000900L.wav
# Sample Rate: 600
# Duration (seconds): 5.9383333333333335
# Shape of Audio Data: (3563,)
#
# File: 6000900M.wav
# Sample Rate: 600
# Duration (seconds): 5.998333333333333
# Shape of Audio Data: (3599,)
#
# File: 61039001.wav
# Sample Rate: 600
# Duration (seconds): 72.31
# Shape of Audio Data: (43386,)
#
# File: 61047009.wav
# Sample Rate: 600
# Duration (seconds): 93.01333333333334
# Shape of Audio Data: (55808,)
#
# File: 6104700D.wav
# Sample Rate: 600
# Duration (seconds): 48.71666666666667
# Shape of Audio Data: (29230,)
#
# File: 6104700E.wav
# Sample Rate: 600
# Duration (seconds): 42.79666666666667
# Shape of Audio Data: (25678,)
#
# File: 6104700F.wav
# Sample Rate: 600
# Duration (seconds): 59.93833333333333
# Shape of Audio Data: (35963,)
#
# File: 61048004.wav
# Sample Rate: 600
# Duration (seconds): 59.348333333333336
# Shape of Audio Data: (35609,)
#
# File: 61048005.wav
# Sample Rate: 600
# Duration (seconds): 32.52166666666667
# Shape of Audio Data: (19513,)
#
# File: 61048007.wav
# Sample Rate: 600
# Duration (seconds): 41.04833333333333
# Shape of Audio Data: (24629,)
#
# File: 61064006.wav
# Sample Rate: 600
# Duration (seconds): 69.635
# Shape of Audio Data: (41781,)
#
# File: 61064008.wav
# Sample Rate: 600
# Duration (seconds): 43.49333333333333
# Shape of Audio Data: (26096,)
#
# File: 61064009.wav
# Sample Rate: 600
# Duration (seconds): 65.06666666666666
# Shape of Audio Data: (39040,)
#
# File: 6106400A.wav
# Sample Rate: 600
# Duration (seconds): 51.126666666666665
# Shape of Audio Data: (30676,)
#
# File: 6106400B.wav
# Sample Rate: 600
# Duration (seconds): 52.068333333333335
# Shape of Audio Data: (31241,)
#
# File: 6106400D.wav
# Sample Rate: 600
# Duration (seconds): 31.403333333333332
# Shape of Audio Data: (18842,)
#
# File: 6106400F.wav
# Sample Rate: 600
# Duration (seconds): 69.21333333333334
# Shape of Audio Data: (41528,)
#
# File: 6106400J.wav
# Sample Rate: 600
# Duration (seconds): 74.465
# Shape of Audio Data: (44679,)
#
# File: 6106400L.wav
# Sample Rate: 600
# Duration (seconds): 83.93333333333334
# Shape of Audio Data: (50360,)
#
# File: 6106400O.wav
# Sample Rate: 600
# Duration (seconds): 27.321666666666665
# Shape of Audio Data: (16393,)
#
# File: 61079002.wav
# Sample Rate: 600
# Duration (seconds): 90.32333333333334
# Shape of Audio Data: (54194,)
#
# File: 61079005.wav
# Sample Rate: 600
# Duration (seconds): 44.775
# Shape of Audio Data: (26865,)
#
# File: 61079006.wav
# Sample Rate: 600
# Duration (seconds): 31.58
# Shape of Audio Data: (18948,)
#
# File: 61079007.wav
# Sample Rate: 600
# Duration (seconds): 32.655
# Shape of Audio Data: (19593,)
#
# File: 61079009.wav
# Sample Rate: 600
# Duration (seconds): 35.155
# Shape of Audio Data: (21093,)
#
# File: 6107900A.wav
# Sample Rate: 600
# Duration (seconds): 29.473333333333333
# Shape of Audio Data: (17684,)
#
# File: 6107900B.wav
# Sample Rate: 600
# Duration (seconds): 64.13333333333334
# Shape of Audio Data: (38480,)
#
# File: 6107900C.wav
# Sample Rate: 600
# Duration (seconds): 38.71
# Shape of Audio Data: (23226,)
#
# File: 6107900D.wav
# Sample Rate: 600
# Duration (seconds): 81.46666666666667
# Shape of Audio Data: (48880,)
#
# File: 6107900E.wav
# Sample Rate: 600
# Duration (seconds): 81.49
# Shape of Audio Data: (48894,)
#
# File: 6107900F.wav
# Sample Rate: 600
# Duration (seconds): 66.98333333333333
# Shape of Audio Data: (40190,)
#
# File: 6107900G.wav
# Sample Rate: 600
# Duration (seconds): 46.8
# Shape of Audio Data: (28080,)
#
# File: 6107900H.wav
# Sample Rate: 600
# Duration (seconds): 87.1
# Shape of Audio Data: (52260,)
#
# File: 6107900I.wav
# Sample Rate: 600
# Duration (seconds): 98.97333333333333
# Shape of Audio Data: (59384,)
#
# File: 6107900J.wav
# Sample Rate: 600
# Duration (seconds): 101.91333333333333
# Shape of Audio Data: (61148,)
#
# File: 6107900K.wav
# Sample Rate: 600
# Duration (seconds): 31.898333333333333
# Shape of Audio Data: (19139,)
#
# File: 6107900L.wav
# Sample Rate: 600
# Duration (seconds): 25.005
# Shape of Audio Data: (15003,)
#
# File: 6107900M.wav
# Sample Rate: 600
# Duration (seconds): 86.615
# Shape of Audio Data: (51969,)
#
# File: 6107900N.wav
# Sample Rate: 600
# Duration (seconds): 75.92
# Shape of Audio Data: (45552,)
#
# File: 78014003.wav
# Sample Rate: 640
# Duration (seconds): 24.0
# Shape of Audio Data: (15360,)
#
# File: 78014004.wav
# Sample Rate: 640
# Duration (seconds): 24.0
# Shape of Audio Data: (15360,)
#
# File: 78014005.wav
# Sample Rate: 640
# Duration (seconds): 24.0
# Shape of Audio Data: (15360,)
#
# File: 78014006.wav
# Sample Rate: 640
# Duration (seconds): 24.0
# Shape of Audio Data: (15360,)
#
# File: 78014007.wav
# Sample Rate: 640
# Duration (seconds): 24.0
# Shape of Audio Data: (15360,)
#
# File: 78014008.wav
# Sample Rate: 640
# Duration (seconds): 24.0
# Shape of Audio Data: (15360,)
#
# File: 78014009.wav
# Sample Rate: 640
# Duration (seconds): 24.0
# Shape of Audio Data: (15360,)
#
# File: 7801400A.wav
# Sample Rate: 640
# Duration (seconds): 24.0
# Shape of Audio Data: (15360,)
#
# File: 6608400I.wav
# Sample Rate: 5000
# Duration (seconds): 5.4742
# Shape of Audio Data: (27371,)
#
# File: 6608400J.wav
# Sample Rate: 5000
# Duration (seconds): 2.6058
# Shape of Audio Data: (13029,)
#
# File: 6608400N.wav
# Sample Rate: 5000
# Duration (seconds): 5.1712
# Shape of Audio Data: (25856,)
#
# File: 6608400P.wav
# Sample Rate: 5000
# Duration (seconds): 2.4016
# Shape of Audio Data: (12008,)
#
# File: 6608400Q.wav
# Sample Rate: 5000
# Duration (seconds): 7.2364
# Shape of Audio Data: (36182,)
#
# File: 6608400R.wav
# Sample Rate: 5000
# Duration (seconds): 3.5708
# Shape of Audio Data: (17854,)
#
# File: 6608400T.wav
# Sample Rate: 5000
# Duration (seconds): 6.794
# Shape of Audio Data: (33970,)
#
# File: 6608400Z.wav
# Sample Rate: 5000
# Duration (seconds): 3.402
# Shape of Audio Data: (17010,)
#
# File: 66084010.wav
# Sample Rate: 5000
# Duration (seconds): 2.34
# Shape of Audio Data: (11700,)
#
# File: 66084013.wav
# Sample Rate: 5000
# Duration (seconds): 7.272
# Shape of Audio Data: (36360,)
#
# File: 64103001.wav
# Sample Rate: 1280
# Duration (seconds): 0.94453125
# Shape of Audio Data: (1209,)
#
# File: 64103002.wav
# Sample Rate: 1280
# Duration (seconds): 0.94453125
# Shape of Audio Data: (1209,)
#
# File: 64103003.wav
# Sample Rate: 1280
# Duration (seconds): 0.94453125
# Shape of Audio Data: (1209,)
#
# File: 64103004.wav
# Sample Rate: 1280
# Duration (seconds): 1.41796875
# Shape of Audio Data: (1815,)
#
# File: 64103005.wav
# Sample Rate: 1280
# Duration (seconds): 1.41796875
# Shape of Audio Data: (1815,)
#
# File: 64103006.wav
# Sample Rate: 1280
# Duration (seconds): 1.41796875
# Shape of Audio Data: (1815,)
#
# File: 64103007.wav
# Sample Rate: 1280
# Duration (seconds): 1.41796875
# Shape of Audio Data: (1815,)
#
# File: 64103008.wav
# Sample Rate: 1280
# Duration (seconds): 0.9703125
# Shape of Audio Data: (1242,)
#
# File: 64103009.wav
# Sample Rate: 1280
# Duration (seconds): 1.41328125
# Shape of Audio Data: (1809,)
#
# File: 6410300A.wav
# Sample Rate: 1280
# Duration (seconds): 1.3734375
# Shape of Audio Data: (1758,)
#
# File: 6410300B.wav
# Sample Rate: 1280
# Duration (seconds): 1.25859375
# Shape of Audio Data: (1611,)
#
# File: 64104001.wav
# Sample Rate: 1280
# Duration (seconds): 0.94453125
# Shape of Audio Data: (1209,)
#
# File: 64104002.wav
# Sample Rate: 1280
# Duration (seconds): 0.70859375
# Shape of Audio Data: (907,)
#
# File: 64104003.wav
# Sample Rate: 1280
# Duration (seconds): 0.70859375
# Shape of Audio Data: (907,)
#
# File: 64104004.wav
# Sample Rate: 1280
# Duration (seconds): 1.4109375
# Shape of Audio Data: (1806,)
#
# File: 64104005.wav
# Sample Rate: 1280
# Duration (seconds): 1.3359375
# Shape of Audio Data: (1710,)
#
# File: 64104006.wav
# Sample Rate: 1280
# Duration (seconds): 1.4109375
# Shape of Audio Data: (1806,)
#
# File: 64041002.wav
# Sample Rate: 20480
# Duration (seconds): 10.4625
# Shape of Audio Data: (214272,)
#
# File: 6404200B.wav
# Sample Rate: 43900
# Duration (seconds): 31.802004555808654
# Shape of Audio Data: (1396108,)

# %%
# Visualize the distribution of audio file durations (histogram with density curve)

plt.figure(figsize=(14, 7))
sns.histplot(duration_list, kde=True, bins=30, color='lightblue', edgecolor='black')
plt.xlabel('Duration (seconds)')
plt.ylabel('Count')
plt.title('Distribution of Audio File Durations with Density Curve')
plt.grid(True)
plt.show()

# %%
# Visualize the distribution of audio sample rate (histogram with density curve)

plt.figure(figsize=(14, 7))
sns.histplot(sample_rate_list, kde=True, bins=30, color='lightblue', edgecolor='black')
plt.xlabel('Sample rate (Hz)')
plt.ylabel('Count')
plt.title('Distribution of Audio File Sample Rate with Density Curve')
plt.grid(True)
plt.show()

# %% [markdown]
# ## **Class Distribution Analysis**

# %%
# Create dictionairies to hold audio data and class counts
class_audio_data = {}
class_counts = {}

# Recursively iterate over all files in the directory and subdirectories
for root, dirs, files in os.walk(directory):
  for filename in files:
    if filename.endswith('.wav'):
      class_name = os.path.basename(root)
      filepath = os.path.join(root, filename)
      try:
        # Load the WAV file, with original sample rate
        audio_data, sample_rate = librosa.load(filepath, sr=None)

        # Append audio data to the class dictionary
        if class_name not in class_audio_data:
          class_audio_data[class_name] = []
          class_counts[class_name] = 0
        class_audio_data[class_name].append((audio_data, sample_rate))
        class_counts[class_name] += 1

        # Print information about the loaded file
        print(f"Loaded '{filename}' from class '{class_name}'. Sample rate: {sample_rate}, Duration: {len(audio_data) / sample_rate} seconds")
      except Exception as e:
        print(f"Error loading {filename}: {e}")

# Print summary statistics
print("\nSummary:")
for class_name, audios in class_audio_data.items():
  print(f"Class '{class_name} has {len(audios)} instances.")
total_instances = sum(class_counts.values())
print(f"Total number of instances: {total_instances}")
# Out:
# Loaded '61025003.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 43900, Duration: 3.527995444191344 seconds
# Loaded '61025001.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 43900, Duration: 3.527995444191344 seconds
# Loaded '61025002.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 43900, Duration: 3.527995444191344 seconds
# Loaded '61025004.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 43900, Duration: 1.763986332574032 seconds
# Loaded '61025006.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 43900, Duration: 1.763986332574032 seconds
# Loaded '61025007.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 43900, Duration: 1.763986332574032 seconds
# Loaded '61025008.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 43900, Duration: 3.527995444191344 seconds
# Loaded '61025009.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 43900, Duration: 2.646013667425968 seconds
# Loaded '6102500A.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 43900, Duration: 3.527995444191344 seconds
# Loaded '6102500B.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 60600, Duration: 1.2227062706270626 seconds
# Loaded '6102500C.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 60600, Duration: 1.5207920792079208 seconds
# Loaded '6102500D.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 60600, Duration: 1.2324752475247525 seconds
# Loaded '6102500E.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 60600, Duration: 1.116831683168317 seconds
# Loaded '6102500F.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 60600, Duration: 1.1664686468646865 seconds
# Loaded '6102500G.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 60600, Duration: 1.4574257425742574 seconds
# Loaded '6102500H.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 60600, Duration: 1.0967656765676568 seconds
# Loaded '6102500I.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 60600, Duration: 1.7937293729372936 seconds
# Loaded '6102500J.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 60600, Duration: 1.4621782178217821 seconds
# Loaded '6102500K.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 60600, Duration: 0.8645544554455445 seconds
# Loaded '6102500M.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 60600, Duration: 0.9821782178217822 seconds
# Loaded '6102500N.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 60600, Duration: 1.8723267326732673 seconds
# Loaded '6102500O.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 60600, Duration: 1.33016501650165 seconds
# Loaded '6102500P.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 60600, Duration: 1.3526072607260726 seconds
# Loaded '6102500Q.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 60600, Duration: 1.451089108910891 seconds
# Loaded '6102500R.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 60600, Duration: 58.62316831683168 seconds
# Loaded '61026001.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.9211875 seconds
# Loaded '61026002.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.7978125 seconds
# Loaded '61026004.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.6121875 seconds
# Loaded '6102600F.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.665125 seconds
# Loaded '6102600G.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.682425 seconds
# Loaded '6102601Y.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.551 seconds
# Loaded '6102601Z.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.3395 seconds
# Loaded '61026020.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.4241 seconds
# Loaded '61026021.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.5369 seconds
# Loaded '6102602I.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.2408 seconds
# Loaded '6102602J.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.5792 seconds
# Loaded '6102602K.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.4382 seconds
# Loaded '6102602T.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.7907 seconds
# Loaded '6102602U.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.692 seconds
# Loaded '6102602V.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.2549 seconds
# Loaded '6102602W.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.1421 seconds
# Loaded '61026031.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.4946 seconds
# Loaded '61026036.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.3677 seconds
# Loaded '6102603A.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.3959 seconds
# Loaded '6102603C.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.6074 seconds
# Loaded '6102603E.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.5087 seconds
# Loaded '6102603F.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.3959 seconds
# Loaded '6102603I.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.3113 seconds
# Loaded '6102603L.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.4382 seconds
# Loaded '6102603O.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.2486125 seconds
# Loaded '6102603S.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.2980625 seconds
# Loaded '6102603V.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.4835 seconds
# Loaded '6102603W.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.3846 seconds
# Loaded '6102603X.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.310425 seconds
# Loaded '6102603Z.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.3846 seconds
# Loaded '6102604J.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.9292 seconds
# Loaded '6102604K.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.670825 seconds
# Loaded '6102604L.wav' from class 'AtlanticSpottedDolphin'. Sample rate: 80000, Duration: 1.75695 seconds
# Loaded '66038002.wav' from class 'BeardedSeal'. Sample rate: 18000, Duration: 6.109111111111111 seconds
# Loaded '66038001.wav' from class 'BeardedSeal'. Sample rate: 18000, Duration: 3.905777777777778 seconds
# Loaded '66038003.wav' from class 'BeardedSeal'. Sample rate: 30000, Duration: 6.5398 seconds
# Loaded '66038004.wav' from class 'BeardedSeal'. Sample rate: 18000, Duration: 8.174777777777777 seconds
# Loaded '66038005.wav' from class 'BeardedSeal'. Sample rate: 18000, Duration: 8.174777777777777 seconds
# Loaded '66038007.wav' from class 'BeardedSeal'. Sample rate: 18000, Duration: 8.037 seconds
# Loaded '70025001.wav' from class 'BeardedSeal'. Sample rate: 20480, Duration: 2.8359375 seconds
# Loaded '70025002.wav' from class 'BeardedSeal'. Sample rate: 20480, Duration: 2.7046875 seconds
# Loaded '70025003.wav' from class 'BeardedSeal'. Sample rate: 20480, Duration: 2.8359375 seconds
# Loaded '70025004.wav' from class 'BeardedSeal'. Sample rate: 20480, Duration: 2.8359375 seconds
# Loaded '70025005.wav' from class 'BeardedSeal'. Sample rate: 20480, Duration: 1.41796875 seconds
# Loaded '70025006.wav' from class 'BeardedSeal'. Sample rate: 20480, Duration: 2.5640625 seconds
# Loaded '70025007.wav' from class 'BeardedSeal'. Sample rate: 20480, Duration: 2.1046875 seconds
# Loaded '70025008.wav' from class 'BeardedSeal'. Sample rate: 10240, Duration: 1.321875 seconds
# Loaded '70025009.wav' from class 'BeardedSeal'. Sample rate: 10240, Duration: 1.9921875 seconds
# Loaded '71012001.wav' from class 'BeardedSeal'. Sample rate: 5120, Duration: 1.41796875 seconds
# Loaded '71012002.wav' from class 'BeardedSeal'. Sample rate: 5120, Duration: 1.41796875 seconds
# Loaded '72021005.wav' from class 'BeardedSeal'. Sample rate: 10240, Duration: 142.5 seconds
# Loaded '71012003.wav' from class 'BeardedSeal'. Sample rate: 5120, Duration: 0.75 seconds
# Loaded '71012004.wav' from class 'BeardedSeal'. Sample rate: 5120, Duration: 0.75 seconds
# Loaded '7202100T.wav' from class 'BeardedSeal'. Sample rate: 10240, Duration: 2.8359375 seconds
# Loaded '7202100V.wav' from class 'BeardedSeal'. Sample rate: 10240, Duration: 2.8359375 seconds
# Loaded '71012005.wav' from class 'BeardedSeal'. Sample rate: 5120, Duration: 0.75 seconds
# Loaded '7202100Z.wav' from class 'BeardedSeal'. Sample rate: 10240, Duration: 2.465625 seconds
# Loaded '71012006.wav' from class 'BeardedSeal'. Sample rate: 5120, Duration: 1.134375 seconds
# Loaded '71012007.wav' from class 'BeardedSeal'. Sample rate: 5120, Duration: 1.209375 seconds
# Loaded '78018002.wav' from class 'BeardedSeal'. Sample rate: 10240, Duration: 45.3 seconds
# Loaded '71012008.wav' from class 'BeardedSeal'. Sample rate: 5120, Duration: 0.83671875 seconds
# Loaded '78018003.wav' from class 'BeardedSeal'. Sample rate: 10240, Duration: 11.34375 seconds
# Loaded '71012009.wav' from class 'BeardedSeal'. Sample rate: 5120, Duration: 0.83671875 seconds
# Loaded '7801800B.wav' from class 'BeardedSeal'. Sample rate: 10240, Duration: 2.7515625 seconds
# Loaded '7801800D.wav' from class 'BeardedSeal'. Sample rate: 10240, Duration: 2.7515625 seconds
# Loaded '7801800H.wav' from class 'BeardedSeal'. Sample rate: 10240, Duration: 3.61875 seconds
# Loaded '7801800J.wav' from class 'BeardedSeal'. Sample rate: 10240, Duration: 3.61875 seconds
# Loaded '78018001.wav' from class 'BeardedSeal'. Sample rate: 10240, Duration: 40.875 seconds
# Loaded '78018005.wav' from class 'BeardedSeal'. Sample rate: 10240, Duration: 11.34375 seconds
# Loaded '7801800M.wav' from class 'BeardedSeal'. Sample rate: 10240, Duration: 11.30625 seconds
# Loaded '62018001.wav' from class 'Beluga_WhiteWhale'. Sample rate: 40000, Duration: 1.8635 seconds
# Loaded '62018002.wav' from class 'Beluga_WhiteWhale'. Sample rate: 40000, Duration: 2.5571 seconds
# Loaded '62019001.wav' from class 'Beluga_WhiteWhale'. Sample rate: 20000, Duration: 4.2588 seconds
# Loaded '62019007.wav' from class 'Beluga_WhiteWhale'. Sample rate: 16000, Duration: 5.1685625 seconds
# Loaded '6202200E.wav' from class 'Beluga_WhiteWhale'. Sample rate: 80000, Duration: 3.3323125 seconds
# Loaded '6202200F.wav' from class 'Beluga_WhiteWhale'. Sample rate: 80000, Duration: 1.549075 seconds
# Loaded '6202200G.wav' from class 'Beluga_WhiteWhale'. Sample rate: 80000, Duration: 4.1789 seconds
# Loaded '6202200P.wav' from class 'Beluga_WhiteWhale'. Sample rate: 80000, Duration: 1.254825 seconds
# Loaded '6202200Q.wav' from class 'Beluga_WhiteWhale'. Sample rate: 80000, Duration: 4.4130625 seconds
# Loaded '6202200T.wav' from class 'Beluga_WhiteWhale'. Sample rate: 80000, Duration: 4.7372875 seconds
# Loaded '6202200W.wav' from class 'Beluga_WhiteWhale'. Sample rate: 80000, Duration: 1.305225 seconds
# Loaded '6202200Z.wav' from class 'Beluga_WhiteWhale'. Sample rate: 80000, Duration: 1.96655 seconds
# Loaded '62022012.wav' from class 'Beluga_WhiteWhale'. Sample rate: 80000, Duration: 1.089575 seconds
# Loaded '62022013.wav' from class 'Beluga_WhiteWhale'. Sample rate: 80000, Duration: 1.674225 seconds
# Loaded '62022014.wav' from class 'Beluga_WhiteWhale'. Sample rate: 80000, Duration: 1.5280625 seconds
# Loaded '62022016.wav' from class 'Beluga_WhiteWhale'. Sample rate: 80000, Duration: 1.7008 seconds
# Loaded '62022017.wav' from class 'Beluga_WhiteWhale'. Sample rate: 80000, Duration: 2.3518875 seconds
# Loaded '62022018.wav' from class 'Beluga_WhiteWhale'. Sample rate: 80000, Duration: 2.49805 seconds
# Loaded '62026001.wav' from class 'Beluga_WhiteWhale'. Sample rate: 20000, Duration: 2.1258 seconds
# Loaded '62026002.wav' from class 'Beluga_WhiteWhale'. Sample rate: 20000, Duration: 4.3827 seconds
# Loaded '62026003.wav' from class 'Beluga_WhiteWhale'. Sample rate: 20000, Duration: 5.8701 seconds
# Loaded '62026006.wav' from class 'Beluga_WhiteWhale'. Sample rate: 16000, Duration: 3.8974375 seconds
# Loaded '62026007.wav' from class 'Beluga_WhiteWhale'. Sample rate: 16000, Duration: 2.7570625 seconds
# Loaded '62026009.wav' from class 'Beluga_WhiteWhale'. Sample rate: 16000, Duration: 8.731875 seconds
# Loaded '6202600A.wav' from class 'Beluga_WhiteWhale'. Sample rate: 16000, Duration: 2.007375 seconds
# Loaded '6202600B.wav' from class 'Beluga_WhiteWhale'. Sample rate: 16000, Duration: 2.070125 seconds
# Loaded '6202600C.wav' from class 'Beluga_WhiteWhale'. Sample rate: 16000, Duration: 2.0034375 seconds
# Loaded '6202600D.wav' from class 'Beluga_WhiteWhale'. Sample rate: 16000, Duration: 2.654625 seconds
# Loaded '63015001.wav' from class 'Beluga_WhiteWhale'. Sample rate: 30000, Duration: 4.326466666666667 seconds
# Loaded '63015002.wav' from class 'Beluga_WhiteWhale'. Sample rate: 30000, Duration: 4.078633333333333 seconds
# Loaded '63015003.wav' from class 'Beluga_WhiteWhale'. Sample rate: 30000, Duration: 2.3434333333333335 seconds
# Loaded '63015004.wav' from class 'Beluga_WhiteWhale'. Sample rate: 30000, Duration: 3.0044666666666666 seconds
# Loaded '63015005.wav' from class 'Beluga_WhiteWhale'. Sample rate: 30000, Duration: 2.9171 seconds
# Loaded '63015006.wav' from class 'Beluga_WhiteWhale'. Sample rate: 16000, Duration: 4.3895 seconds
# Loaded '65030001.wav' from class 'Beluga_WhiteWhale'. Sample rate: 40000, Duration: 1.22235 seconds
# Loaded '65030009.wav' from class 'Beluga_WhiteWhale'. Sample rate: 40000, Duration: 3.3699 seconds
# Loaded '6503000F.wav' from class 'Beluga_WhiteWhale'. Sample rate: 40000, Duration: 1.37125 seconds
# Loaded '6503000H.wav' from class 'Beluga_WhiteWhale'. Sample rate: 40000, Duration: 0.61425 seconds
# Loaded '6503000G.wav' from class 'Beluga_WhiteWhale'. Sample rate: 40000, Duration: 0.5223 seconds
# Loaded '6503000I.wav' from class 'Beluga_WhiteWhale'. Sample rate: 40000, Duration: 0.64085 seconds
# Loaded '65033002.wav' from class 'Beluga_WhiteWhale'. Sample rate: 81920, Duration: 1.06171875 seconds
# Loaded '65033003.wav' from class 'Beluga_WhiteWhale'. Sample rate: 81920, Duration: 0.80390625 seconds
# Loaded '65033004.wav' from class 'Beluga_WhiteWhale'. Sample rate: 81920, Duration: 1.284375 seconds
# Loaded '65033007.wav' from class 'Beluga_WhiteWhale'. Sample rate: 81920, Duration: 1.41796875 seconds
# Loaded '6503300C.wav' from class 'Beluga_WhiteWhale'. Sample rate: 81920, Duration: 1.41796875 seconds
# Loaded '6503300D.wav' from class 'Beluga_WhiteWhale'. Sample rate: 81920, Duration: 1.31484375 seconds
# Loaded '6503300E.wav' from class 'Beluga_WhiteWhale'. Sample rate: 40960, Duration: 5.671875 seconds
# Loaded '6503300H.wav' from class 'Beluga_WhiteWhale'. Sample rate: 40960, Duration: 1.40859375 seconds
# Loaded '6503300J.wav' from class 'Beluga_WhiteWhale'. Sample rate: 40960, Duration: 1.38984375 seconds
# Loaded '6503300K.wav' from class 'Beluga_WhiteWhale'. Sample rate: 10240, Duration: 2.8359375 seconds
# Loaded '51041C01.wav' from class 'BottlenoseDolphin'. Sample rate: 30000, Duration: 0.9715333333333334 seconds
# Loaded '56006001.wav' from class 'BottlenoseDolphin'. Sample rate: 60600, Duration: 0.9747854785478548 seconds
# Loaded '56006002.wav' from class 'BottlenoseDolphin'. Sample rate: 60600, Duration: 1.2184818481848185 seconds
# Loaded '56006003.wav' from class 'BottlenoseDolphin'. Sample rate: 60600, Duration: 1.1716171617161717 seconds
# Loaded '56006004.wav' from class 'BottlenoseDolphin'. Sample rate: 60600, Duration: 1.2278547854785478 seconds
# Loaded '56006005.wav' from class 'BottlenoseDolphin'. Sample rate: 60600, Duration: 1.1716171617161717 seconds
# Loaded '56006006.wav' from class 'BottlenoseDolphin'. Sample rate: 60600, Duration: 1.0966336633663367 seconds
# Loaded '5600600A.wav' from class 'BottlenoseDolphin'. Sample rate: 60600, Duration: 1.180990099009901 seconds
# Loaded '5600600B.wav' from class 'BottlenoseDolphin'. Sample rate: 60600, Duration: 1.452805280528053 seconds
# Loaded '5600600D.wav' from class 'BottlenoseDolphin'. Sample rate: 60600, Duration: 0.7685808580858086 seconds
# Loaded '5600600E.wav' from class 'BottlenoseDolphin'. Sample rate: 60600, Duration: 1.0122772277227723 seconds
# Loaded '89514001.wav' from class 'BottlenoseDolphin'. Sample rate: 81920, Duration: 1.125 seconds
# Loaded '89514002.wav' from class 'BottlenoseDolphin'. Sample rate: 81920, Duration: 1.125 seconds
# Loaded '89514003.wav' from class 'BottlenoseDolphin'. Sample rate: 81920, Duration: 1.5 seconds
# Loaded '89514004.wav' from class 'BottlenoseDolphin'. Sample rate: 81920, Duration: 1.5 seconds
# Loaded '89514005.wav' from class 'BottlenoseDolphin'. Sample rate: 81920, Duration: 1.875 seconds
# Loaded '89514010.wav' from class 'BottlenoseDolphin'. Sample rate: 81920, Duration: 1.303125 seconds
# Loaded '89514011.wav' from class 'BottlenoseDolphin'. Sample rate: 81920, Duration: 1.303125 seconds
# Loaded '89514012.wav' from class 'BottlenoseDolphin'. Sample rate: 81920, Duration: 1.303125 seconds
# Loaded '89514013.wav' from class 'BottlenoseDolphin'. Sample rate: 81920, Duration: 1.303125 seconds
# Loaded '89514014.wav' from class 'BottlenoseDolphin'. Sample rate: 81920, Duration: 1.303125 seconds
# Loaded '89514015.wav' from class 'BottlenoseDolphin'. Sample rate: 81920, Duration: 1.303125 seconds
# Loaded '89514017.wav' from class 'BottlenoseDolphin'. Sample rate: 81920, Duration: 1.303125 seconds
# Loaded '89514018.wav' from class 'BottlenoseDolphin'. Sample rate: 81920, Duration: 1.303125 seconds
# Loaded '72021005.wav' from class 'BowheadWhale'. Sample rate: 10240, Duration: 142.5 seconds
# Loaded '7202100T.wav' from class 'BowheadWhale'. Sample rate: 10240, Duration: 2.8359375 seconds
# Loaded '7202100V.wav' from class 'BowheadWhale'. Sample rate: 10240, Duration: 2.8359375 seconds
# Loaded '7202100Z.wav' from class 'BowheadWhale'. Sample rate: 10240, Duration: 2.465625 seconds
# Loaded '78018002.wav' from class 'BowheadWhale'. Sample rate: 10240, Duration: 45.3 seconds
# Loaded '78018003.wav' from class 'BowheadWhale'. Sample rate: 10240, Duration: 11.34375 seconds
# Loaded '7801800B.wav' from class 'BowheadWhale'. Sample rate: 10240, Duration: 2.7515625 seconds
# Loaded '7801800D.wav' from class 'BowheadWhale'. Sample rate: 10240, Duration: 2.7515625 seconds
# Loaded '7801800H.wav' from class 'BowheadWhale'. Sample rate: 10240, Duration: 3.61875 seconds
# Loaded '7801800J.wav' from class 'BowheadWhale'. Sample rate: 10240, Duration: 3.61875 seconds
# Loaded '7202100Q.wav' from class 'BowheadWhale'. Sample rate: 10240, Duration: 2.8359375 seconds
# Loaded '88006001.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 2.6462 seconds
# Loaded '88006003.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 3.6159 seconds
# Loaded '88006005.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 3.6178 seconds
# Loaded '88006006.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 3.7755 seconds
# Loaded '88006007.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 2.8372 seconds
# Loaded '88006008.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 3.3554 seconds
# Loaded '8800600A.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 4.5024 seconds
# Loaded '8800600C.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 9.7083 seconds
# Loaded '8800600D.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 6.5727 seconds
# Loaded '8800600E.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 4.2948 seconds
# Loaded '8800600F.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 4.9446 seconds
# Loaded '8800600G.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 5.1657 seconds
# Loaded '8800600H.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 5.3667 seconds
# Loaded '8800600I.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 8.7234 seconds
# Loaded '8800600J.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 4.1808 seconds
# Loaded '8800600K.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 5.0652 seconds
# Loaded '8800600L.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 5.025 seconds
# Loaded '8800600N.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 5.5674 seconds
# Loaded '8800600O.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 3.8816 seconds
# Loaded '8800600Q.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 3.2042 seconds
# Loaded '8800600P.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 5.2239 seconds
# Loaded '8800600R.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 6.2809 seconds
# Loaded '8800600S.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 3.576 seconds
# Loaded '8800600T.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 4.1782 seconds
# Loaded '8800600U.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 5.4741 seconds
# Loaded '8800600W.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 3.9366 seconds
# Loaded '8800600Y.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 3.7265 seconds
# Loaded '8800600Z.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 3.9321 seconds
# Loaded '88006013.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 3.6912 seconds
# Loaded '88006016.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 6.5316 seconds
# Loaded '88006017.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 5.6304 seconds
# Loaded '8800601B.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 4.3098 seconds
# Loaded '8800601C.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 3.9343 seconds
# Loaded '8800601L.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 2.5595 seconds
# Loaded '8800601U.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 2.975 seconds
# Loaded '8800601Y.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 2.73 seconds
# Loaded '8800602Q.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 1.824 seconds
# Loaded '8800602S.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 4.2102 seconds
# Loaded '8800602T.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 3.7446 seconds
# Loaded '8800602U.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 4.3848 seconds
# Loaded '8800602Z.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 4.0758 seconds
# Loaded '88006030.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 4.1268 seconds
# Loaded '88006031.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 4.0035 seconds
# Loaded '88006032.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 3.642 seconds
# Loaded '88006033.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 5.0157 seconds
# Loaded '88006034.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 6.0279 seconds
# Loaded '88006036.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 7.1124 seconds
# Loaded '88006037.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 5.8833 seconds
# Loaded '88006038.wav' from class 'BowheadWhale'. Sample rate: 10000, Duration: 7.4469 seconds
# Loaded '83006002.wav' from class 'ClymeneDolphin'. Sample rate: 81920, Duration: 2.1984375 seconds
# Loaded '83006001.wav' from class 'ClymeneDolphin'. Sample rate: 81920, Duration: 2.1984375 seconds
# Loaded '83006003.wav' from class 'ClymeneDolphin'. Sample rate: 81920, Duration: 2.8359375 seconds
# Loaded '83006009.wav' from class 'ClymeneDolphin'. Sample rate: 81920, Duration: 1.41796875 seconds
# Loaded '83006008.wav' from class 'ClymeneDolphin'. Sample rate: 81920, Duration: 2.8359375 seconds
# Loaded '8300600A.wav' from class 'ClymeneDolphin'. Sample rate: 81920, Duration: 1.41796875 seconds
# Loaded '8300600B.wav' from class 'ClymeneDolphin'. Sample rate: 81920, Duration: 1.41796875 seconds
# Loaded '8300600C.wav' from class 'ClymeneDolphin'. Sample rate: 81920, Duration: 1.41796875 seconds
# Loaded '8300600E.wav' from class 'ClymeneDolphin'. Sample rate: 81920, Duration: 1.41796875 seconds
# Loaded '8300600D.wav' from class 'ClymeneDolphin'. Sample rate: 81920, Duration: 2.0671875 seconds
# Loaded '8300600F.wav' from class 'ClymeneDolphin'. Sample rate: 81920, Duration: 2.4609375 seconds
# Loaded '8300601F.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 2.6055462184873948 seconds
# Loaded '8300600N.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 2.0458823529411765 seconds
# Loaded '8300601G.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 2.4003361344537817 seconds
# Loaded '8300601J.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 2.1530852340936373 seconds
# Loaded '8300601K.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 2.599951980792317 seconds
# Loaded '8300601R.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 2.8169747899159665 seconds
# Loaded '8300601V.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 2.207563025210084 seconds
# Loaded '83006022.wav' from class 'ClymeneDolphin'. Sample rate: 41600, Duration: 1.4475240384615384 seconds
# Loaded '8300602B.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 2.6739495798319326 seconds
# Loaded '8300602C.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 2.680168067226891 seconds
# Loaded '8300602E.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 2.6615126050420166 seconds
# Loaded '8300602M.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 3.1838655462184873 seconds
# Loaded '8300602Q.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 3.0624129651860743 seconds
# Loaded '8300602T.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 2.2341176470588233 seconds
# Loaded '83006031.wav' from class 'ClymeneDolphin'. Sample rate: 41600, Duration: 1.711826923076923 seconds
# Loaded '8300603C.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 3.2278991596638655 seconds
# Loaded '8300603S.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 2.886374549819928 seconds
# Loaded '8300603U.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 2.565666266506603 seconds
# Loaded '83006047.wav' from class 'ClymeneDolphin'. Sample rate: 41600, Duration: 1.8648076923076924 seconds
# Loaded '8300604A.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 2.294297719087635 seconds
# Loaded '8300604C.wav' from class 'ClymeneDolphin'. Sample rate: 81920, Duration: 0.80711669921875 seconds
# Loaded '8300604D.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 1.7128091236494598 seconds
# Loaded '8300604E.wav' from class 'ClymeneDolphin'. Sample rate: 81920, Duration: 1.484228515625 seconds
# Loaded '8300604F.wav' from class 'ClymeneDolphin'. Sample rate: 81920, Duration: 1.5390625 seconds
# Loaded '8300604G.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 1.9056422569027611 seconds
# Loaded '8300604H.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 1.9197599039615847 seconds
# Loaded '8300604I.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 1.9759903961584633 seconds
# Loaded '8300604J.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 0.5697118847539016 seconds
# Loaded '8300604K.wav' from class 'ClymeneDolphin'. Sample rate: 41600, Duration: 1.4604086538461538 seconds
# Loaded '8300604L.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 1.3697358943577431 seconds
# Loaded '8300604M.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 1.622797118847539 seconds
# Loaded '8300604N.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 2.0135234093637453 seconds
# Loaded '8300604P.wav' from class 'ClymeneDolphin'. Sample rate: 41600, Duration: 1.3239663461538462 seconds
# Loaded '8300604O.wav' from class 'ClymeneDolphin'. Sample rate: 41600, Duration: 1.2957932692307692 seconds
# Loaded '8300604Q.wav' from class 'ClymeneDolphin'. Sample rate: 43900, Duration: 2.0363097949886106 seconds
# Loaded '8300604R.wav' from class 'ClymeneDolphin'. Sample rate: 42100, Duration: 1.2942755344418053 seconds
# Loaded '8300604S.wav' from class 'ClymeneDolphin'. Sample rate: 60600, Duration: 20.759455445544553 seconds
# Loaded '8300604T.wav' from class 'ClymeneDolphin'. Sample rate: 60600, Duration: 24.106072607260725 seconds
# Loaded '83035001.wav' from class 'ClymeneDolphin'. Sample rate: 81920, Duration: 1.41796875 seconds
# Loaded '83035002.wav' from class 'ClymeneDolphin'. Sample rate: 81920, Duration: 1.41796875 seconds
# Loaded '83035003.wav' from class 'ClymeneDolphin'. Sample rate: 81920, Duration: 2.8359375 seconds
# Loaded '83035007.wav' from class 'ClymeneDolphin'. Sample rate: 81920, Duration: 0.708984375 seconds
# Loaded '83035006.wav' from class 'ClymeneDolphin'. Sample rate: 81920, Duration: 1.41796875 seconds
# Loaded '8303500N.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 1.914765906362545 seconds
# Loaded '8303501L.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 2.318607442977191 seconds
# Loaded '8303501W.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 3.7877551020408164 seconds
# Loaded '8303503N.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 1.1355342136854742 seconds
# Loaded '8303503O.wav' from class 'ClymeneDolphin'. Sample rate: 81920, Duration: 0.58543701171875 seconds
# Loaded '8303503S.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 1.5951500600240096 seconds
# Loaded '8303503Q.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 1.2878091236494598 seconds
# Loaded '8303503R.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 0.30516806722689077 seconds
# Loaded '8303503P.wav' from class 'ClymeneDolphin'. Sample rate: 166600, Duration: 1.3518787515006003 seconds
# Loaded '58014015.wav' from class 'CommonDolphin'. Sample rate: 43900, Duration: 0.5235535307517084 seconds
# Loaded '58014014.wav' from class 'CommonDolphin'. Sample rate: 43900, Duration: 0.6088382687927107 seconds
# Loaded '5801400J.wav' from class 'CommonDolphin'. Sample rate: 43900, Duration: 1.08624145785877 seconds
# Loaded '58014028.wav' from class 'CommonDolphin'. Sample rate: 43900, Duration: 1.738861047835991 seconds
# Loaded '5801402C.wav' from class 'CommonDolphin'. Sample rate: 43900, Duration: 1.3456036446469248 seconds
# Loaded '58014034.wav' from class 'CommonDolphin'. Sample rate: 43900, Duration: 1.6236902050113895 seconds
# Loaded '58014036.wav' from class 'CommonDolphin'. Sample rate: 43900, Duration: 1.7665148063781322 seconds
# Loaded '5801403O.wav' from class 'CommonDolphin'. Sample rate: 43900, Duration: 1.0287699316628702 seconds
# Loaded '5801404D.wav' from class 'CommonDolphin'. Sample rate: 43900, Duration: 0.7644191343963553 seconds
# Loaded '5801403R.wav' from class 'CommonDolphin'. Sample rate: 43900, Duration: 1.9834168564920274 seconds
# Loaded '5801404R.wav' from class 'CommonDolphin'. Sample rate: 60600, Duration: 53.03815181518152 seconds
# Loaded '5801404S.wav' from class 'CommonDolphin'. Sample rate: 60600, Duration: 53.04818481848185 seconds
# Loaded '5801404T.wav' from class 'CommonDolphin'. Sample rate: 60600, Duration: 52.13641914191419 seconds
# Loaded '5801404U.wav' from class 'CommonDolphin'. Sample rate: 60600, Duration: 52.13993399339934 seconds
# Loaded '5801404V.wav' from class 'CommonDolphin'. Sample rate: 60600, Duration: 52.13993399339934 seconds
# Loaded '7500302U.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 2.3570710784313724 seconds
# Loaded '7500303M.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 2.0383823529411766 seconds
# Loaded '7500303N.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 1.7682352941176471 seconds
# Loaded '7500303Q.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 2.271691176470588 seconds
# Loaded '7500303R.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 2.910220588235294 seconds
# Loaded '7500303Y.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 1.473529411764706 seconds
# Loaded '7500303Z.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 1.9401470588235294 seconds
# Loaded '75003041.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 2.308529411764706 seconds
# Loaded '75003042.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 1.7436764705882353 seconds
# Loaded '75003043.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 1.9524264705882353 seconds
# Loaded '75003044.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 3.3891176470588236 seconds
# Loaded '75003045.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 1.755955882352941 seconds
# Loaded '75003047.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 0.9823529411764705 seconds
# Loaded '7500304F.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 2.685919117647059 seconds
# Loaded '7500304G.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 2.2903186274509806 seconds
# Loaded '7500304H.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 2.248676470588235 seconds
# Loaded '7500304I.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 2.1029289215686275 seconds
# Loaded '7500304K.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 2.2903186274509806 seconds
# Loaded '7500304L.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 2.9774142156862746 seconds
# Loaded '7500304M.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 2.6234558823529412 seconds
# Loaded '7500304N.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 2.12375 seconds
# Loaded '7500304O.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 2.7900245098039216 seconds
# Loaded '7500304P.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 0.40503676470588235 seconds
# Loaded '7500304Q.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 0.2206985294117647 seconds
# Loaded '75003051.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 3.1684313725490196 seconds
# Loaded '75003052.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 2.14921568627451 seconds
# Loaded '75003053.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 2.802843137254902 seconds
# Loaded '75003056.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 0.9859803921568627 seconds
# Loaded '75003057.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 0.7865686274509804 seconds
# Loaded '75003058.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 1.3737254901960785 seconds
# Loaded '7500305C.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 0.8914705882352941 seconds
# Loaded '7500305D.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 0.7422549019607844 seconds
# Loaded '7500305H.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 1.1632352941176471 seconds
# Loaded '7500305I.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 1.052450980392157 seconds
# Loaded '7500305M.wav' from class 'CommonDolphin'. Sample rate: 81600, Duration: 1.157095588235294 seconds
# Loaded '87003005.wav' from class 'CommonDolphin'. Sample rate: 81920, Duration: 1.41796875 seconds
# Loaded '87003006.wav' from class 'CommonDolphin'. Sample rate: 81920, Duration: 1.41796875 seconds
# Loaded '6102100P.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.90234375 seconds
# Loaded '6102100Q.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.85078125 seconds
# Loaded '6102100T.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.5390625 seconds
# Loaded '6102100W.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.59296875 seconds
# Loaded '6102100X.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.29296875 seconds
# Loaded '6102100Y.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.3140625 seconds
# Loaded '61021011.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.54609375 seconds
# Loaded '61021012.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.66328125 seconds
# Loaded '61021019.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.4828125 seconds
# Loaded '6102101A.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.4828125 seconds
# Loaded '6102101B.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.309375 seconds
# Loaded '6102101C.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.309375 seconds
# Loaded '6102101F.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.64453125 seconds
# Loaded '6102101N.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.69609375 seconds
# Loaded '6102101T.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.61640625 seconds
# Loaded '61023001.wav' from class 'FalseKillerWhale'. Sample rate: 30000, Duration: 4.005933333333333 seconds
# Loaded '6102101U.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.65625 seconds
# Loaded '61023002.wav' from class 'FalseKillerWhale'. Sample rate: 30000, Duration: 5.768633333333334 seconds
# Loaded '61023005.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 1.01561279296875 seconds
# Loaded '61023006.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 1.00936279296875 seconds
# Loaded '61023008.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.98436279296875 seconds
# Loaded '61023009.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.92186279296875 seconds
# Loaded '6102300A.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 2.10623779296875 seconds
# Loaded '6102300C.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 1.37186279296875 seconds
# Loaded '6102300D.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 1.14686279296875 seconds
# Loaded '6102300F.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 1.17186279296875 seconds
# Loaded '6102300H.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.61875 seconds
# Loaded '6102300I.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 1.09373779296875 seconds
# Loaded '6102300P.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.97811279296875 seconds
# Loaded '6102300J.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 1.09373779296875 seconds
# Loaded '6102300R.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.7359375 seconds
# Loaded '6102300S.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.68671875 seconds
# Loaded '6102300U.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.85311279296875 seconds
# Loaded '6102300V.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.63984375 seconds
# Loaded '6102300W.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.89998779296875 seconds
# Loaded '6102300X.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 1.08515625 seconds
# Loaded '6102300Z.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.71561279296875 seconds
# Loaded '61023010.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.60234375 seconds
# Loaded '61023015.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.84609375 seconds
# Loaded '61023016.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.60703125 seconds
# Loaded '61023018.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 1.05936279296875 seconds
# Loaded '61023019.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.79453125 seconds
# Loaded '6102301A.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.54140625 seconds
# Loaded '6102301B.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.54140625 seconds
# Loaded '6102301D.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 1.059375 seconds
# Loaded '6102301E.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.5578125 seconds
# Loaded '6102301I.wav' from class 'FalseKillerWhale'. Sample rate: 30000, Duration: 2.7547 seconds
# Loaded '6102301J.wav' from class 'FalseKillerWhale'. Sample rate: 81920, Duration: 0.50458984375 seconds
# Loaded '95003001.wav' from class 'FalseKillerWhale'. Sample rate: 80000, Duration: 1.20675 seconds
# Loaded '95003002.wav' from class 'FalseKillerWhale'. Sample rate: 80000, Duration: 2.0008625 seconds
# Loaded '95003003.wav' from class 'FalseKillerWhale'. Sample rate: 80000, Duration: 1.4231125 seconds
# Loaded '95003004.wav' from class 'FalseKillerWhale'. Sample rate: 80000, Duration: 2.2113875 seconds
# Loaded '95003005.wav' from class 'FalseKillerWhale'. Sample rate: 80000, Duration: 1.6021625 seconds
# Loaded '95003006.wav' from class 'FalseKillerWhale'. Sample rate: 80000, Duration: 1.44595 seconds
# Loaded '95003007.wav' from class 'FalseKillerWhale'. Sample rate: 80000, Duration: 1.9188 seconds
# Loaded '95003008.wav' from class 'FalseKillerWhale'. Sample rate: 80000, Duration: 2.248 seconds
# Loaded '95003009.wav' from class 'FalseKillerWhale'. Sample rate: 80000, Duration: 1.6236 seconds
# Loaded '9500300A.wav' from class 'FalseKillerWhale'. Sample rate: 80000, Duration: 1.6506875 seconds
# Loaded '9500300B.wav' from class 'FalseKillerWhale'. Sample rate: 80000, Duration: 3.3046 seconds
# Loaded '91008005.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 1.89061279296875 seconds
# Loaded '91008008.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 0.6882568359375 seconds
# Loaded '91008009.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 0.7238525390625 seconds
# Loaded '9100800A.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 0.5953857421875 seconds
# Loaded '9100800C.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 0.72607421875 seconds
# Loaded '9100800B.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 0.670458984375 seconds
# Loaded '9100800D.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 0.8543701171875 seconds
# Loaded '9100800E.wav' from class 'Fraser'sDolphin'. Sample rate: 60600, Duration: 7.428003300330033 seconds
# Loaded '9100800F.wav' from class 'Fraser'sDolphin'. Sample rate: 60600, Duration: 10.409455445544554 seconds
# Loaded '91010004.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 1.41796875 seconds
# Loaded '9101000F.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 1.41796875 seconds
# Loaded '9101000H.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 3.78123779296875 seconds
# Loaded '9101000K.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 0.821875 seconds
# Loaded '9101000S.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 2.14373779296875 seconds
# Loaded '9101000W.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 3.78123779296875 seconds
# Loaded '9101000X.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 3.54373779296875 seconds
# Loaded '9101000Y.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 3.78123779296875 seconds
# Loaded '9101000Z.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 3.78123779296875 seconds
# Loaded '91010010.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 1.03828125 seconds
# Loaded '91010014.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 1.41796875 seconds
# Loaded '91010019.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 1.29061279296875 seconds
# Loaded '9101001H.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 3.48748779296875 seconds
# Loaded '9101001D.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 3.78123779296875 seconds
# Loaded '9101001L.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 3.71873779296875 seconds
# Loaded '9101001M.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 1.89061279296875 seconds
# Loaded '9101001O.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 1.02421875 seconds
# Loaded '9101001P.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 0.8109375 seconds
# Loaded '9101001Q.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 0.8662353515625 seconds
# Loaded '9101001R.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 1.0953369140625 seconds
# Loaded '9101001S.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 0.775634765625 seconds
# Loaded '9101001T.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 0.9467529296875 seconds
# Loaded '9101001U.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 0.3405029296875 seconds
# Loaded '9101001V.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 1.0131591796875 seconds
# Loaded '9101001W.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 0.94541015625 seconds
# Loaded '9101001X.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 1.137890625 seconds
# Loaded '9101001Y.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 1.136865234375 seconds
# Loaded '9101001Z.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 0.46922607421875 seconds
# Loaded '91010020.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 0.54708251953125 seconds
# Loaded '91010021.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 0.59913330078125 seconds
# Loaded '91010022.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 0.71383056640625 seconds
# Loaded '91010023.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 0.9802001953125 seconds
# Loaded '91010024.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 0.766748046875 seconds
# Loaded '91010025.wav' from class 'Fraser'sDolphin'. Sample rate: 60600, Duration: 30.025082508250826 seconds
# Loaded '91010026.wav' from class 'Fraser'sDolphin'. Sample rate: 60600, Duration: 17.264422442244225 seconds
# Loaded '91010027.wav' from class 'Fraser'sDolphin'. Sample rate: 60600, Duration: 14.374653465346535 seconds
# Loaded '91010028.wav' from class 'Fraser'sDolphin'. Sample rate: 60600, Duration: 12.945742574257427 seconds
# Loaded '91010029.wav' from class 'Fraser'sDolphin'. Sample rate: 60600, Duration: 30.943894389438945 seconds
# Loaded '9101002A.wav' from class 'Fraser'sDolphin'. Sample rate: 60600, Duration: 30.943894389438945 seconds
# Loaded '9101002B.wav' from class 'Fraser'sDolphin'. Sample rate: 60600, Duration: 24.506930693069307 seconds
# Loaded '91013001.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 1.89061279296875 seconds
# Loaded '91013002.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 1.89061279296875 seconds
# Loaded '9101002C.wav' from class 'Fraser'sDolphin'. Sample rate: 60600, Duration: 21.86772277227723 seconds
# Loaded '91013003.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 1.89061279296875 seconds
# Loaded '91013004.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 1.89061279296875 seconds
# Loaded '91013005.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 1.89061279296875 seconds
# Loaded '91013008.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 1.89061279296875 seconds
# Loaded '9101300A.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 1.89061279296875 seconds
# Loaded '9101300B.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 3.78123779296875 seconds
# Loaded '9101300C.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 3.78123779296875 seconds
# Loaded '9101300D.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 3.78123779296875 seconds
# Loaded '9101300E.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 1.89061279296875 seconds
# Loaded '9101300F.wav' from class 'Fraser'sDolphin'. Sample rate: 81920, Duration: 1.89061279296875 seconds
# ...
# Loaded '7200500M.wav' from class 'White_beakedDolphin'. Sample rate: 60600, Duration: 1.965990099009901 seconds
# Loaded '7200500N.wav' from class 'White_beakedDolphin'. Sample rate: 60600, Duration: 2.765841584158416 seconds
# Loaded '7200500P.wav' from class 'White_beakedDolphin'. Sample rate: 60600, Duration: 2.907871287128713 seconds
# Loaded '7200500U.wav' from class 'White_beakedDolphin'. Sample rate: 60600, Duration: 2.024257425742574 seconds
# Loaded '7200500V.wav' from class 'White_beakedDolphin'. Sample rate: 60600, Duration: 2.407095709570957 seconds
# Loaded '7200500W.wav' from class 'White_beakedDolphin'. Sample rate: 60600, Duration: 2.2443894389438945 seconds
# Loaded '7200500Y.wav' from class 'White_beakedDolphin'. Sample rate: 60600, Duration: 2.565016501650165 seconds
# Loaded '7200500Z.wav' from class 'White_beakedDolphin'. Sample rate: 60600, Duration: 2.1582508250825083 seconds
# Loaded '61072006.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 3.1389625 seconds
# Loaded '6107200E.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 2.0598875 seconds
# Loaded '61072004.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 2.2615875 seconds
# Loaded '61072005.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 1.936 seconds
# Loaded '6107200G.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 2.702225 seconds
# Loaded '6107200H.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 1.7274375 seconds
# Loaded '6107200K.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 2.35875 seconds
# Loaded '6107200M.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 1.91475 seconds
# Loaded '6107200O.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 2.150625 seconds
# Loaded '6107200R.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 2.1991875 seconds
# Loaded '6107200S.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 2.442 seconds
# Loaded '6107200T.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 1.80375 seconds
# Loaded '6107200Z.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 2.54 seconds
# Loaded '6107201H.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 1.8084 seconds
# Loaded '61072013.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 2.5781 seconds
# Loaded '6107201N.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 1.6166 seconds
# Loaded '6107201P.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 2.3016 seconds
# Loaded '6107201X.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 1.507 seconds
# Loaded '61072020.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 1.37 seconds
# Loaded '61072021.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 1.3508625 seconds
# Loaded '61072022.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 1.4337375 seconds
# Loaded '61072023.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 2.3205 seconds
# Loaded '6107202D.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 2.79295 seconds
# Loaded '6107202K.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 3.1210375 seconds
# Loaded '6107202N.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 2.8686625 seconds
# Loaded '6107202L.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 3.482775 seconds
# Loaded '6107202O.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 2.3302625 seconds
# Loaded '6107202R.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 2.910725 seconds
# Loaded '6107202T.wav' from class 'White_sidedDolphin'. Sample rate: 80000, Duration: 3.078975 seconds
# Loaded '61072031.wav' from class 'White_sidedDolphin'. Sample rate: 60600, Duration: 23.230610561056107 seconds
# Loaded '61072032.wav' from class 'White_sidedDolphin'. Sample rate: 60600, Duration: 46.62925742574257 seconds
# Loaded '7500100Y.wav' from class 'White_sidedDolphin'. Sample rate: 166600, Duration: 2.409795918367347 seconds
# Loaded '75001019.wav' from class 'White_sidedDolphin'. Sample rate: 166600, Duration: 1.9689795918367348 seconds
# Loaded '7500101N.wav' from class 'White_sidedDolphin'. Sample rate: 166600, Duration: 2.6351020408163266 seconds
# Loaded '7500101P.wav' from class 'White_sidedDolphin'. Sample rate: 166600, Duration: 3.9281632653061225 seconds
# Loaded '75001021.wav' from class 'White_sidedDolphin'. Sample rate: 166600, Duration: 2.1648979591836737 seconds
# Loaded '7500102G.wav' from class 'White_sidedDolphin'. Sample rate: 166600, Duration: 2.84187274909964 seconds
# Loaded '7500102H.wav' from class 'White_sidedDolphin'. Sample rate: 166600, Duration: 3.177527010804322 seconds
# Loaded '7500102I.wav' from class 'White_sidedDolphin'. Sample rate: 166600, Duration: 1.7342136854741896 seconds
# Loaded '7500102R.wav' from class 'White_sidedDolphin'. Sample rate: 166600, Duration: 1.6894597839135654 seconds
# Loaded '7500102S.wav' from class 'White_sidedDolphin'. Sample rate: 166600, Duration: 3.9830972388955583 seconds
# Loaded '7500103D.wav' from class 'White_sidedDolphin'. Sample rate: 166600, Duration: 2.9649459783913565 seconds
# Loaded '7500103V.wav' from class 'White_sidedDolphin'. Sample rate: 166600, Duration: 2.3831452581032413 seconds
# Loaded '78007015.wav' from class 'White_sidedDolphin'. Sample rate: 148100, Duration: 1.8835313977042538 seconds
# Loaded '7800701J.wav' from class 'White_sidedDolphin'. Sample rate: 148100, Duration: 1.0587440918298447 seconds
# Loaded '78007038.wav' from class 'White_sidedDolphin'. Sample rate: 148100, Duration: 1.3505469277515192 seconds
# Loaded '7800703Q.wav' from class 'White_sidedDolphin'. Sample rate: 148100, Duration: 2.217380148548278 seconds
# Loaded '79004007.wav' from class 'White_sidedDolphin'. Sample rate: 148100, Duration: 1.253801485482782 seconds
# Loaded '79004016.wav' from class 'White_sidedDolphin'. Sample rate: 148100, Duration: 1.3336529372045915 seconds
# Loaded '79006014.wav' from class 'White_sidedDolphin'. Sample rate: 81920, Duration: 1.1983154296875 seconds
# Loaded '79006015.wav' from class 'White_sidedDolphin'. Sample rate: 81920, Duration: 1.01107177734375 seconds
# Loaded '79006016.wav' from class 'White_sidedDolphin'. Sample rate: 81920, Duration: 1.490625 seconds
# Loaded '79006017.wav' from class 'White_sidedDolphin'. Sample rate: 81920, Duration: 0.8896728515625 seconds
# Loaded '79006018.wav' from class 'White_sidedDolphin'. Sample rate: 81920, Duration: 0.7308837890625 seconds
# Loaded '79006019.wav' from class 'White_sidedDolphin'. Sample rate: 81920, Duration: 0.7752685546875 seconds
# Loaded '60009005.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 44.20166666666667 seconds
# Loaded '60009006.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 35.428333333333335 seconds
# Loaded '60009007.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 24.908333333333335 seconds
# Loaded '6000900L.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 5.9383333333333335 seconds
# Loaded '6000900M.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 5.998333333333333 seconds
# Loaded '61039001.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 72.31 seconds
# Loaded '61047009.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 93.01333333333334 seconds
# Loaded '6104700D.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 48.71666666666667 seconds
# Loaded '6104700E.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 42.79666666666667 seconds
# Loaded '6104700F.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 59.93833333333333 seconds
# Loaded '61048004.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 59.348333333333336 seconds
# Loaded '61048005.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 32.52166666666667 seconds
# Loaded '61048007.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 41.04833333333333 seconds
# Loaded '61064006.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 69.635 seconds
# Loaded '61064008.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 43.49333333333333 seconds
# Loaded '61064009.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 65.06666666666666 seconds
# Loaded '6106400A.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 51.126666666666665 seconds
# Loaded '6106400B.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 52.068333333333335 seconds
# Loaded '6106400D.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 31.403333333333332 seconds
# Loaded '6106400F.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 69.21333333333334 seconds
# Loaded '6106400J.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 74.465 seconds
# Loaded '6106400L.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 83.93333333333334 seconds
# Loaded '6106400O.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 27.321666666666665 seconds
# Loaded '61079002.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 90.32333333333334 seconds
# Loaded '61079005.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 44.775 seconds
# Loaded '61079006.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 31.58 seconds
# Loaded '61079007.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 32.655 seconds
# Loaded '61079009.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 35.155 seconds
# Loaded '6107900A.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 29.473333333333333 seconds
# Loaded '6107900B.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 64.13333333333334 seconds
# Loaded '6107900C.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 38.71 seconds
# Loaded '6107900D.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 81.46666666666667 seconds
# Loaded '6107900E.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 81.49 seconds
# Loaded '6107900F.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 66.98333333333333 seconds
# Loaded '6107900G.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 46.8 seconds
# Loaded '6107900H.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 87.1 seconds
# Loaded '6107900I.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 98.97333333333333 seconds
# Loaded '6107900J.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 101.91333333333333 seconds
# Loaded '6107900K.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 31.898333333333333 seconds
# Loaded '6107900L.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 25.005 seconds
# Loaded '6107900M.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 86.615 seconds
# Loaded '6107900N.wav' from class 'Fin_FinbackWhale'. Sample rate: 600, Duration: 75.92 seconds
# Loaded '78014003.wav' from class 'Fin_FinbackWhale'. Sample rate: 640, Duration: 24.0 seconds
# Loaded '78014004.wav' from class 'Fin_FinbackWhale'. Sample rate: 640, Duration: 24.0 seconds
# Loaded '78014005.wav' from class 'Fin_FinbackWhale'. Sample rate: 640, Duration: 24.0 seconds
# Loaded '78014006.wav' from class 'Fin_FinbackWhale'. Sample rate: 640, Duration: 24.0 seconds
# Loaded '78014007.wav' from class 'Fin_FinbackWhale'. Sample rate: 640, Duration: 24.0 seconds
# Loaded '78014008.wav' from class 'Fin_FinbackWhale'. Sample rate: 640, Duration: 24.0 seconds
# Loaded '78014009.wav' from class 'Fin_FinbackWhale'. Sample rate: 640, Duration: 24.0 seconds
# Loaded '7801400A.wav' from class 'Fin_FinbackWhale'. Sample rate: 640, Duration: 24.0 seconds
# Loaded '6608400I.wav' from class 'LeopardSeal'. Sample rate: 5000, Duration: 5.4742 seconds
# Loaded '6608400J.wav' from class 'LeopardSeal'. Sample rate: 5000, Duration: 2.6058 seconds
# Loaded '6608400N.wav' from class 'LeopardSeal'. Sample rate: 5000, Duration: 5.1712 seconds
# Loaded '6608400P.wav' from class 'LeopardSeal'. Sample rate: 5000, Duration: 2.4016 seconds
# Loaded '6608400Q.wav' from class 'LeopardSeal'. Sample rate: 5000, Duration: 7.2364 seconds
# Loaded '6608400R.wav' from class 'LeopardSeal'. Sample rate: 5000, Duration: 3.5708 seconds
# Loaded '6608400T.wav' from class 'LeopardSeal'. Sample rate: 5000, Duration: 6.794 seconds
# Loaded '6608400Z.wav' from class 'LeopardSeal'. Sample rate: 5000, Duration: 3.402 seconds
# Loaded '66084010.wav' from class 'LeopardSeal'. Sample rate: 5000, Duration: 2.34 seconds
# Loaded '66084013.wav' from class 'LeopardSeal'. Sample rate: 5000, Duration: 7.272 seconds
# Loaded '64103001.wav' from class 'MinkeWhale'. Sample rate: 1280, Duration: 0.94453125 seconds
# Loaded '64103002.wav' from class 'MinkeWhale'. Sample rate: 1280, Duration: 0.94453125 seconds
# Loaded '64103003.wav' from class 'MinkeWhale'. Sample rate: 1280, Duration: 0.94453125 seconds
# Loaded '64103004.wav' from class 'MinkeWhale'. Sample rate: 1280, Duration: 1.41796875 seconds
# Loaded '64103005.wav' from class 'MinkeWhale'. Sample rate: 1280, Duration: 1.41796875 seconds
# Loaded '64103006.wav' from class 'MinkeWhale'. Sample rate: 1280, Duration: 1.41796875 seconds
# Loaded '64103007.wav' from class 'MinkeWhale'. Sample rate: 1280, Duration: 1.41796875 seconds
# Loaded '64103008.wav' from class 'MinkeWhale'. Sample rate: 1280, Duration: 0.9703125 seconds
# Loaded '64103009.wav' from class 'MinkeWhale'. Sample rate: 1280, Duration: 1.41328125 seconds
# Loaded '6410300A.wav' from class 'MinkeWhale'. Sample rate: 1280, Duration: 1.3734375 seconds
# Loaded '6410300B.wav' from class 'MinkeWhale'. Sample rate: 1280, Duration: 1.25859375 seconds
# Loaded '64104001.wav' from class 'MinkeWhale'. Sample rate: 1280, Duration: 0.94453125 seconds
# Loaded '64104002.wav' from class 'MinkeWhale'. Sample rate: 1280, Duration: 0.70859375 seconds
# Loaded '64104003.wav' from class 'MinkeWhale'. Sample rate: 1280, Duration: 0.70859375 seconds
# Loaded '64104004.wav' from class 'MinkeWhale'. Sample rate: 1280, Duration: 1.4109375 seconds
# Loaded '64104005.wav' from class 'MinkeWhale'. Sample rate: 1280, Duration: 1.3359375 seconds
# Loaded '64104006.wav' from class 'MinkeWhale'. Sample rate: 1280, Duration: 1.4109375 seconds
# Loaded '64041002.wav' from class 'WeddellSeal'. Sample rate: 20480, Duration: 10.4625 seconds
# Loaded '6404200B.wav' from class 'WeddellSeal'. Sample rate: 43900, Duration: 31.802004555808654 seconds
#
# Summary:
# Class 'AtlanticSpottedDolphin has 58 instances.
# Class 'BeardedSeal has 37 instances.
# Class 'Beluga_WhiteWhale has 50 instances.
# Class 'BottlenoseDolphin has 24 instances.
# Class 'BowheadWhale has 60 instances.
# Class 'ClymeneDolphin has 63 instances.
# Class 'CommonDolphin has 52 instances.
# Class 'FalseKillerWhale has 59 instances.
# Class 'Fraser'sDolphin has 87 instances.
# Class 'Grampus_Risso'sDolphin has 67 instances.
# Class 'HarpSeal has 47 instances.
# Class 'HumpbackWhale has 64 instances.
# Class 'KillerWhale has 35 instances.
# Class 'Long_FinnedPilotWhale has 70 instances.
# Class 'MelonHeadedWhale has 63 instances.
# Class 'Narwhal has 50 instances.
# Class 'NorthernRightWhale has 54 instances.
# Class 'PantropicalSpottedDolphin has 66 instances.
# Class 'RossSeal has 50 instances.
# Class 'Rough_ToothedDolphin has 50 instances.
# Class 'Short_Finned(Pacific)PilotWhale has 67 instances.
# Class 'SouthernRightWhale has 25 instances.
# Class 'SpermWhale has 75 instances.
# Class 'SpinnerDolphin has 114 instances.
# Class 'StripedDolphin has 81 instances.
# Class 'Walrus has 38 instances.
# Class 'White_beakedDolphin has 57 instances.
# Class 'White_sidedDolphin has 55 instances.
# Class 'Fin_FinbackWhale has 50 instances.
# Class 'LeopardSeal has 10 instances.
# Class 'MinkeWhale has 17 instances.
# Class 'WeddellSeal has 2 instances.
# Total number of instances: 1697

# %%
# Print summary in a table format
# Create a DataFrame from the class counts
class_summary_df = pd.DataFrame(list(class_counts.items()), columns=['Class', 'Number of Instances'])

# Calculate the total number of instances
total_instances = class_summary_df['Number of Instances'].sum()

# Calculate the total number of classes
total_classes = len(class_summary_df)

# Append these totals to the DataFrame
total_instances_df = pd.DataFrame([['Total Instances', total_instances]], columns=['Class', 'Number of Instances'])
total_classes_df = pd.DataFrame([['Total Classes', total_classes]], columns=['Class', 'Number of Instances'])
class_summary_df = pd.concat([class_summary_df, total_instances_df, total_classes_df], ignore_index=True)

# Display the DataFrame as styled table
class_summary_styled = class_summary_df.style.set_properties(**{'text-align': 'left'})
class_summary_styled.set_table_styles([dict(selector='th', props=[('text-align', 'left')])])

# Highlight the total rows
def highlight_totals(row):
    if 'Total' in row['Class']:
        return ['font-weight: bold; background-color: #00008B']*2  # Light blue background for total rows
    return ['']*2

class_summary_styled = class_summary_styled.apply(highlight_totals, axis=1)
class_summary_styled
# Out:
# <style type="text/css">
# #T_8470a th {
#   text-align: left;
# }
# #T_8470a_row0_col0, #T_8470a_row0_col1, #T_8470a_row1_col0, #T_8470a_row1_col1, #T_8470a_row2_col0, #T_8470a_row2_col1, #T_8470a_row3_col0, #T_8470a_row3_col1, #T_8470a_row4_col0, #T_8470a_row4_col1, #T_8470a_row5_col0, #T_8470a_row5_col1, #T_8470a_row6_col0, #T_8470a_row6_col1, #T_8470a_row7_col0, #T_8470a_row7_col1, #T_8470a_row8_col0, #T_8470a_row8_col1, #T_8470a_row9_col0, #T_8470a_row9_col1, #T_8470a_row10_col0, #T_8470a_row10_col1, #T_8470a_row11_col0, #T_8470a_row11_col1, #T_8470a_row12_col0, #T_8470a_row12_col1, #T_8470a_row13_col0, #T_8470a_row13_col1, #T_8470a_row14_col0, #T_8470a_row14_col1, #T_8470a_row15_col0, #T_8470a_row15_col1, #T_8470a_row16_col0, #T_8470a_row16_col1, #T_8470a_row17_col0, #T_8470a_row17_col1, #T_8470a_row18_col0, #T_8470a_row18_col1, #T_8470a_row19_col0, #T_8470a_row19_col1, #T_8470a_row20_col0, #T_8470a_row20_col1, #T_8470a_row21_col0, #T_8470a_row21_col1, #T_8470a_row22_col0, #T_8470a_row22_col1, #T_8470a_row23_col0, #T_8470a_row23_col1, #T_8470a_row24_col0, #T_8470a_row24_col1, #T_8470a_row25_col0, #T_8470a_row25_col1, #T_8470a_row26_col0, #T_8470a_row26_col1, #T_8470a_row27_col0, #T_8470a_row27_col1, #T_8470a_row28_col0, #T_8470a_row28_col1, #T_8470a_row29_col0, #T_8470a_row29_col1, #T_8470a_row30_col0, #T_8470a_row30_col1, #T_8470a_row31_col0, #T_8470a_row31_col1 {
#   text-align: left;
# }
# #T_8470a_row32_col0, #T_8470a_row32_col1, #T_8470a_row33_col0, #T_8470a_row33_col1 {
#   text-align: left;
#   font-weight: bold;
#   background-color: #00008B;
# }
# </style>
# <table id="T_8470a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8470a_level0_col0" class="col_heading level0 col0" >Class</th>
#       <th id="T_8470a_level0_col1" class="col_heading level0 col1" >Number of Instances</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8470a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8470a_row0_col0" class="data row0 col0" >AtlanticSpottedDolphin</td>
#       <td id="T_8470a_row0_col1" class="data row0 col1" >58</td>
#     </tr>
#     <tr>
#       <th id="T_8470a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8470a_row1_col0" class="data row1 col0" >BeardedSeal</td>
#       <td id="T_8470a_row1_col1" class="data row1 col1" >37</td>
#     </tr>
#     <tr>
#       <th id="T_8470a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8470a_row2_col0" class="data row2 col0" >Beluga_WhiteWhale</td>
#       <td id="T_8470a_row2_col1" class="data row2 col1" >50</td>
#     </tr>
#     <tr>
#       <th id="T_8470a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8470a_row3_col0" class="data row3 col0" >BottlenoseDolphin</td>
#       <td id="T_8470a_row3_col1" class="data row3 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_8470a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8470a_row4_col0" class="data row4 col0" >BowheadWhale</td>
#       <td id="T_8470a_row4_col1" class="data row4 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_8470a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8470a_row5_col0" class="data row5 col0" >ClymeneDolphin</td>
#       <td id="T_8470a_row5_col1" class="data row5 col1" >63</td>
#     </tr>
#     <tr>
#       <th id="T_8470a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8470a_row6_col0" class="data row6 col0" >CommonDolphin</td>
#       <td id="T_8470a_row6_col1" class="data row6 col1" >52</td>
#     </tr>
#     <tr>
#       <th id="T_8470a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8470a_row7_col0" class="data row7 col0" >FalseKillerWhale</td>
#       <td id="T_8470a_row7_col1" class="data row7 col1" >59</td>
#     </tr>
#     <tr>
#       <th id="T_8470a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8470a_row8_col0" class="data row8 col0" >Fraser'sDolphin</td>
#       <td id="T_8470a_row8_col1" class="data row8 col1" >87</td>
#     </tr>
#     <tr>
#       <th id="T_8470a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8470a_row9_col0" class="data row9 col0" >Grampus_Risso'sDolphin</td>
#       <td id="T_8470a_row9_col1" class="data row9 col1" >67</td>
#     </tr>
#     <tr>
#       <th id="T_8470a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8470a_row10_col0" class="data row10 col0" >HarpSeal</td>
#       <td id="T_8470a_row10_col1" class="data row10 col1" >47</td>
#     </tr>
#     <tr>
#       <th id="T_8470a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8470a_row11_col0" class="data row11 col0" >HumpbackWhale</td>
#       <td id="T_8470a_row11_col1" class="data row11 col1" >64</td>
#     </tr>
#     <tr>
#       <th id="T_8470a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_8470a_row12_col0" class="data row12 col0" >KillerWhale</td>
#       <td id="T_8470a_row12_col1" class="data row12 col1" >35</td>
#     </tr>
#     <tr>
#       <th id="T_8470a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_8470a_row13_col0" class="data row13 col0" >Long_FinnedPilotWhale</td>
#       <td id="T_8470a_row13_col1" class="data row13 col1" >70</td>
#     </tr>
#     <tr>
#       <th id="T_8470a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_8470a_row14_col0" class="data row14 col0" >MelonHeadedWhale</td>
#       <td id="T_8470a_row14_col1" class="data row14 col1" >63</td>
#     </tr>
#     <tr>
#       <th id="T_8470a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_8470a_row15_col0" class="data row15 col0" >Narwhal</td>
#       <td id="T_8470a_row15_col1" class="data row15 col1" >50</td>
#     </tr>
#     <tr>
#       <th id="T_8470a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_8470a_row16_col0" class="data row16 col0" >NorthernRightWhale</td>
#       <td id="T_8470a_row16_col1" class="data row16 col1" >54</td>
#     </tr>
#     <tr>
#       <th id="T_8470a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_8470a_row17_col0" class="data row17 col0" >PantropicalSpottedDolphin</td>
#       <td id="T_8470a_row17_col1" class="data row17 col1" >66</td>
#     </tr>
#     <tr>
#       <th id="T_8470a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_8470a_row18_col0" class="data row18 col0" >RossSeal</td>
#       <td id="T_8470a_row18_col1" class="data row18 col1" >50</td>
#     </tr>
#     <tr>
#       <th id="T_8470a_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_8470a_row19_col0" class="data row19 col0" >Rough_ToothedDolphin</td>
#       <td id="T_8470a_row19_col1" class="data row19 col1" >50</td>
#     </tr>
#     <tr>
#       <th id="T_8470a_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_8470a_row20_col0" class="data row20 col0" >Short_Finned(Pacific)PilotWhale</td>
#       <td id="T_8470a_row20_col1" class="data row20 col1" >67</td>
#     </tr>
#     <tr>
#       <th id="T_8470a_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_8470a_row21_col0" class="data row21 col0" >SouthernRightWhale</td>
#       <td id="T_8470a_row21_col1" class="data row21 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_8470a_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_8470a_row22_col0" class="data row22 col0" >SpermWhale</td>
#       <td id="T_8470a_row22_col1" class="data row22 col1" >75</td>
#     </tr>
#     <tr>
#       <th id="T_8470a_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_8470a_row23_col0" class="data row23 col0" >SpinnerDolphin</td>
#       <td id="T_8470a_row23_col1" class="data row23 col1" >114</td>
#     </tr>
#     <tr>
#       <th id="T_8470a_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_8470a_row24_col0" class="data row24 col0" >StripedDolphin</td>
#       <td id="T_8470a_row24_col1" class="data row24 col1" >81</td>
#     </tr>
#     <tr>
#       <th id="T_8470a_level0_row25" class="row_heading level0 ro

# %%
# Visualize the class distribution
plt.figure(figsize=(22, 8))
bars = plt.bar(class_counts.keys(), class_counts.values(), color='lightblue')

# Adding labels on top of each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, int(yval), ha='center', va='bottom')

plt.xlabel('Class')
plt.ylabel('Number of Instances')
plt.title('Number of Instances per Class')
plt.xticks(rotation=90, ha="right")  # Rotate class labels for better visibility
plt.show()

# %% [markdown]
# ## **Statistical Summary**

# %%
# Dictionaries to store durations for each class
class_durations = {}

# Recursively iterate over all files in the directory and subdirectories
for root, dirs, files in os.walk(directory):
    for filename in files:
        if filename.endswith('.wav'):
            class_name = os.path.basename(root)  # Assuming each class is a directory
            filepath = os.path.join(root, filename)
            try:
                # Load the WAV file with original sample rate
                audio_data, sample_rate = librosa.load(filepath, sr=None)
                duration = len(audio_data) / sample_rate
                if class_name not in class_durations:
                    class_durations[class_name] = []
                class_durations[class_name].append(duration)
            except Exception as e:
                print(f"Error loading {filename}: {e}")

# Data structure to hold the summary for each class
class_summary_stats = {}

# Calculate the 5-number summary for each class
for class_name, durations in class_durations.items():
    summary = pd.Series(durations).describe(percentiles=[.25, .5, .75])
    class_summary_stats[class_name] = {
        'min': summary['min'],
        '25%': summary['25%'],
        'median': summary['50%'],
        '75%': summary['75%'],
        'max': summary['max']
    }

# Set pandas display options
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)

# Calculate the 5-number summary for each class and store in a DataFrame
class_summary_stats = {class_name: pd.Series(durations).describe(percentiles=[.25, .5, .75]).to_dict()
                       for class_name, durations in class_durations.items()}
summary_df = pd.DataFrame(class_summary_stats).T

# Display the DataFrame
print(summary_df.to_string())
# Out:
#                                  count       mean         std        min        25%        50%        75%          max
# AtlanticSpottedDolphin            58.0   2.651345    7.505645   0.864554   1.332499   1.489050   1.763986    58.623168
# BeardedSeal                       37.0   9.573095   24.404341   0.750000   1.417969   2.835938   6.539800   142.500000
# Beluga_WhiteWhale                 50.0   2.626717    1.655173   0.522300   1.394531   2.097962   3.765553     8.731875
# BottlenoseDolphin                 24.0   1.241549    0.217944   0.768581   1.125000   1.265490   1.303125     1.875000
# BowheadWhale                      60.0   7.484944   18.575005   1.824000   3.605925   4.101300   5.393550   142.500000
# ClymeneDolphin                    63.0   2.576001    3.705874   0.305168   1.417969   1.919760   2.582809    24.106073
# CommonDolphin                     52.0   6.610223   15.132794   0.220699   1.139382   1.854191   2.423667    53.048185
# FalseKillerWhale                  59.0   1.157747    0.947630   0.292969   0.611719   0.899988   1.289306     5.768633
# Fraser'sDolphin                   87.0   5.834219    9.283154   0.340503   0.940448   1.890613   3.781238    32.760396
# Grampus_Risso'sDolphin            67.0   2.569309    6.095769   0.248145   0.412616   0.609375   2.291544    35.625000
# HarpSeal                          47.0   2.862088    7.666594   0.644531   0.874219   1.417969   2.505469    53.788838
# HumpbackWhale                     64.0  45.626897  118.946197   1.332282   4.360185  11.030537  24.685671   709.056779
# KillerWhale                       35.0   3.006231    2.731779   1.047671   1.638664   2.094612   3.349315    14.249452
# Long_FinnedPilotWhale             70.0   7.542372   16.471679   0.099988   0.949411   1.375103   2.819794    69.981287
# MelonHeadedWhale                  63.0   2.464891    4.991131   0.053687   0.175604   0.679077   1.370026    27.691089
# Narwhal                           50.0   1.626496    0.908752   1.196040   1.417969   1.417969   1.417969     5.861386
# NorthernRightWhale                54.0   2.202228    0.810492   0.593333   1.643781   2.170000   2.596762     4.567843
# PantropicalSpottedDolphin         66.0   1.746741    2.605259   0.273003   0.796922   1.024050   1.521078    15.293450
# RossSeal                          50.0   3.241280    0.915899   1.383500   2.619662   3.108200   3.722037     5.650650
# Rough_ToothedDolphin              50.0   1.300813    0.341452   0.456006   1.082227   1.287488   1.531238     1.890613
# Short_Finned(Pacific)PilotWhale   67.0  26.368563  155.159460   0.386133   1.051767   1.420313   2.052233  1260.000000
# SouthernRightWhale                25.0   1.867234    0.587286   1.335938   1.417969   1.764844   2.057812     3.948242
# SpermWhale                        75.0  74.117552  271.105830   0.099988   1.358203   2.826563  11.377587  1260.000000
# SpinnerDolphin                   114.0   2.786119    8.522271   0.406900   1.041950   1.367181   1.725147    57.361634
# StripedDolphin                    81.0   1.774760    2.700421   0.255677   0.965498   1.353039   1.881912    24.924835
# Walrus                            38.0   4.849516    3.980629   0.601172   1.234570   4.047542   6.632313    20.018400
# White_beakedDolphin               57.0   2.715732    1.727055   0.431925   1.852700   2.286700   2.703828     9.623630
# White_sidedDolphin                55.0   3.328035    6.635190   0.730884   1.561800   2.199187   2.747587    46.629257
# Fin_FinbackWhale                  50.0  49.537300   25.451378   5.938333  27.859583  43.847500  69.529583   101.913333
# LeopardSeal                       10.0   4.626800    2.011053   2.340000   2.804850   4.371000   6.464050     7.272000
# MinkeWhale                        17.0   1.178860    0.269918   0.708594   0.944531   1.335938   1.413281     1.417969
# WeddellSeal                        2.0  21.132252   15.089308  10.462500  15.797376  21.132252  26.467128    31.802005

# %%
# Apply a style to the DataFrame for visualisation purposes
styled_df = summary_df.style.format("{:.2f}")  # Format numbers to two decimal places
styled_df = styled_df.background_gradient(cmap='Blues')  # Apply a gradient based on values

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_b273e_row0_col0 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_b273e_row0_col1, #T_b273e_row0_col5, #T_b273e_row2_col1, #T_b273e_row7_col3, #T_b273e_row9_col2, #T_b273e_row10_col1, #T_b273e_row13_col6, #T_b273e_row14_col7, #T_b273e_row17_col3, #T_b273e_row17_col4, #T_b273e_row23_col1, #T_b273e_row26_col1, #T_b273e_row26_col6, #T_b273e_row27_col6 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_b273e_row0_col2, #T_b273e_row5_col3, #T_b273e_row8_col7, #T_b273e_row9_col7, #T_b273e_row10_col4, #T_b273e_row12_col1, #T_b273e_row21_col5, #T_b273e_row27_col2, #T_b273e_row31_col7 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_b273e_row0_col3, #T_b273e_row1_col6, #T_b273e_row6_col1, #T_b273e_row29_col6 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_b273e_row0_col4, #T_b273e_row6_col7, #T_b273e_row10_col7, #T_b273e_row22_col4 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_b273e_row0_col6, #T_b273e_row2_col2, #T_b273e_row2_col7, #T_b273e_row7_col5, #T_b273e_row13_col3, #T_b273e_row15_col1, #T_b273e_row22_col3, #T_b273e_row23_col6, #T_b273e_row26_col2, #T_b273e_row26_col7, #T_b273e_row29_col2, #T_b273e_row29_col7 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_b273e_row0_col7, #T_b273e_row1_col4, #T_b273e_row2_col3, #T_b273e_row2_col4, #T_b273e_row5_col4, #T_b273e_row15_col4, #T_b273e_row21_col4, #T_b273e_row23_col7, #T_b273e_row25_col1, #T_b273e_row27_col4, #T_b273e_row29_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_b273e_row1_col0 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_b273e_row1_col1 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_b273e_row1_col2, #T_b273e_row4_col1, #T_b273e_row13_col1, #T_b273e_row18_col4, #T_b273e_row29_col5 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_b273e_row1_col3, #T_b273e_row3_col3, #T_b273e_row4_col2 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_b273e_row1_col5, #T_b273e_row12_col4, #T_b273e_row13_col7, #T_b273e_row16_col3, #T_b273e_row16_col4, #T_b273e_row22_col5, #T_b273e_row25_col3 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_b273e_row1_col7, #T_b273e_row4_col7, #T_b273e_row15_col3 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_b273e_row2_col0, #T_b273e_row15_col0, #T_b273e_row18_col0, #T_b273e_row19_col0, #T_b273e_row28_col0 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_b273e_row2_col5, #T_b273e_row3_col4, #T_b273e_row6_col4, #T_b273e_row8_col2, #T_b273e_row12_col5, #T_b273e_row19_col4, #T_b273e_row20_col3, #T_b273e_row20_col4, #T_b273e_row23_col3, #T_b273e_row23_col4 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_b273e_row2_col6, #T_b273e_row8_col6, #T_b273e_row16_col5, #T_b273e_row18_col6, #T_b273e_row19_col3, #T_b273e_row25_col4, #T_b273e_row26_col3, #T_b273e_row26_col5, #T_b273e_row27_col5, #T_b273e_row27_col7 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_b273e_row3_col0 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_b273e_row3_col1, #T_b273e_row3_col2, #T_b273e_row3_col6, #T_b273e_row3_col7, #T_b273e_row7_col1, #T_b273e_row7_col2, #T_b273e_row7_col6, #T_b273e_row7_col7, #T_b273e_row9_col5, #T_b273e_row14_col3, #T_b273e_row14_col4, #T_b273e_row14_col5, #T_b273e_row14_col6, #T_b273e_row15_col2, #T_b273e_row15_col6, #T_b273e_row15_col7, #T_b273e_row16_col2, #T_b273e_row16_col7, #T_b273e_row17_col6, #T_b273e_row18_col2, #T_b273e_row18_col7, #T_b273e_row19_col1, #T_b273e_row19_col2, #T_b273e_row19_col6, #T_b273e_row19_col7, #T_b273e_row21_col2, #T_b273e_row21_col7, #T_b273e_row30_col1, #T_b273e_row30_col2, #T_b273e_row30_col6, #T_b273e_row30_col7, #T_b273e_row31_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_b273e_row3_col5, #T_b273e_row5_col2, #T_b273e_row9_col6, #T_b273e_row16_col1, #T_b273e_row25_col2, #T_b273e_row25_col7 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_b273e_row4_col0 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_b273e_row4_col3 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_b273e_row4_col4, #T_b273e_row11_col3, #T_b273e_row21_col3 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_b273e_row4_col5, #T_b273e_row25_col5, #T_b273e_row25_col6, #T_b273e_row28_col7 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_b273e_row4_col6, #T_b273e_row13_col2, #T_b273e_row26_col4 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_b273e_row5_col0, #T_b273e_row14_col0 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_b273e_row5_col1, #T_b273e_row5_col6, #T_b273e_row5_col7, #T_b273e_row6_col3, #T_b273e_row6_col6, #T_b273e_row7_col4, #T_b273e_row9_col1, #T_b273e_row9_col3, #T_b273e_row10_col5, #T_b273e_row10_col6, #T_b273e_row13_col5, #T_b273e_row14_col1, #T_b273e_row14_col2, #T_b273e_row15_col5, #T_b273e_row16_col6, #T_b273e_row19_col5, #T_b273e_row20_col5, #T_b273e_row23_col5, #T_b273e_row24_col3, #T_b273e_row24_col5, #T_b273e_row24_col7, #T_b273e_row30_col5 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_b273e_row5_col5, #T_b273e_row6_col5, #T_b273e_row8_col3, #T_b273e_row8_col4, #T_b273e_row8_col5, #T_b273e_row10_col2, #T_b273e_row12_col6, #T_b273e_row13_col4, #T_b273e_row18_col1, #T_b273e_row23_col2, #T_b273e_row24_col4, #T_b273e_row27_col1, #T_b273e_row30_col4 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_b273e_row6_col0 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_b273e_row6_col2, #T_b273e_row10_col3, #T_b273e_row18_col5, #T_b273e_row31_col2 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_b273e_row7_col0 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_b273e_row8_col0 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_b273e_row8_col1, #T_b273e_row27_col3, #T_b273e_row30_col3 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_b273e_row9_col0, #T_b273e_row20_col0 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_b273e_row9_col4, #T_b273e_row12_col2, #T_b273e_row12_col7, #T_b273e_row17_col1, #T_b273e_row17_col2, #T_b273e_row17_col5, #T_b273e_row17_col7, #T_b273e_row20_col6, #T_b273e_row21_col1, #T_b273e_row21_col6, #T_b273e_row24_col1, #T_b273e_row24_col2, #T_b273e_row24_col6 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_b273e_row10_col0 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_b273e_row11_col0 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_b273e_row11_col1 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_b273e_row11_col2 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_b273e_row11_col4 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_b273e_row11_col5 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_b273e_row11_col6 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_b273e_row11_col7 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_b273e_row12_col0 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_b273e_row12_col3, #T_b273e_row29_col4 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_b273e_row13_col0 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_b273e_row16_col0 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_b273e_row17_col0, #T_b273e_row20_col2 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_b273e_row18_col3 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_b273e_row20_col1 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_b273e_row20_col7, #T_b273e_row22_col1, #T_b273e_row22_col2, #T_b273e_row22_col7, #T_b273e_row23_col0, #T_b273e_row28_col4, #T_b273e_row28_col5, #T_b273e_row28_col6, #T_b273e_row31_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b273e_row21_col0 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_b273e_row22_col0 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_b273e_row22_col6 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_b273e_row24_col0 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_b273e_row25_col0 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_b273e_row26_col0 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_b273e_row27_col0, #T_b273e_row31_col5 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_b273e_row28_col1

# %%
# Use a whitegrid
sns.set(style="whitegrid")

# Number of plots per row
plots_per_row = 3

# Calculate the number of required rows
num_classes = len(class_durations)
num_rows = (num_classes + plots_per_row - 1) // plots_per_row

# Set up the figure and axes
fig, axs = plt.subplots(num_rows, plots_per_row, figsize=(15, num_rows * 5))  # Adjust the figure size as needed
fig.subplots_adjust(hspace=0.4, wspace=0.3)  # Adjust horizontal and vertical spacing

# Plot data
for idx, (class_name, durations) in enumerate(class_durations.items()):
    ax = axs[idx // plots_per_row, idx % plots_per_row]
    sns.boxplot(data=durations, color='skyblue', ax=ax)
    ax.set_title(f'Box Plot for {class_name}')
    ax.set_xlabel('Class')
    ax.set_ylabel('Duration (seconds)')

# Hide any unused axes if the number of classes isn't a perfect multiple of plots_per_row
if num_classes % plots_per_row:
    for ax in axs.flatten()[num_classes:]:
        ax.set_visible(False)

plt.show()
